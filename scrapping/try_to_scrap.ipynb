# %%
from selenium import webdriver

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 963C-DFD5
#
#  C:\Develops\forkspoon 디렉터리
#
# 2021-08-12  오후 10:04        11,107,328 chromedriver.exe
#                1개 파일          11,107,328 바이트
#                0개 디렉터리     330,870,784 바이트 남음

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('https://www.jobkorea.co.kr/')

# %%
import time

# %%
time.sleep(1.5)
browser.find_element_by_css_selector('span.mainBtn.mainBtnPer').click()
browser.find_elements_by_css_selector('input#lb_id.iptTx')[0].send_keys('axlovexa')
browser.find_elements_by_css_selector('input#lb_pw.iptTx.devCapsLock')[0].send_keys('multi0811')
browser.find_element_by_css_selector('div.loginIptWrap.clear>button.btnLogin').click()

# %%
time.sleep(1.5)
browser.find_element_by_css_selector('li#gnbStart>a.linkItem').click()
browser.find_element_by_css_selector('li>a[href="/starter/passassay/"]').click()

# %%
browser.find_element_by_css_selector('div.toolTipCont.fullLy>div>button').click()
browser.find_elements_by_css_selector('input#txtSearch')[0].send_keys('선택한')

browser.find_element_by_css_selector('button#btnSraech').click()

# %%
cnt = 0
import pandas as pd
from bs4 import BeautifulSoup

# %%
# contents = []
for i in range(1,21):
    browser.find_element_by_css_selector('li:nth-child('+str(i)+') > div.txBx > p > a > span').click()
    html = browser.page_source
    soup = BeautifulSoup(html, 'html.parser')
    introduction_page = soup.select('div.stContainer')
    time.sleep(1)
    
    contents = []
    for scraping in introduction_page:
        company = introduction_page[0].select('h2 > strong > a')[0].text.strip()
        group = introduction_page[0].select('h2 > em')[0].text.strip()
        score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
        result = [company, group, score]


        for q in range(0, 10):
            try:
                ColumnQ = 'Q'+str(q+1)
                question = soup.select('button > span.tx')[q].text.strip()
                ColumnA = 'A'+str(q+1)
                answer = soup.select('dd > div.tx')[q].text.strip()
                print(ColumnQ, question, ColumnA, answer)
#                 df = pd.DataFrame(contents,columns=['company', 'group', 'score', 'question', 'answer'])
            except IndexError:
                print(' ')
                result = [company, group, score, question, answer]
                contents.append(result)

    browser.back()
    
#     question1, answer1, question2, answer2, question3, answer3, question4, answer4,question5, answer5, question6, answer6, question7, answer7, question8, answer8, question9, answer9, question10, answer10
# Out:
# Q1 입사 지원동기를 작성해주세요. (① 지원 부문을 선택한 이유와 ② 지원 부문과 관련하여 본인이 쌓아온 역량을 포함하여 작성) 단, 경영과 기술 부문 지원자는 해당 부문에서 구체적으로 '어떤 업무'를 하고 싶은지, 그 업무 수행을 위한 본인의 경쟁력은 무엇인지 제시해주세요. 최소 30자 / 1000자 제한 A1 경영은 전사의 콘텐츠 제작에서부터 유통 과정을 파악하고, 설정한 목표를 이루기 위해 전 과정에서의 문제점이나 비효율성을 제거하는 직무임을 알고 있습니다. 이 직무를 수행하기 위해서는 상황판단력과 문제해결력이 필수 역량이라고 생각합니다.아쉬운점 1 한국어, 영어, 일본어에 이르는 언어 구사력과 빠른 적응력을 바탕으로, 풍부한 사회 경험을 하며 핵심 역량을 키웠습니다. ‘OOOOO’와 ‘OOO’에서 교육 콘텐츠 개발 및 학생 응대 CS업무를 수행하면서, 클라이언트와의 소통을 통한 효율적인 문제해결 방법을 끊임없이 모색하여 최선의 결과를 도출하곤 했습니다. 회사 부대표님 말씀에 따르면 제가 제작에 참여한 교재 콘텐츠나 상담 내역을 기록한 일지는 후임 직원들에게 몇년 간 본보기처럼 제시되고 있다고 합니다. 아쉬운점 2
#
# 제가 배양한 역량을 바탕으로 경영 부문의 다섯 가지 직무군 중 ‘정책’ 혹은 ‘사업’ 팀에서 일하며, 방송 환경의 무한한 미래를 그려가고자 희망합니다. 방송 시장이 급격한 변화를 맞으면서, 귀사는 사업영역 확장을 고민하고 도전하였습니다. 귀사가 장기적으로 성장할 수 있도록, 콘텐츠의 효율적인 재생산 방식을 탐구하고 싶습니다. 시장 변화에 민첩하게 반응하는 유연성을 바탕으로, 페이퍼워크뿐만 아니라 확장된 영역의 업무를 수행하는 데에도 준비되어 있습니다. 아쉬운점 3 글자수 649자1,122Byte
# Q2 SBS는 당신이 어떤 사람인지 궁금합니다. 소위 말하는 '스펙'의 나열보다는, '내가 어떤 사람인지' 보여줄 수 있는 자신의 성격이나 스타일을 자유로운 방식으로 설명해주세요. 최소 30자 / 1000자 제한 A2 저는 한번 마음먹고 시작한 일은 쉽게 포기하지 않는 ‘끈기’와 ‘집중력’이 대단합니다. 대학에 들어와 시작한 과외 아르바이트 및 그 외 아르바이트는 모두 4년 이상 단 한 번의 지각이나 트러블 없이 최근까지 계속해 왔습니다. 맡은 업무에 최선을 다하고 주변환경이 방해해도 흔들림이 없는 저의 성격은 경영직무 신입사원으로서 지녀야 할 핵심 역량 중 하나라고 생각합니다.
#
# 더 나아가, 제가 특히 좋아하는 분야에는 오랜 시간과 정성을 들여, 모르는 것이 없을 정도로 통달하는 수준에 이르는 특징이 있습니다. 남들보다 열성적으로 식도락을 즐기는 저를 보고 친구들이 ‘OOOO’라는 별명을 붙여주기도 했습니다. 새로운 맛집을 연구하고, 리뷰를 남기고, 먹어본 경험을 바탕으로 제가 직접 만들어보는 과정을 통해, 주변인들과 만날 때마다 미식의 즐거움을 주는 것이 저에게 큰 보람입니다. 뿐만 아니라 앞으로도 계속해서 더 많은 음식을 탐구하는 식도락 여정의 기쁨을 극대화하기 위해, 평소에 운동과 건강 관리도 놓치지 않고 있습니다.아쉬운점 1 글자수 518자891Byte
# Q3 본인의 경험 중 가장 큰 성공 경험과 가장 큰 실패 경험을 작성해주세요. (경험의 대상은 학업/일/인간 관계 등 어떤 것도 상관 없으며, 각 경험을 통해 배운 점을 포함하여 작성) 최소 30자 / 1000자 제한 A3 성공 경험: 아르바이트 중 위기 극복
# 실패 경험: 대학교 팀프로젝트아쉬운점 1 글자수 39자65Byte
# Q4 기업 경영과 관련된 여러가지 사회적 변화 속에서, SBS가 경쟁력 있는 기업으로 성장하기 위하여 가장 신경 써야 하는 부분은 무엇일까요? (① 선정 이유와 ② 실제 SBS 경영에 어떻게 반영되어야 할지 본인의 견해를 포함하여 작성) 최소 30자 / 1000자 제한 A4 무한 경쟁이 일어나는 미디어 시장에서 귀사가 경쟁력을 높이기 위해서는, 비재무적 성과를 측정하는 지표인 ‘ESG(환경, 사회, 지배구조)’에 관심을 기울여야 합니다. ESG는 미래에 지속가능한지를 알려주는 지표입니다. 최근 해외 투자시장에서는 이 지표를 잣대로 투자여부를 결정하는 추세가 증가하고 있습니다. 또한 미·중무역전쟁이나 코로나19의 확산과 같은 대내외적 경영위기 속에서, 국내 기업들은 환경 투자와 사회적 책임 수행, 지배구조 개편 등 미래 지속가능성을 높이기 위한 노력을 아끼지 않고 있습니다. 귀사에 지표를 도입함으로써, 방송 콘텐츠의 다양성을 보다 제고하여 미래 성장 비전을 실현하고, 글로벌 콘텐츠 기업 1위의 입지를 굳건히 할 수 있을 것입니다. 아쉬운점 1
#
# 실제 경영에 반영한다면, 방송의 윤리강령 준수 정도를 다방면으로 평가하도록 적용할 수 있습니다. 또한, 콘텐츠 제작, 송출 주체로서, 디지털 탄소발자국 이슈에 주목하여 환경문제 개선에 기여해야 합니다. 코로나로 IT기기의 사용과 동영상 스트리밍이 증가하면서, 데이터 센터의 전력 소비와 열 방출이 급증하고 이와 함께 열 냉각을 위해서도 대규모 전력이 소모되기 때문입니다. 탄소 중립적인 데이터 센터 설립 및 운영방식을 고려하고, 콘텐츠 유통 전과정이 환경에 미치는 영향을 최소화하고자 노력할 수 있습니다.  ESG 경영의 중요성을 인지하고 진정성 있게 추진하는 데 관심을 기울인다면, 귀사가 경쟁력 강한 글로벌 기업으로 나아갈 수 있을 것입니다.아쉬운점 2 글자수 738자1,265Byte
#
#
#
#
#
#
# Q1 과거 자기개발에 꾸준히 노력한 자신의 모습을 평가해 주시고, 전문가로 성장하기 위해 본인이 노력한 내용을 기술해 주십시오. (500) A1 "내실을 굳게 다진 소재공학도"
#
# 소재 기술은 표면적으로 드러나지 않지만, 제품의 전반적인 성능을 결정하는 핵심 기술입니다. 이러한 매력에 끌려 재료공학을 전공했습니다. 학부 때는 재료 미세구조설계, 열기계적 특성 등의 전공을 배우고, 전공평점 3.93의 성적을 유지하며 소재에 대한 기본기를 다졌습니다. 또한, 소재 핵심역량을 키우기 위해 대학원에 진학하여 ‘Si계 무기고분자 합성과 이를 이용한 세라믹 섬유’를 연구했습니다. 세부전공으로 다룬 소재의 실험 설계, 결과 분석, 학회에서 연구내용 발표, 문헌을 작성해본 경험은 소재 전문가로 성장하는 데 많은 도움이 되었습니다. 연구경력을 꾸준히 쌓고자 한국OOOOOO의 인턴연구원으로 활동하며 탄소섬유강화복합재 관련 과제의 실험 업무를 도맡았습니다. 복합재에 적용되는 무기계 바인더의 배합비와 공정조건 확립, 물성 평가 업무를 지속해서 수행했습니다. 폭넓게 쌓은 소재역량은 한국산업단지공단의 소재부품산업 과제를 수행하는 데 도움이 될 것입니다.좋은점 1 글자수 503자867Byte
# Q2 상황 변화에 대해 본인이 받아들이는 방식에 대해 평가해 주시고, 과거 혁신적인 변화를 기획하고 성과를 창출한 사례를 기술해 주십시오. (500) A2 "엉킨 실타래는 생각보다 단순하게 풀린다"
#
# 벤치마킹한 특허 내용과는 다른 배합 방식을 적용해 정부 과제의 목표를 성공적으로 달성한 경험이 있습니다.아쉬운점 1
# 한국OOOOOO의 인턴으로 활동하면서 ‘섬유복합재용 Si계 무기고분자 합성’ 과제를 담당했습니다. 과제의 목표는 프리프레그 제조가 가능할 정도의 성형성과 800도 내열성을 갖는 섬유강화복합재를 확보하는 것이었습니다.
# 과제 진행 초기에는 벤치마킹한 특허를 토대로 배합비를 설정하여 바인더의 물성을 확보하려 했으나, 용매의 함량이 너무 적고 흄드 실리카의 비표면적이 매우 넓어 균일한 혼합이 불가능했습니다. 이 문제를 해결하고자 적용 가능한 원재료와 실험 관련 문헌을 꼼꼼히 조사했고, 생각지도 못한 ‘화장품용 실리카 분말’을 적용했을 때 문제를 해결할 수 있었습니다. 소량의 계면활성제와 오토클레이브 공정을 추가하여 과제의 최종목표를 성공적으로 달성할 수 있었고, 수행한 과제의 연구공로를 인정받아 150만 원의 성과금을 받았습니다.아쉬운점 2 글자수 497자859Byte
# Q3 본인의 대인관계에 대해 평가해 주시고, 여러 사람이 관계된 일을 수행할 때 상대방의 이익을 해치지 않고 목적을 달성한 사례를 기술해 주십시오. (500) A3 "내가 맡은 업무는 꼭 성공시킨다!"
#
# 대학생부터 지금까지 저는 ‘조직 속에서 내 가치를 충분히 드러내자’는 생각으로 사회 활동에 임하였습니다. 아쉬운점 1학부생 시절, 캡스톤 디자인 프로그램으로 ‘니켈-망간 산화물의 전기적 특성 평가’ 팀 프로젝트를 진행했을 때 PPT 구성과 발표를 담당했습니다. 팀원들과 함께 실험한 자료와 사진을 취합하고, 이를 바탕으로 짜임새 있게 발표자료를 구성했습니다. 최종발표의 2일 전부터 팀원들에게 모의발표를 하면서 예상 질문에 대비하였고, 15분의 제한시간 내에 발표를 마무리하고자 연습에 몰두했습니다. 브리핑 연습을 토대로 발표한 결과, 구성한 내용을 깔끔하게 설명할 수 있었고, 질의응답 시간까지 청중들의 집중을 받아 팀원 모두가 A의 성적을 받았습니다.
# 이처럼 조직에서 가치를 발휘하고자 노력할 때, 그 결과는 모두가 발전하는 방향으로 바뀐다고 생각합니다. 맡은 역할에 최선을 다한다면 결과는 배신하지 않는다는 것을 느끼게 해준 경험이었습니다.아쉬운점 2 글자수 492자848Byte
# Q4 본인이 업무를 대하는 태도에 대해 평가해 주시고, 주어진 업무가 기한 내 미완수될 우려가 있었으나, 이를 해결하여 성공적으로 마무리했던 경험을 기술해 주십시오. (500) A4 대학원생 시절, 탄화규소 세라믹의 전구체인 폴리카보실란의 기술개발을 위해 공동연구 협약을 맺은 기업 측에서 급하게 전구체 반응물 200g을 요구한 적이 있었습니다.아쉬운점 1
# 1주에 반응물 120g을 얻을 수 있는 기존의 합성조건은 1일 차에 350도 10시간, 2일 차에 450도 6시간 합성하여 반응물을 얻는 데 2일이 걸렸습니다. 반응물을 여과 및 진공 정제하고 추후 합성을 위한 반응기 세척까지 포함하면 총 4일이 필요했습니다. 기업 과제를 함께 하던 선배는 넉넉히 2주 정도의 시간이 필요하다고 말했지만, 저는 기존 합성 일정을 참고하여 반응물 120g을 합성하는 데 2일이 걸리던 일정을 하루에 가능하도록 수정하여 최대한 기업 측 요구를 들어주려 노력했습니다. 수정한 합성조건은 총 14시간이 걸려 밤늦게 실험이 종료되었지만, 일주일에 2회 합성을 할 수 있어 200g의 반응물을 안정적으로 공급할 수 있었고, 추가적인 원료 분석 결과까지 전달하여 협약 기업의 높은 신뢰를 얻을 수 있었습니다.좋은점 1 글자수 501자837Byte
# Q5 우리 공단에 지원동기와 직무를 선택한 이유, 입사 후 목표와 포부를 기술해 주십시오. (500) A5 "‘재료’를 전공하며 나의 가치를 증명하다"
#
# 제조업은 우리나라 경제의 주요 성장 기반이며 특히, 소재부품의 기술력은 국가 경쟁력과도 직결되므로 소재기술의 중요성은 더욱 커지고 있습니다. 한국산업단지공단은 국내 핵심 소재부품의 글로벌 경쟁력을 키우고 시장 변화에 대응하기 위해 산업의 융복합화, 스마트화 등 고부가가치 소재부품을 개발하는 데 지원을 아끼지 않고 있습니다. 산업단지의 70% 이상을 이루는 소재부품기업의 산업 활동을 지원하면서 내 가치를 증명하고, 산단에 입주한 소재부품기업의 핵심 기술력을 강화하고자 한국산업단지공단의 소재 직무를 선택하였습니다.아쉬운점 1
#
# 입사 후 국가의 근간 사업인 제조업 시장의 경쟁력을 강화하는 데 최선을 다하겠습니다. 단기적으로는 산단 내에 입주한 소재부품장비 기업을 분석하고 정책과제의 진행 현황을 파악하겠습니다. 궁극적으로 소재부품기술의 대외 의존성을 낮춰 국가의 소재기술 혁신을 주도하는 인재가 되겠습니다.아쉬운점 2 글자수 474자831Byte
# Q6 과거 교육과정, 경력들을 통해 습득한 전공지식, 기술경험이 우리 공단 업무와 관련성이 있는지? 그러한 지식과 경험을 실제 어떠한 방식으로 우리 공단에 적용할 수 있는지 기술해 주십시오. (500) A6 대학원생, 인턴연구원 활동으로 얻은 경험을 발휘하여 공단의 소재 직무에 적용하겠습니다.
# 대학원생 시절, 항공기 동체의 고부가가치 부품으로 적용되는 세라믹섬유복합소재 분야를 연구한 경험이 있습니다. 섬유강화복합재의 개발 동향 및 응용 분야에 관한 문헌 조사, 국제 복합소재 전시회 참가, 국내/외 학회 참석 및 발표 등의 경험들은 공단의 소재부품산업을 육성하고 R&D 고도화 방안을 제시하는 데 활용할 수 있을 것입니다.
# 한국OOOOOO의 인턴연구원으로 활동 시, 타 연구기관과 협업하여 ‘산업부산물을 이용한 섬유복합재용 무기바인더 합성’ 과제를 1년간 수행했습니다. 과제의 실험연구원으로 회의에 참여하면서 실험 중 발생한 내용에 대응하고, 과제 목표를 달성하기 위한 방안을 제시하는 업무를 주로 담당했습니다. 이러한 경험은 공단과 입주 기업 간 협력 관계를 형성하여 R&D 지원 방향을 제시하는 데 도움이 될 것입니다.아쉬운점 1 글자수 460자789Byte
# Q7 과거 타인의 욕구나 기대사항을 반영하여 주도적으로 도움을 준 사례 및 입사 후 산단 입주기업 지원을 위한 본인의 이행 계획을 기술해 주십시오. (500) A7 3D 프린팅용 무기고분자의 경화 문제를 해결한 경험이 있습니다.
# 인턴활동 중 팀원이 담당하고 있는 경화 실험이 잘 안 되어 성형체가 계속 무너지는 문제가 생겼습니다. 동료는 이를 해결하기 위해 석사 주제로 실리콘 기반의 무기고분자 합성을 연구했던 저에게 도움을 요청했습니다. 3D 프린팅용 무기고분자는 액상 폴리카보실란을 사용하며 열경화가 아닌 광경화 기반으로 성형되지만, 에너지 전달 방법만 다를 뿐 경화 메커니즘은 같았습니다. 석사과정 때 참고한 문헌 일부를 설명해주었고 조사한 내용을 기반으로 변수를 하나씩 제어한 결과, 링 타입의 성형체를 안정적으로 얻을 수 있었습니다.좋은점 1
# 입사 후 소재부품산업의 산학연 네트워크를 활성화하여 산단 입주기업의 경쟁력을 강화하겠습니다. 학부 실험실 생활, 대학원, 인턴 활동을 하면서 다양한 연구기관, 기업체와 과제를 수행하고 세미나, 기술교류 활동을 했습니다. 이러한 경험들을 활용하여 입주기업에 물적, 인적 자원을 꾸준히 공급하겠습니다.좋은점 2 글자수 492자853Byte
# Q8 과거 학업, 업무 시 경력개발을 위한 비전 수립 및 이행 사례를 기술하시고, 공단 입사 후 본인 경력개발 비전을 제시해 주십시오. (500) A8 재료공학도로 성장하여 전문성을 어필하고자 ‘SCI급 학술논문 1저자 게재’ 목표를 세워 석사과정에 임하였습니다.
# 섬유화 공정에 필요한 이론과 지식을 쌓기 위해 100편 이상의 참고문헌을 학습하고, 폴리머 합성실험과 분석을 병행했습니다. 분기별로 진행한 연구 내용은 국내 학회에 참가하며 꾸준히 점검하였고, 학회 시즌이 끝난 다음 주에는 랩 세미나 시간을 활용해 동료들에게 내용을 공유하였습니다. 그 결과, ‘섬유 방사용 무기고분자 합성’ 관련 SCI급 해외학술지에 1 저자로 게재하는 성과를 낼 수 있었습니다.
# 공단 입사 후, 경량소재부품 기업의 산업 활동을 지원하고 기술경쟁력을 키우는 데 집중하겠습니다. 차세대 먹거리 산업으로 친환경 모빌리티 시장이 빠르게 성장하고 있습니다. 석사 및 인턴활동 중 진행했던 섬유강화복합재 연구 경험을 바탕으로 탄소섬유를 적용한 경량복합소재 기업의 기술개발과 산학연 클러스터 형성을 지원하겠습니다.좋은점 1 글자수 468자810Byte
#
#
# Q1 지원직무를 선택한 이유를(직무와 관련한 경험, 전공, 수강과목, 자격증 등을 포함하여) 설명하십시오. A1 "직접 만든다는 것"
#
# 실습을 위해 콤부차를 조사하였습니다. 한정된 자료에서 최대한 조사했지만, 자세한 공정은 알 수 없었습니다. 좋은 결과를 도출하기 위해선 철저한 계획이 중요하다 생각돼 제조사, 제조공장에 문의하여 부원료 선택조건, 발효시간 등의 부분적인 답변을 들음으로 초안을 계획할 수 있었습니다. 이후 차 제조회사의 개발 업무에서 두 원료를 조합해 제품을 개발하는 업무에 참여했는데, 두 원료를 섞으면서 각각의 특색이 사라지는 문제가 있었습니다. 두 원료가 활성을 가지는 당도와 산도가 극과 극이었기 때문이었는데, 이전 실습을 위해 공정 조사를 문의할 때 조합이 좋을 것 같은데 왜 사용을 하지 않는지에 대한 답변을 실제로 경험하게 된 상황이었습니다. 두 원료의 황금비율을 찾는 것과 동시에 맛, 컨셉, 안정성 또한 유지하려 노력했습니다. 배합비를 수정하고 관능 검사하는 과정을 반복하면서 혀가 쓴맛을 즐기게 될 때쯤, 제품의 완성도가 갖춰져 두가지 원료를 조화롭게 느낄 수 있었습니다. 그리고 전화로 들었던 한계를 해결하는 듯한 성취감 또한 느꼈습니다. 아쉬운점 1
#
# 소비자 입장에서 왜 맛있는 두가지를 섞어 팔지 않는지에 대해 의구심을 가졌습니다. 하지만 식품을 전공하면서 의구심에 대한 답을 배우고, 개발을 하면서 해결방안을 찾았습니다. 주변을 둘러보면 많은 소비자들이 자신들이 자신이 원하는 제품을 기다리는 모습을 볼 수 있습니다. 모든 소비자가 식품을 전공하고 개발할 수 없기에 누군가가 소비자를 위해 제품을 만들어야 합니다. 그리고 저는 제가 얻은 지식과 경험으로 소비자를 위한 제품을 만들기 위해 노력하겠습니다.아쉬운점 2 글자수 800자1,381Byte
# Q2 직장 또는 단체생활에서 구성원에게 가장 필요한 태도, 역량은 무엇이라고 생각하는지 본인의 경험을 바탕으로 설명하십시오. A2 "각자의 경험이 다르다는 것"
#
# 인턴기간에 동반성장을 목표로 새로운 메뉴를 개발하는 프로젝트에 참여했습니다. 기업간의 협업으로, 각자가 잘 하는 방식으로 자신의 역할에 최선을 다했어야 했기에 초기 아이디어 회의에서부터 많은 의견이 나왔습니다. 아쉬운점 130개의 아이디어는 각각 매력과 가능성을 가지고 있었지만 가장 좋은 것을 선별해야 했습니다. 먼저 1차적인 선별을 위해 시장조사와 제조공정을 파악하여 대중성이 있고, 자체 개발이 가능한 제품을 선별했습니다. 이 과정에서 저는 팀으로 협력하면서 팀 구성원에게 필요한 태도를 배울 수 있었는데, 바로, 각자의 역할을 수행하고, 서로의 접근방식을 공유하고 수용하며 해답을 찾는 것입니다. 아쉬운점 2저는 프로젝트에서 소비자들의 소비형태와 그에 따른 시장의 동향을 조사하였고, 이를 요약하여 팀원들에게 분배했습니다. 그리고 팀원들은 받은 자료를 토대로 각자가 담당하던 제품과 연관된 소재를 구체화하였고, 마지막으로 팀장이 단가, 공정 등 세부사항을 판단하여 좋은 주제를 간추렸습니다.
#
# 기업간 협업에서 각자가 잘하는 방식으로 역할에 최선을 다하듯 팀 구성원도 자신의 역할에 충실하여 효율을 높일 수 있었습니다. 또한, 아이디어 회의에서부터 매일 1회 이상 프로젝트 회의를 진행하면서 비슷한 상황에서 창의적, 효과적으로 해결할 수 있었던 각자의 방법을 서로 제시하고 실천하여 효율적으로 업무를 진행하였습니다. 결과적으로, 각자의 경험이 다르다는 것은 다양한 시선과 방법이 다양하다는 것으로, 관점과 방법을 제시하고 수용하면서 함께 발전할 수 있다는 점에서 팀에게 가장 필요한 태도이자 역량이라고 생각하였습니다.아쉬운점 3 글자수 803자1,398Byte
# Q3 오뚜기에 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 설명하십시오. A3 "가능성을 캐내고 가치를 심자"
#
# 식품은 광범위한 방면에서 다양한 방향성을 가지고 나아가고 있기 때문에 대학에 오랜 기간에 걸쳐 쌓인 지식으로는 현재 식품 시장을 온전히 이해할 수 없다고 생각했습니다. 우물 안 개구리에서 벗어나 트렌드를 이해하고 한발 먼저 행동하기 위해 식품 신문을 읽고 시장과 제품 조사를 하면서 빠른 변화에 적응하려고 노력했습니다. 그러면서 깨달은 것은 식품 산업이 무궁무진한 가능성을 가지고 있는 덕분에 다양한 방향성을 가지고 나아갈 수 있다는 것이었습니다. 아쉬운점 1오뚜기는 식품 산업 전반을 이끄는 기업입니다. 가능성을 봤을 때 언제든 뛰어들어 열풍을 이끌 수 있다고 오뚜기의 제품이 증명합니다.
#
# 저는 식품 산업의 가능성을 확인하면서 가능한 방향성을 찾을 수 있었습니다. 그리고 그 방향성으로부터 원료와 제품에서 가치를 발굴하고 또다른 가치를 심어주는 것을 저의 목표로 하였습니다. 아쉬운점 2신라면 두부김치, 열려라 참깨라면은 두가지 제품의 시너지 효과를, 전자레인지를 이용한 컵라면 조리방법은 새로운 즐거움을, 진짬뽕밥은 기존 제품에 새로운 가치를 이끌어냈습니다. OEM, ODM, 아웃소싱, 협업 등의 구조는 계속해서 발전하면서 좋은 제품을 위한 방법을 제시하고 가치를 창출할 수 있는 가능성이 증가시킵니다. 오징어 먹물을 넣은 검은색 비빔면, 시금치 페스토를 이용한 파스타 등 다양한 가치를 지녔지만 아직 발굴되지 않은 제품이 많다고 생각합니다. 새로움과 변화를 주도하는 오뚜기에서 저는 기존 제품의 가능성을 캐내고, 새로운 원료와 가능성에 가치를 심어 함께 발전하도록 하겠습니다.아쉬운점 3 글자수 787자1,359Byte
#
#
#
#
#
#
#
# Q1 본인이 선택한 직무에 대해 아래 내용을 포함하여 기술하시오. ①지원한 직무의 역할이 무엇이라 생각하는지 자유롭게 기술 ②본인이 해당 직무에 적합하다는 근거를 본인의 경험을 바탕으로 기술 ③입사 후 경력개발 계획에 대해 기술 A1 `전지적 참견 시점`
#
# 영업관리 직무는 BGF리테일의 점포 관리를 위한 매니저라고 생각합니다. 시청자의 사랑을 받는 유명 인기연예인은 유능한 매니저가 뒷받침되어야 만들어지는 것처럼, SC 직무는 시장, 점포운영, 트렌드 등을 분석하여 BGF리테일의 점포가 고객의 사랑을 받을 수 있도록 최선을 다해 지원하는 직무입니다.좋은점 1
#
# `Be Good Fact : 신뢰를 주는 소통`
#
# 신뢰를 주는 소통을 할 줄 알며, 이를 통해 효율적인 SC 직무 수행이 가능하다고 생각합니다. 학사 과정 중, 신뢰감을 주는 정보전달로 효율적인 업무 수행을 경험했습니다.
# 아쉬운점 1
# 팀 활동 시, 많은 시간이 발표 전 자료의 객관성과 사실을 확인하는 과정에 들었고, 부정확한 정보로 팀원 간 갈등을 경험했습니다. 이후, 자료를 일목요연하게 정리하고, 객관적인 사실과 명확한 출처를 밝혀 전달했습니다. 확실한 자료조사는 많은 시간을 단축했고, 질의·응답까지 완벽하게 답변하는 높은 수준의 발표를 만들었습니다. 또한, 팀원 간 형성된 신뢰감은 이후 활동에서 좋은 효율성을 보였습니다.
#
# 이처럼, 설득력 있는 정확한 자료조사와 분석 역량은 점주와 신뢰감을 형성하고, 장기적으로 좋은 시너지를 발휘할 수 있다고 생각합니다.     아쉬운점 2
#
# '경험으로 만드는 최고의 교본.'
#
# 단기적인 목표는 직영점 근무 시, 해당 점포 상권 분석을 철저히 하고 도전적인 전략을 구사하며 더욱 다양한 현장 경험을 쌓을 계획입니다. 또한, 재고품을 최소화하기 위해, 점주님과 협업으로 효과적인 POP 전략을 구사할 계획입니다. 또한, 이후, CVS산업 특성상, 다양한 상권에 다양한 점포가 있고, 다양한 점포를 담당해야 하는 SC 업무를 위해, 시장분석부터 영업관리 경험을 분석, 정리, 빅데이터화해 장기적으로 업무의 효율을 높이겠습니다.
# 아쉬운점 3 글자수 895자1,492Byte
# Q2 공동의 목표를 달성하기 위하여 가장 중요하다고 생각하는 역량 1가지를 선정하고, 그 이유와 해당 역량을 발휘하여 목표를 달성한 경험에 대해 구체적으로 기술하시오. A2 "남의 말을 잘 들으면 좋은 결과가 나온다"
#
# 팀워크 시 의사소통 역량을 중요하게 생각했고, 원활한 의사소통을 통한 참신한 아이디어로 PT 대회에서 좋은 성과를 이룬 경험이 있습니다.
#
# 교내 PT 대회 당시, 3인의 팀을 구성해 참가했습니다. 학교 커뮤니티를 통해 직무에 맞춘 공고를 올리고, 팀원을 구성하게 되었습니다. 대회 주제는 ‘학교 내 한 가지만 바꾼다면’ 이였으며, 입상을 공동의 목표로 설정했습니다. 효율적인 의사소통을 위해 나이, 학과 등 배경이 개입하지 않는 수평적인 팀 분위기를 형성했습니다.
#
# 학교광장을 주제로 진행했습니다. 모든 생각은 열어두 되, 모든 팀원은 아이디어 제안 시, 논리적인 근거 혹은 예시 등 설득력 있는 자료를 제시하기로 합의했고, 이를 통해 전체적인 팀워크가 효율적으로 진행되었습니다. 최종적으로 `학교광장에 스트레스 해소를 위한 트램펄린 설치`라는 주제를 제출했습니다. 1차 아이디어 심사에서 `터무니없지만 참신하다`라는 평가를 받았지만, 2차 발표심사에서 회의를 통해 도출한 구체적인 사업계획을 설득력 있게 발표해 동상을 달성했습니다.아쉬운점 1
#
# 이처럼, 본부, 점주님들과 의사소통을 통해, 참신한 아이디어 통한 경쟁력 있는 영업관리를 수행하겠습니다.                        글자수 620자1,054Byte
# Q3 남들과 다른 새로운 관점으로 변화/혁신을 추구한 경험과 그를 통해 배운점이 무엇인지 기술하시오. A3 "답은 많은 곳에 있다"
#
# 영업문제에 다양한 관점으로 접근했고, 도전적인 변화로 재고 감소와 매출증대를 이룬 경험이 있습니다.
#
# 1년간 맥주 바에서 근무하면서, 매니저 업무를 수행했습니다. 대중적인 맥주와 달리 생소한 맥주의 재고가 남아있는 문제를 인식했습니다. 사장님은 해결책으로 재고품을 서비스로 제공하자고 하셨지만, 주종 특성상 큰 효과가 없다고 생각했습니다. 문제의 원인을 분석하며, '생소하다'가 가장 큰 원인으로 판단했습니다. 또한, 고객 특성상, 신규고객들은 냉장고에 디스플레이 되어 있는 맥주를 보고 구매선택을 하는 비율이 높다는 것을 알게 되었습니다. 그래서 재고가 많이 남은 맥주를 잘 보이는 곳에 배치했으며, 기존 인기제품은 뒤쪽에 배치하더라도 주문비율이 꾸준히 높았습니다.
#
# 실제로, 잘 보이는 맥주를 보고 맛에 대한 질문이 많아졌고, 주문율 역시 높아졌습니다. 또한, 냉장고에 맥주를 다 채우지 않고 절반씩만 채웠을 때, 주문 수가 비교적 높았습니다. 이러한 변화를 통해 창고에 남아있던 맥주 재고수를 30% 이상 줄이고 매출액에도 이바지할 수 있었습니다. 아쉬운점 1이를 통해, 문제에 대해 다양한 관점으로 접근하는 방법과 그 중요성에 대해 배울 수 있었습니다.                        글자수 613자1,044Byte
# Q4 평소 CU 편의점 이용 시 느꼈던 장단점을 기술하고, CU 편의점 경쟁력을 제고할 수 있는 아이디어를 제시하시오. A4 "속이 훤히 들여다보인다"
#
# CU 편의점은 투명한 통유리와 밝은 조명으로 내부가 잘 들여다보이는 실내장식이며, 매대가 낮아 안쪽의 상품까지도 다채롭게 보이는 점이 장점이라고 생각합니다.
#
# CU 편의점의 장단점을 알아보기 위해, 수원 만석공원을 기점으로 열 군데의 CU 편의점과 G사 편의점을 방문했습니다. 결품, 집기, 상품군 등 다양한 관점으로 비교, 분석하며 방문했지만, 점포별로 차이가 있을 뿐, 장단점을 찾기 어려웠습니다. 하지만 방문하며 느낀 점은 경쟁사 편의점과 비교하면, CU는 내부가 잘 보이는 구조로 발길을 끈다는 점이었습니다. 가장 큰 이유가 매대와 상품진열 높이라고 생각합니다. 경쟁사의 경우 매대 높이가 제 머리에서 이마까지 위치했고 상품 진열은 머리 위까지 진열되었지만, CU 편의점의 경우 매대 높이가 어깨, 상품은 머리 정도에 위치했습니다. 방문한 곳 중 수원만석점, 수원메디프라점은 상대적으로 높았지만, 경쟁사와 비슷한 수준이었습니다. 낮은 매대는 밖에서도 모든 상품이 잘 보이는 장점과 다양한 이용층에 편리성을 준다는 점에서 장점이라고 생각했습니다.아쉬운점 1
#
# 단점은 CU의 충성고객으로서 홍보가 아쉽다고 생각합니다. CU는 편의점 업계 최초로 전용 멤버십, 캐릭터 사업 등을 유치했으며, 편의점 이용 시 편리성을 주는 포켓 CU 앱을 개발했습니다. CVS 산업 특성상, 고객접근 면에서 진입장벽이 낮아 충성고객을 유치하기 힘들지만, 전용 멤버십, 편리한 앱, 캐릭터 상품은 충성고객을 유치하기에 좋은 수단이라고 생각합니다. 아쉬운점 2편의점 산업 역시 CLV를 높여 경쟁력을 제고해야 하며, 그 방법으로 홍보전략을 구체화하는 노력이 필요하다고 생각합니다.                        글자수 829자1,408Byte
#
#
#
#
#
#
# Q1 본인이 선택한 직무를 담당하고 싶은 이유, 적합성 등에 대해 자유롭게 설명해 보십시오.(학업, 인턴 등 경험한 내용을 중심으로) A1 16살에 처음 회계를 접하고 흥미를 느껴 뚜렷한 진로 방향을 형성했습니다.
# 기초회계 이론부터 꼼꼼히 배워서 그 결과 전산회계 1급, FAT 1급, 전산회계운용사 2급 등 전문 자격증들을 취득하였습니다. 자격증뿐만 아니라 각종 회계, 세무 대회에도 출전하였습니다. 사단법인 한국OOOOOO가 주최한 OOOOOO OOO 대회에서 2016년 7월 회계 관리 부문 장려상, 2017년 7월 세무회계 부문 국회의원상을 받는 좋은 결과를 얻었습니다. 또한, 2016년 11월 교내 글로벌비즈니스 경진대회에서 컴퓨터활용능력 부문 은상(2위)을 차지하며 컴퓨터활용능력도 높여갔습니다. 회계에 대한 확신은 좋은 결과로 돌아왔습니다.
#
# 더 전문성을 갖추기 위해 교내 전공동아리인 ‘세무동아리’에 입단하여 부원들과 방과 후에 매일 늦은 시간까지 회계, 세무 지식을 늘려갔습니다. 상업 고등학교에 다니며 원가 회계, 상업경제, 금융 일반, 사무관리실무, 회계 원리, 회계실무, 세무 실무, 회계 정보처리시스템, 증권 거래 업무, 창구 사무, 기업 자원 통합 관리 등 회계와 금융경제 과목을 수강했고 성취도 또한 A와 B를 받을 만큼 우수했습니다. 전공지식을 더 쌓고자 대학교 세무회계과에 진학하여 심화한 회계 배웠습니다. 2년 동안 회계 원리, 전산회계, 전산세무 회계, 세법 개론, ERP 회계실무는 A+를 놓친 적이 없고, 법인세신고 실무, 중학 소득세신고 실무, 부가세신고 실무도 모두 A 학점을 취득했습니다. 제가 준비해 온 것들이 SIMPAC 재무회계 직종의 주요 직무들과 적합하다고 생각하여 지원하게 되었습니다. 오랜 시간 단단하게 쌓아온 전문지식으로 SIMPAC에 입사해 실무 전문가로서의 역량을 키우겠습니다. 좋은점 1 글자수 845자1,401Byte
# Q2 SIMPAC을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.(추상적인 내용을 지양하고 구체적인 방법 및 계획을 제시할 것) A2 첫째, 인재상과 적합함을 확신하였습니다. 총학생회, 동아리, 등 분야를 가리지 않고 사람을 모으고, 사람이 있는 곳을 찾아다녔습니다. 열린 마음과 진심으로 소통한 결과, 주변에서는 제게 세무회계과 학회장이라는 리더의 역할을 맡겨주었습니다. 리더로서, 기본 교칙과 질서를 중요시하며 학과를 이끌었으며 내/외부적 이해관계와 갈등, 또한 코로나 세대로 이전까지 겪어보지 못한 학교와 학우들 사이에서 일어나는 여러 문제를 경험했습니다. 모든 과목 비대면 강의로 진행되는 탓에 등록금 반환에 대한 학우들의 원성이 쏟아져나왔고 이러한 문제들을 총학생회에서는 각 학과를 대표해 학교에 적극적인 건의를 하였습니다. 그 결과 등록금 전액 반환은 어려웠지만, 200,000원 감면이라는 결과를 얻어냈습니다. 학생회 생활로 다져온 화합을 이끄는 소통과 긍정적인 사고, 끊임없는 도전정신은 SIMPAC의 인재상과 적합함을 확신해 SIMPAC을 선택하였습니다.아쉬운점 1
#
# 둘째, 안정성과 진취성을 겸비한 회사에서 회사와 함께 성장해 가고 싶기 때문입니다. 저는 오늘보다 내일 더 발전하는 사람이 되고 싶습니다. 재무제표 분석 결과 마음 놓고 역량을 펼칠 수 있는 안정성을 가지고 있다고 판단하였습니다. 아쉬운점 2
# 입사 후 1년은 SIMPAC을 이해하고 적응하도록 최선을 다하겠습니다.
# 입사 후 5년 동안은 발전을 위해 실무에 대한 감각과 기술을 함양하는데 부단한 노력과 시간을 쏟는 등 능력을 인정받도록 일하겠습니다. 또한 재무 관련 포럼과 강연에 참여하고 10년 안에 CTA 자격증을 취득하고 최고의 재무·회계 전문가가 되어, SIMPAC의 재무적 건전성과 자금관리의 효율성을 책임지겠습니다. 아쉬운점 3 글자수 821자1,391Byte
# Q3 본인의 성장과정을 간략히 기술하되, 가장 힘들었던 시기와, 사유, 그 시기를 극복하기 위해 어떠한 노력을 기울였는지 기술해 주십시오. A3 학창시절 생활기록부에 ‘사교성’, ‘대인관계 원만’, ‘긍정적’, ‘활발’ 등 이러한 키워드가 빠진 적이 없을 만큼 사람을 좋아해 어딜 가도 적응이 빠르고 좋은 대인관계를 위해 노력했습니다. 여러 사람과 부딫히며 갈등을 해결하는 법도 배우고 열린 사고도 상대방을 이해하는 법을 배웠습니다. 이런 제가 살아오면서 가장 힘들었던 일은 9살에 미세하게 시작되어 성장하면서 점점 눈에 띄게 걸음걸이에 문제가 생겼었습니다. 모든 일에 적극적이고 활동적이었던 저는 고등학생 시절 저의 신체적 문제로 더 이상 학생회 활동을 할 수 없음을 자각했고 여태까지 큰 자부심을 느끼던 활동이라 더욱 박탈감을 느꼈었습니다. 그뿐만 아니라 신체의 문제 때문에 저의 꿈들을 포기해야 한다는 게 절망스러웠습니다. 좋은점 1
#
# 저는 극복하고자 항상 긍정적인 사고로 생각하며 살아가는 중에 ‘지선아 사랑해’라는 책을 읽게 되었고, 그 책의 주인공은 사고로 삶을 송두리째 빼앗긴 사람이었습니다. 그렇지만 그녀의 긍정적인 사고는 고난을 축복으로 만들었습니다. 저는 이 책을 읽고 주인공의 아픔에 너무나도 공감하고 긍정적인 사고를 배우려 노력했습니다. 그 결과 아픔 속에서 강인한 정신과 긍정적인 사고를 얻었습니다. 걸음걸이를 고치기 위해 부모님과 10년 동안 대학병원들에 다니며 각종 검사와 재활 치료를 받았습니다. 포기하지 않고 걸을 걸이를 고치겠단 의지 하나로 피나는 노력을 한 결과 완치 가능한 약을 찾았고 다른 사람과 다를 게 없는 다리를 가지게 되었습니다. 10년 동안 너무도 힘들었지만, 저의 꿈을 포기할 수 없었고 그 결과 누구보다 단단한 정신과 몸을 얻게되었습니다. 성인이 되어서 만난 지인들은 ‘그런 아픔이 있는 줄 꿈에도 몰랐을 만큼 밝은 사람이다‘ 라고 합니다. 저는 이런 말을 들을 때 버텨온 자신이 뿌듯하고 무엇도 할 수 있는 사람이 된 것 같습니다. 이런 저의 성장 과정을 바탕으로 SIMPAC에 입사해서 누구보다 강인하고 끈기 있으며 긍정적인 저의 모습을 보여드리겠습니다.좋은점 2 글자수 984자1,697Byte
# Q4 최근 사회이슈 중 중요하다고 생각되는 사항을 한가지 선택하고 이에 관한 자신의 견해를 기술해 주시기 바랍니다. A4 우리 사회에 물들어 있는 부패를 척결하고자 김영란법이 시행되었고 크고 작은 논란이 있었습니다. 김영란법은 부정 청탁과 금품 등의 수수 금지에 관한 법률입니다. 이 법안이 시행됨으로써 몇몇 업종에서 매출 감소가 발생하여 이미 좋지 않은 경제에 기름을 붓는 격이라고 하며 반대 의견이 많았습니다. 한국OOOOOOOOOO는 “역대 최장 장마에 코로나 19로 농,축산물 소비마저 위축돼 이중고를 겪고 있다”라고 호소했습니다.
#
# 지난해 추석에는 농축산물 선물 한도를 20만 원으로 상향했더니 매출 7%가 증가하였습니다. 이렇듯 선물 가액을 상향한 효과는 과거에도 입증된 바가 있습니다. 지난 추석 당일 코로나 확진자 수는 63명에 불과했습니다. 지난 추석보다 올해 설 코로나 19 상황이 더욱 심각하다는 점으로 미루어보아 이번 설 농업계의 피해가 막대할 것으로 짐작됩니다. 따라서 저는 농·축산물 선물 가액 완화에 찬성합니다. 이에 따라 각 기업의 재무업무 담당자들은 이 기준을 확실히 인지하고 관련해서 발생할 수 있는 문제를 사전에 차단해야 한다고 생각합니다. 실제로 현업에서 비용 담당자들이 가끔 해당 법의 비용집행 가이드라인을 잘 인지하지 못한 채 전표가 올라와 반려 후 집행 가이드라인을 재전달하고 해당 기준 한도로 맞추어 재상신 요청했다던 사례들을 봤습니다. 재무 담당자들은 이러한 부분을 확실히 인지하여 자사에서 법을 어기는 불미스러운 일이 발생하지 않도록 유념해야 합니다. 김영란법은 장기적인 관점에서 본다면 우리 사회에 뿌리 박혀 있는 부정부패를 방지할 수 있는 법안이며, 깨끗한 사회로의 첫 발걸음이라고 생각합니다. 우리 국민 모두가 자기 자리에서 법의 취지에 맞는 올바른 행동을 통해 우리 사회에서 부패가 척결되기를 희망하지만 코로나 19와 같은 세계적인 경제 비상사태에 국가 경제를 위해 부정청탁금지법상 10만 원으로 정해진 농,축산물 선물 가액을 한시적으로 완화하는 것에 찬성합니다.좋은점 1 글자수 952자1,637Byte
#
#
#
#
#
#
# Q1 한국항공우주산업(주)에 관해 알고 있는 주요 내용(사업, 업무, 제도)은 무엇이며 당사를 선택한 이유에 대해 기술해주시기 바랍니다. (최소 500자, 최대 800자 입력가능) A1 먼저 한국항공우주산업(이하 KAI)에 특별한 관심을 가지게 된 이유는 2019 OOOOOOOOO에서 KAI 사의 부스를 접하고 난 뒤였습니다. 저는 위 대회에서 "국방과학기술을 활용한 창업경진대회"에 팀장으로 참여해 151개 팀 중 6위로 입상한 경험이 있습니다. 창업경진대회 부스를 운용하면서 잠시 쉬는 시간 짬을 내어 KAI 사의 한국형 전투기 사업과 소형무장 헬기를 보면서 기계공학도로서, 또 국방과학기술을 활용해 창업을 준비하는 입장으로서, 방위산업의 한 축을 담당하는 KAI에 입사해 저의 능력을 펼치는 꿈을 꾸었고 이렇게 기회가 찾아오게 되었습니다.
# 좋은점 1
# 웅장한 부스를 자랑하는 KAI 사에 관심이 생겨 대회 중간중간 검색을 통해 정보를 찾았습니다. 군용기 중심의 방산 및 완제기 수출의 방위산업만 담당하는 것이 아니라, 민항기의 양산과 기체 부품, 정비 및 개조를 담당하는 민항기 운용의 MRO 사업과 성능개량사업 또한 있음을 알게 되었습니다. 추가로, 비행 방식에 따라 고정익(일반적인 비행기), 회전익(헬기 등) 항공기 등으로 구분을 해놓았고 무인항공기 사업분야를 따로 정립한 것을 보아 확실히 무인항공기 사업이 미래 먹거리가 될 것임을 엿 볼 수 있었습니다.
#
# KAI에는 또 협력회사 교육지원제도가 있는 것을 보았습니다. 협력회사들에게 맞춤형 교육과 전문기술 인력 양성을 위한 제도로써, 산업의 파이가 중요한  항공우주산업 업계의 특성을 잘 활용한 제도라고 생각합니다. 심지어 작년 상반기에는 4억 원이 넘는 포상금을 주는 등, KAI 사의 사업 이념은 올바르게 가고 있다고 생각합니다.좋은점 2 글자수 789자1,324Byte
# Q2 KAI인재상을 바탕으로 자신만의 경쟁력을 구체적인 사례(최근 5년 이내)를 통해 기술해주시기 바랍니다. (최소 500자, 최대 800자 입력가능) A2 KAI의 인재상인 창조, 도전, 협동 3가지 역량을 모두 갖추도록 큰 거름이 되어준 "국방과학기술을 활용한 창업경진대회" 사례를 말하고 싶습니다.
#
# 특히 저의 사업아이템은 창조와 도전을 나타내는 미래기술을 활용한 ICT 웨어러블 기기로써, 화생방전에 쓰이는 국방기술을 활용해 추락, 충돌과 더불어 민간의 3대 안전사고인 "질식" 사고를 막고자 개발한 아이템입니다. 현재 시장에 나온 질식사고 예방 기기와 가장 큰 차이점은 내부 작업자가 "웨어러블 형태"의 기기를 착용하고 실시간으로 생체신호와 유해가스 농도를 "동시에" 측정하여 외부의 작업자에게 보내는 "하나의 시스템"이라는 점입니다.
#
# 단순한 아이디어 대회가 아닌 창업을 목표로 하는 대회니 만큼, 사업계획서 작성과 비즈니스 모델 구축에 심혈을 기울였습니다. 평소 안전하고 더불어 사는 세상을 추구하던 아이템을 만들고 싶었던 저는, 처음 설계를 기획할 때부터 안전사고 예방이라는 사회적 공공의 가치를 실현하는 아이템으로 컨셉을 잡았습니다. B2G 모델을 기본 베이스로 깔았고, 안전보건공단의 2019년도 사업 보고서를 참고하여 나라장터에서 어떤 분야의 사업을 따낼지 구체화했습니다. 또한 기술보증기금, 방위사업청 주관의 교육을 수강하면서 사업의 트렌드를 읽는 방법과 고객이 원하는, 시장에서 정말 팔릴 수 있는 이론을 배웠습니다.
#
# 위 사례를 통해 지금도 새로운 기술을 활용해 혁신하고 도전하며, 더불어 살아가는 아이템을 만드는 것이 저의 사명이라 생각합니다.    아쉬운점 1 글자수 745자1,273Byte
# Q3 직무와 관련하여 직무역량을 키우기 위해 꾸준히 노력한 경험(최근 5년 이내)에 대해 기술바랍니다. (최소 500자, 최대 800자 입력가능) A3 저는 1년여간의 의공학 연구실에서의 학부 연구생 생활과 연구소 인턴 경험을 통해 특히 웨어러블 기기의 SW 시스템 설계를 주로 했습니다. 당연히 기계공학도로서 SW 중심의 시스템 설계가 쉬운 일이 아니었습니다. 하지만 제가 정말 하고 싶은 일이었고, 미래 먹거리는 데이터를 분석하는 SW 시스템이 될 것이기를 알았기에 다음과 같은 노력을 꾸준히 했습니다.
#
# 먼저 친해지기 위해 노력했습니다.
# 학부 과정상 기껏 배우는 SW는 Matlab과 C언어의 기초일 뿐이고 그 역시 단순한 식과 숫자계산입니다. 저는 그 너머의 한 단계 도약하고 싶은 마음에 의공학 연구실에 직접 찾아가 따로 시험공부까지 준비했고, 그렇게 학부 연구생 생활을 시작했습니다. 교수님께 따로 SW 프로그램을 배우며 생체신호 데이터를 분석하고 정리하며 박사과정 학생을 보조하며 수많은 연구에 참여했습니다.
#
# 지치고 게을러질 때 쯤, 꾸준한 노력을 지속하고자 도전을 했습니다.
# OOOOOOOOO에서 열리는 딥러닝 SW 교육, OOOOO 딥러닝 교육, OO(한국OOOOOOOOO) LabView DAQ 시스템 실습세미나, 미래형 커넥티드 카 전문가 교육과정 참여 등을 통해 아직도 부족한 저를 채찍질하며 다양한 SW를 다루기 위해 학기 중에 부산, 서울, 여수, 경기도 곳곳을 누비며 다녔습니다.
#
# 위와 같은 노력을 바탕으로 1편의 논문등재와 함께 웨어러블 기기 설계로 창업까지 준비하는 전문가가 되어있었고, 항상 꾸준히 노력하는 방법을 터득해 처음 보는 분야에서도 금방 따라잡을 수 있는 힘을 기를 수 있었습니다.아쉬운점 1 글자수 779자1,289Byte
# Q4 항공기개발, 생산, 운영 또는 항공산업 발전을 위해 가장 중요하게 생각하는 것은 무엇이며, 그 이유에 대해 작성해주시기 바랍니다. (최소 500자, 최대 800자 입력가능) A4 먼저 프리미엄 브랜드 세계 1위인 독일계 글로벌 자동차 Technical Team에서 인턴을 하면서 느꼈던 저의 개인적인 생각을 통해 위 문항의 답을 드리고 싶습니다.
#
# 제가 몸담은 B사는 비록 자동차 회사이지만, 항공 산업과 비슷한 제조업 기반의 고부가가치 산업에서 1위를 유지할 수 있는 비결은 무엇일까 생각해보았습니다. 시장을 선점할 정도의 압도적인 기술력, 가격을 낮춘 이익 창출 극대화, 천문학적인 마케팅 투자 비용은 분명 아니었습니다. 제가 생각한 답은 고객들이 신뢰할 수 있는 위험요인 제거와 안전성이라 생각합니다. Customer Service A/S 관련 지수를 보면 B사는 국내에서는 수입차 부문 6년 연속, 세계에서는 4년 연속 수상한 이력이 있습니다.
# 아쉬운점 1
# 이를 항공산업 업계로 들어와 KAI를 통해 바라본다면, 어떻게 적용할 수 있을지 보았습니다. 고객이 느낄 때 KAI의 제품이 안전하다는 신뢰를 주어야 하고, 진단기로 잡을 수 없는 고장 유형과 위험요소를 적극적으로 사전에 파악함으로써 그 신뢰를 완성할 수 있다고 생각합니다. 그리고 그 일을 제가 지원한 체계분석팀에서 수행하고 있음을 알았습니다.
# 원인 모를 소음, 진동, 심적으로 불쾌한 어떤 것들이 느껴지고 사고 위협에 대비를 잘하고 있는지 의심을 하기 시작하면 고객은 불안함을 느낄 것입니다. 고장 유형, 위험요소 식별에 소극적이라면 아무리 뛰어난 제품을 만들더라도 고객은 두 번 다시 KAI의 제품을 구매하지 않을 것입니다.
#
# 고객의 입장에서 생각한 안전성 확보와 신뢰야말로 1위로 향해 갈 수 있는 지름길이라 생각합니다.아쉬운점 2 글자수 794자1,325Byte
# Q5 직무중심 경력개발계획 및 성장경로를 기술바랍니다. (최소 500자, 최대 800자 입력가능) A5 수습 기간 3개월 동안은 항공산업과 친해질 것입니다.
# 자기소개서 3번 문항에서 말했듯이, 대학교 3학년 때 기계공학부에서는 배울 수 없었던 다양한 SW 역량을 기르기 위해 의공학 연구실의 문을 두드린 것처럼, 저보다 선배이자 항공산업 전문가들이신 KAI의 직원분들에게 먼저 다가가겠습니다. 처음 접하는 항공기 체계 분석에 쓰이는 분석 기술과 빨리 친해지기 위해 이번에는 직원분들의 노하우를 열어 볼 수 있는 가슴 속의 문을 두드리겠습니다.  아쉬운점 1
#
# 수습 기간 3개월 후, 입사 2년 차 까지는 기존의 고장유형과 위험도 분석을 한 데이터들을 직원분들과 협력업체 분들이 쉽게 볼 수 있도록 인터페이스를 개선하는 일 등, 새로 우물을 찾아 파는 것 보다는 고여있던 물을 흐르도록 도와주는 일을 하고 싶습니다. 그렇게 자료를 정리하고 기존의 것들을 정리하면서 고장 유형과 위험도 분석을 빠르게 파악할 것입니다.아쉬운점 2
# 입사 3년 차 이후부터는 본격적으로 새로운 우물을 찾는 일을 진행하고 싶습니다. 관심이 가는 영역이 인적/건강 위험요소 식별과 위험도 수준 평가, 체계안전 프로그램 수립/수행 등이 있습니다. 먼저 인적/건강 위험요소는 사람이 직접 느끼는 것을 객관화시키는 것이므로 생체공학을 공부한 저에게 있어서 다소 유리한 분야라는 생각이 듭니다. 그리고 체계안전 프로그램 수립/수행은 체계분석팀의 가장 기본적인 업무로써 늘 혁신해야 하고 발전시켜야 할 부분이기에 그동안 제가 쌓아온 노하우를 이용해 실적을 크게 개선해보고 싶은 욕심이 듭니다.아쉬운점 3
#
# 꼭 위 계획을 이룰 수 있도록 작은 기회라도 주셨으면 정말 감사하겠습니다.                        글자수 793자1,359Byte
#
#
#
#
#
# Q1 성장과정:가족사항, 학창시절, 교우관계, 생활습관, 자신에게 크게 영향을 미친 사건 등을 포함하여 구체적으로 작성 A1 저희 가족은 회사원이신 아버지와 어머니 그리고 누나와 저 4인 가족입니다.좋은점 1
# 학창 시절 독서에 관심을 갖고 폭넓은 분야의 책을 지속적으로 읽었으며, 특히 위인전과 고전 소설, 동서양 철학 등 인문 고전을 탐독했습니다. 덕분에 다양한 인간상에 대한 이해와 공감 능력, 그리고 뛰어난 이성과 논리를 습득하는 한편, 인문학적 소양을 쌓으며 위인을 본받으려는 마음가짐을 다지게 되었습니다.
#
# 이런 특성으로 인해 독서를 좋아하며 바람직한 도덕 관념과 겸손함을 갖춘 친구들과 주로 교우관계를 맺었으며, 성실하고 청렴하신 부모님을 본받아 아침 일찍 등교하고 야간 자율 학습 후 하교하는 성실한 생활 습관을 바탕으로 공부에 임했습니다.
# 이지성 작가의 ‘꿈꾸는 다락방’을 읽으며 범인도 큰 꿈을 가짐으로써 위인으로 거듭나고 결국 그 꿈을 이룰 수 있다는 것을 깨달았고, 이것이 저에게 크게 영향을 미쳐 더 나은 사회를 위한 삶을 살고자 하는 평생의 꿈을 품게 되었습니다.
# 좋은점 2 글자수 483자830Byte
# Q2 실패했던 경험이나 크게 좌절했던 경험과 극복사례는? A2 AI 연구 기관 OOOOO 인턴쉽 과정에서 할당 받은 데이터 분석 업무 달성에 대해 초기에 부족한 실력으로 인해 크게 좌절했으나 결국 전략적으로 역량을 쌓아 인턴 중 최고 성과를 달성하며 극복해낸 사례가 있습니다.
# 인턴 중 가장 부족한 데이터 분석 역량을 갖고 있던 저는 7개의 kaggle competition에서 일정한 예측 정확도 산출을 할당 받았으나, 자발적으로 더 큰 목표에 도전하여, 업무 단계별 초과달성을 통해 체계적으로 역량을 성장시키는 전략을 실천했습니다. 그 결과 최고 성과를 내어 인센티브와 정규직 제의를 받았습니다.좋은점 1 글자수 303자501Byte
# Q3 증권업을 선택하게된 이유와 증권사 중 당사를 선택한 이유 A3 증권업은 데이터 기반의 전략과 통찰로 고객의 안정적인 경제적 삶을 보장해주기에 금융인이 되길 희망하며 경영학을 전공했습니다. IT직무로 진로를 결정하면서 증권업에서 데이터 분석과 AI를 기반으로 고객 일상과 하나된 고객 친화적인 비즈니스 디지털 플랫폼을 만드는 꿈을 키워왔습니다.
# 한국투자증권은 저의 경영 도메인 기반 빅데이터 분석 및 AI 구현 역량과 SW 앱 개발 역량을 통해 당사의 한국투자와 미니스탁과 뱅키스 핀테크 서비스와 온라인 금융 상품권과 인공지능 리서치 AI 에어 서비스 개선에 기여할 수 있기에 지원했습니다좋은점 1
#  글자수 296자509Byte
# Q4 지원한 분야는 어떤 일을 한다고 생각하는가? A4 IT본부 내 트레이딩개발부와 BIZ개발부에 지원하고 있으며, 이 부서들은 매매 업무와 모바일 앱 개발, 그리고 증권 업무의 front부터 back office까지의 개발을 담당합니다.
# 이를 통해 기업 내 증권 업무를 담당하는 영업, 관리 부서의 내부 시스템 구축 및 SW 서비스를 제공하며, 고객의 금융 업무의 편의성을 증진시키기 위한 핀테크 앱을 개발합니다.좋은점 1
#  글자수 204자331Byte
# Q5 지원분야에 본인이 적합한 이유를 증명하시오. A5 저는 경영 IT 융합형 인재로서, 클라이언트와 비즈니스 이해를 기반으로 한국투자증권의 핀테크 서비스와 에어 AI 서비스를 고객 비즈니스 니즈 충족에 최적화된 비즈니스 SW 솔루션으로 개선시킬 수 있기에 한국투자증권의 IT 직무에 적합한 인재입니다.
# 경영학과와 컴퓨터 공학을 전공한 후, AI 연구기관 OOOOO 인턴 업무에서 실제 경영 빅데이터를 분석하여 최적의 솔루션을 도출했으며, AutoML을 위한 Meta feature extraction 기술 연구 조사를 통해 MFE, AutoML 구현 논문을 KCI 학회 발표 준비 중입니다. 또한 OOO 캡스톤 프로젝트, OOO SW 공모전에서 웹 풀스택 개발을 수행했으며, 그 중 OOO SW 공모전에서는 우수상을 수상했습니다.
#
# OOOOO 연계 산업체 프로젝트와 소프트웨어 장학생으로 파견된 OOOO OOO에서의 App Dev, 캡스톤 프로젝트에서 안드로이드 앱을 개발했고, OOOO에서 A등급을 받았습니다.좋은점 1 글자수 485자760Byte
# Q6 당신의 인생계획(Life Plan)에서 꿈은 무엇이고, 그 꿈을 이루기 위해 회사가 어떻게 도움을 줄 수 있는지 서술하시오. A6 저는 경영과 SW를 융합한 디지털 금융 혁신으로 고객 니즈에 최적화된 비즈니스 디지털 플랫폼을 창출하여 고객의 삶의 질을 높이고 더 발전된, 행복한 사회를 만들어가는 꿈을 갖고 있습니다. 한국투자증권은 카카오 등 빅테크 기업과의 연계와 혁신금융서비스로 효과적인 금융 디지털 전략과 핀테크 플랫폼 개발을 동시에 실천하고 있습니다. 이렇듯 DT를 통해 고객에게 기쁨을 주고 새로운 가치를 창조하는 한국투자증권의 현재의 도전에 동참하는 것은, 미래에 기업의 목표 달성과 함께 저의 꿈을 실현하는 데 도움이 될 것입니다.
#
# 저는 IT직무에서 핀테크 서비스를 고객 친화적으로 개선하고, 한국투자증권의 각 사업부문별 비즈니스 특성을 고려한 최적화된 전사적 시스템과 SW플랫폼, 그리고 전사적 데이터 거버넌스 시스템을 구축할 것입니다. 이는 지속적인 DT을 통해 기업의 글로벌 디지털 금융 선도에 기여하여 세계 사회의 발전과 삶의 질 향상에 기여할 수 있다는 점에서 저의 꿈 실현에 도움이 될 것입니다.좋은점 1 글자수 502자862Byte
#
#
#
#
# Q1 본인이 선택한 직무에 대해 아래 내용을 포함하여 기술하시오. ①지원한 직무의 역할이 무엇이라 생각하는지 자유롭게 기술 ②본인이 해당 직무에 적합하다는 근거를 본인의 경험을 바탕으로 기술 ③입사 후 경력개발 계획에 대해 기술 A1 "소통을 통한 점주와의 상생"
#
# SC 직무의 역할은 점주와의 동반사업자라고 생각합니다. 편의점 운영에 대한 조언뿐 아니라 점주와 본사의 징검다리가 되고, 점포의 환경개선활동, 매출, 상권, 고객 데이터 분석까지 점포의 활동에 관여하기 때문입니다. 그렇기에 점주와 조력자 사이 보다는 더 깊은 사업상 파트너로 생각합니다. 아쉬운점 1저는 관계구축에 좋은 사교성을 가지고 있습니다. 대학교 입학 후 총동아리연합회 홍보부장을 맡아 동아리 회장들과 소통을 주로 했습니다.
#
# 저의 업무는 연합회에서 행사를 진행하거나, 지원사업 등을 소개할 때 발표를 하고, 동아리 회장단과 소통을 통해 필요한 물품, 건의 사항을 종합하는 것이었습니다. 그중 동아리 지원사업을 할 때 동아리마다 고충을 파악하기 위해 각 동아리의 특성을 파악했습니다. 또한, 대화하면서 동아리 특성에 따른 대화 주제를 이끌어가며 깊은 유대를 형성하면서 동아리별 특징, 애로사항을 잘 알 수 있었습니다. 추후 SC 직무에 임했을 때, 특성을 파악하여 소통하는 능력을 통해 많은 점포의 점주와 편한 분위기를 조성하여 특성에 맞는 전략을 제시할 것입니다. 이를 통해 궁극적으로 점포의 매출향상을 이끌수 있는 인재가 되겠습니다.아쉬운점 2
#
# "역량을 살린 경력개발"
#
# SC 직무를 통해 점포관리에 대한 전반적인 것을 배운 후 점포설비 쪽으로 경력을 쌓고 싶습니다. 현장실습체험을 통해 Inventor를 사용하여 3D 스케치와 도면작업을 배운 경험이 있습니다. 당시 소형전자카트의 부품스케치, 시제품 제작 시 도면해석을 통한 조립을 주 업무로 했습니다. 이를 통해 도면분석에 대한 역량을 쌓았으며, 산업안전기사를 취득하였기에, 점포설비에 이러한 역량을 투자해 경력을 개발하고 싶습니다.아쉬운점 3 글자수 855자1,457Byte
# Q2 공동의 목표를 달성하기 위하여 가장 중요하다고 생각하는 역량 1가지를 선정하고, 그 이유와 해당 역량을 발휘하여 목표를 달성한 경험에 대해 구체적으로 기술하시오. A2 "분위기를 파악하는 역량"
#
# 목표를 달성하기 위해서는 '분위기를 파악하는 역량'이 중요하다고 생각합니다. 조직은 다양한 구성원이 하나가 되어야 목표를 달성할 수 있습니다. 이때 구성원의 감정, 피로도 등을 알지 못하고, 일관적인 태도로 대한다면 지친 구성원은 조직에 융화하지 못할 것입니다. 그렇기에 구성원들의 분위기를 살피고, 적절히 대응하여야 합니다.아쉬운점 1
#
# OOOOO 공모전에 출전한 경험이 있습니다. 저희 팀은 처음 나가는 공모전이기에 의욕이 충분했지만, 진행 중 감정싸움이 생기곤 했습니다. 이를 해결하기 위해 규칙을 만들었습니다. 누군가 힘들거나, 예민해 보일 경우, 다 같이 휴식하기로 했습니다. 거창한 규칙은 아니었지만, 서로의 상태를 파악하자는 취지였습니다. 규칙을 세우고 난 후부터 감정싸움이 없었습니다. 휴식 동안 대화하며, 감정을 푸는 재충전의 시간이 되었습니다. 그 후 1차 예선, 2차 PT를 거쳐 대상을 받았습니다. 이를 회상하면 팀원끼리 감정, 피로도 등을 파악한 것이 효율을 올렸다고 생각합니다. 입사 후 많은 사람을 만나게 될 것입니다. 그때 이러한 경험에서 배운 교훈을 통해 많은 사람을 만날 때 특징, 분위기에 맞춘 대응을 하여 매끄러운 업무활동을 하도록 노력하겠습니다.아쉬운점 2 글자수 623자1,058Byte
# Q3 남들과 다른 새로운 관점으로 변화/혁신을 추구한 경험과 그를 통해 배운점이 무엇인지 기술하시오. A3 "책임감을 가진 혁신 전략"
#
# 3학년 학생회 때 대학교 축제에서 부스를 운영했습니다. 저희과는 전통적으로 먹거리 부스를 하였지만, 이익이 크지 않았고, 적자를 볼 때도 있었습니다. 하지만 큰 적자가 아니라 생각하여 매년 해왔습니다. 저는 이를 반대하고 학생회비를 사용하기에 이익을 최대한 낼 수 있는 부스 운영을 제시하였습니다. 다른 과도 먹거리 부스 위주로 하였기에 저희과는 축제의 신나는 분위기를 이용하여 송파격파부스를 기획했습니다. 또한, 더운 여름에 물총을 판매하여, 신나는 분위기를 연출했습니다. 이러한 전략은 다른 부스에 비해 많은 손님을 데려왔습니다. 2일 동안 저희는 100만 원이 넘는 영업이익을 달성했고, 남은 수익은 과 학생을 위해 간식 사업을 진행하는 데 사용했습니다.좋은점 1
#
# 이는 처음으로 점포를 운영해본 경험입니다. 비록 짧은 기간이지만, 타인의 돈에 대한 책임감과 어떠한 방식을 이용해야 합리적인 전략을 세울 수 있는지 배웠습니다. 주변에 대한 조사를 통해 부족한 점을 파악한 후 부족한 점을 보완하고, 분위기를 이용할 수 있다면 우수한 전략을 만들 수 있습니다. 제가 SC 직무를 한다면, 이 경험을 살려 책임감과 우수한 전략을 통해 점포의 매출향상을 위해 노력하겠습니다.아쉬운점 1 글자수 619자1,056Byte
# Q4 평소 CU 편의점 이용 시 느꼈던 장단점을 기술하고, CU 편의점 경쟁력을 제고할 수 있는 아이디어를 제시하시오. A4 "CU 편의점 이용 시 장단점"
#
# CU 편의점은 타 사에 비해 많은 PB상품이 있습니다.  PB상품은 저렴한 가격과 우수한 맛으로 마니아층을 형성했습니다. 저도 저렴한 제품을 통해서 만족한 경험이 많습니다. 또한, PB상품의 다양한 종류는 맛보기에 합리적인 가격으로 많이 선택하였습니다. 또한, PB상품끼리 진열하는 방식도 소비자 입장에 이용하기에 편리했습니다. CU는 '편스토랑'과의 협업을 통해 조리과정을 보여줌으로써 신뢰성을 높이고, 제품홍보 효과를 극대화하였습니다, 저 또한 '마장면', '떡쭈빠빠오' 등의 제품을 호기심에 구매해본 경험이 있습니다. 이 2가지 부분이 CU 편의점을 이용하면서 장점이라 느낀 점입니다. 아쉬운점 1
#
# 아쉬운 부분도 있었습니다. 타 사에 비해 도시락, 김밥 류가 매력적이지 못했습니다. 그렇기에 이를 보완하여 도시락 등 식사류의 품질을 향상해 단점을 보완하면 좋을 것입니다.아쉬운점 2
#
# "CU 편의점 경쟁력 제고 전략"
#
# 편의점업계 시장규모가 커지면서 CU의 단점을 보완하기보다는 장점을 더 부각해 타 업계와의 차별점을 두는 것이 좋다고 생각합니다. CU 편의점은 타사 대비 맛좋고, 트렌디한 디저트가 많습니다. 마카롱이나 조각 케이크같이 유행에 알맞은 제품을 시기적절하고 맛있게 선보여, 꾸준한 사랑을 받고 있습니다. 이 점을 극대화해 소비자의 선호도 조사를 통해 CU만의 디저트를 꾸준히 개발하는 것이 타사와의 차별점을 두는 데 좋은 전략이라고 생각합니다. 또한, CU만의 고객층을 분석하는 소프트웨어를 개발하여 유통하는 것도 좋은 방법이라 생각합니다. 점주들도 이용하기 쉬운 고객분석서비스를 개발하여 유통/교육한다면 점주들은 주 고객층 분석에 따른 매장 내 진열 방식, 진열 구조를 바꾸어 더 많은 고객 유치를 할 수 있을 거로 생각합니다.아쉬운점 3 글자수 886자1,496Byte
#
#
#
#
#
#
# Q1 회사 지원동기 및 희망직무를 선택한 이유를 서술하시오. A1 "우리나라 경기를 이끄는 반도체 산업의 기초에서 일하고 싶습니다"
#
# 저는 기초산업에 매력을 느껴 컴퓨터응용기계설계를 전공했습니다. 회사에서 일할 때 눈에 보이는 성과를 내며 성취감을 가지는 저를 발견할 수 있었습니다. 기초를 다지는 업무에 흥미를 느꼈고 또 저의 도면으로 인해 계약할 수 있었다는 이야기를 전해 들었을 때 뿌듯함을 느꼈습니다. 아쉬운점 1반도체는 인공지능, 자율주행 자동차, 드론 등 4차 산업혁명의 기반기술을 구축하는 핵심부품입니다. 좋은점 1
#
# 실리콘 웨이퍼는 반도체 산업의 기초가 되는 중요한 부품입니다. 그리고 SK실트론은 반도체의 주재료인 실리콘 웨이퍼 시장에서 상위 회사 중 유일한 국내 회사이며 최고의 기술력을 바탕으로 국내뿐 아니라 해외에도 제품을 공급하고 있습니다. 저는 세계 최고 수준인 대한민국의 반도체 기초산업의 중심인 SK실트론에서 업무를 수행한다면 더욱 큰 성취감과 원동력을 가지고 역량을 발휘할 수 있을 것 같아 지원했습니다. 더 나아가 반도체의 기초인 실리콘 웨이퍼를 검사하여 고객사에 불량품이 전달되어 큰 문제로 발생하는 것을 방지하고 싶습니다. 아쉬운점 1
#
# "주도면밀한 태도로 검사 분야에서 제 역량을 발휘하고 싶습니다."
#
# 저는 이전 회사에서 실적 1등을 한 경험이 있습니다. 제가 맡은 업무는 엘리베이터 승인도를 작성하고 검토하는 일이었습니다. 엘리베이터 승인도는 실수가 곧 불량으로 이어지기 때문에 도면에 오류가 있어서는 안 됩니다. 저는 도면을 큰 부분부터 작은 부분까지 놓치지 않고 검토하였으며 한번이 아닌 두세 번 확인하였기 때문에 좋은 실적이 나올 수 있었습니다. 위의 경험으로 미루어 보았을 때 저의 역량은 사소한 것도 다시 살펴보는 꼼꼼함과 맡은 바 임무를 충실히 하는 책임감이라고 생각합니다. 다음과 같은 역량을 검사 분야에서 가장 잘 발휘할 수 있을 것 같아 검사 분야에 지원하게 되었습니다. 좋은점 2 글자수 925자1,590Byte
# Q2 본인이 지원한 직무의 전문가가 되기 위해 수행한 경험 및 경력을 구체적으로 서술하시오.(학교/외부교육 수강,동아리/대외활동,직무 관련 경력 등) A2 "설계를 통해 꼼꼼함을 증대하다."
#
# OOOOOOO설계과에 진학하여 치공구설계실습 과목을 수강했습니다. 수업시간에 공작물을 기준으로 하여 2D와 3D의 밀링고정구와 드릴지그 조립도를 작성했습니다. 이를 통해 합리적이고 경제적인 설계를 해야 하는 것을 배웠습니다. 또 도면을 작성하면서 치수 및 형상파악을 위하여 꼼꼼하게 도면을 살피고 올바른 투상을 하였는지 재확인하는 과정을 거쳤습니다. 저의 관심과 노력은 치공구설계산업기사를 취득하는 결과를 가져왔습니다. 그리고 학교에서 배운 것을 바탕으로 회사에서 엘리베이터 승인도를 작성할 때도 설계자가 편한 설계가 아닌 고객이 편리한 설계, 또 경제적인 설계를 할 수 있었습니다. 이러한 설계를 할 수 있었던 이유는 꼼꼼하게 도면을 살피고 현재 주어진 상황을 살피는 능력이 있었다고 생각합니다.아쉬운점 1
#
# "창의적인 사고로 업무환경을 발전시키겠습니다."
#
# ‘제16회 대한민국 OOOOOOO 아이디어 경진대회’에서 동상을 받은 경험이 있습니다. 학기 초부터 교수님은 창의적인 아이디어에 관심이 많으셨고 저희에게도 창의적인 아이디어의 중요성을 수업시간에 일깨워주셨습니다. 그래서 저는 학교에서 많이 접하는 기계 분야에서 절삭유에 대해 생각했습니다. 절삭유가 부패하는 원인 중 미세칩 문제를 해결하기 위하여 번뜩이는 아이디어로 친환경적인 미세칩 방지장치를 발명했습니다. 이를 통해 수상하는 쾌거까지 얻을 수 있었습니다. 저는 기존의 관점과는 다른 생각을 하기 위해 평소에 작은 것도 그냥 넘어가지 않고 깊이 생각해보는 습관이 생겼습니다. 저의 창의적인 생각과 몰입하는 습관은 업무에서 불편함을 개선하거나 기존의 것을 더 효과적으로 수행할 수 있도록 하여 기업문화 발전에 도모할 수 있습니다.
# 아쉬운점 2
# 저의 이러한 경험들이 검사 직무에 도움이 될 것으로 생각합니다. 작은 것도 놓치지 않는 꼼꼼함, 업무환경을 개선할 수 있는 창의력을 바탕으로 SK 실트론에서 제 역량을 발휘하여 현실에 안주하지 않고 패기 있게 도전하여 회사와 같이 성장하는 사원이 되겠습니다.                         글자수 1,008자1,738Byte
# Q3 본인의 한계를 뛰어넘어 도전했던 경험과 이를 SK실트론 및 지원직무에 활용할 수 있는 방안을 서술하시오 A3 "부단한 노력을 통해 적극적인 성향으로 변화된 나"
#
# 학창시절 저는 남들 앞에 서서 발표하는 것을 두려워했습니다. 소극적인 성향으로 주목받는 것을 꺼리는 동시에 친구들 앞에서 큰 목소리로 발표를 잘하는 친구를 볼 때면 부럽기도 했습니다, 한 친구가 저에게 목소리가 작고 무엇을 말하는지 잘 들리지 않는다고 했을 때 저는 큰 충격을 받았습니다. 이러한 성향을 바꾸고자 시낭송 대회에 참가하였습니다. 시를 암기하여 대회에서 시를 낭송하였지만 여전히 다리가 떨리고 목소리는 크게 나오지 않았습니다. 그래서 결과가 좋지 않았고, 참가한 것에 의의를 두기로 했습니다.
#
# 저는 자괴감이 들었지만, 어머니의 격려로 웅변대회를 준비하게 되었습니다. 웅변학원에 다니면서 큰 목소리와 또박또박한 발음 그리고 의지에 가득 찬 눈빛을 배웠습니다. 스스로 음성 녹음을 통해 웅변 연설문을 암기하였고 발음 교정을 하였습니다. 또한, 동영상을 촬영하여 저의 태도와 표정을 교정할 수 있었습니다. 매일매일 연습하여 초반보다 훨씬 나아진 저를 볼 수 있었습니다.좋은점 1 웅변대회 날 떨리지만 다시 지난번과 같은 실수를 하지 말자며 마음을 다잡아서 무대에 올랐습니다. 연설문을 중반쯤 읽었을 때 뒷부분이 생각이 안 나서 낭독 중 멈췄고 관객들은 괜찮다며 박수를 보냈습니다. 저는 심호흡을 크게 한 뒤 마음을 다시 잡아 웅변을 마무리할 수 있었습니다. 실수는 했지만 끝까지 마무리한 덕분에 인기상을 받을 수 있었습니다. 그리고 학교에서도 발표할 때 이전보다 훨씬 나은 태도로 친구들 눈을 마주하며 발표를 할 수 있게 되었습니다. 또한, 친구들이 저에게 더 많이 다가옴을 알 수 있었습니다.
# 아쉬운점 1
# 이러한 경험은 저에게 자신감을 가지게 해주었으며 한계가 오더라도 그 한계를 뛰어넘을 힘이 될 것입니다. 그리고 항상 당당한 모습으로 업무에 임하여 주위 사람에게도 좋은 영향을 끼칠 수 있을 것이라 생각이 듭니다. 또한, 넘어져도 다시 딛고 일어날 수 있는 원동력이 되어 업무를 할 때 적극적인 자세로 도전하고 눈에 보이는 변화를 가져오는 사원이 되겠습니다.아쉬운점 2 글자수 1,020자1,754Byte
# Q4 팀의 성과를 달성하기 위해 협력한 경험과 이를 SK실트론 및 지원직무에 활용할 수 있는 방안을 서술하시오. A4 "혼자가 아닌, 협력에 의해 얻어낸 성과"
#
# 2016년 12월부터 2017년 10월까지 긴 시간 동안 ‘제9회 대학생 OOOO 창의 아이디어 공모전’에 도전한 경험이 있습니다. 4명이 한 팀을 이루어 멘토 기업과 함께 공작기계 관련된 창의 아이디어를 바탕으로 연구개발을 하는 장기간 공모전입니다. 초기에는 팀원이 머리를 맞대어 공작기계에 관련된 창의 아이디어를 큰 틀로 구성하여 초안을 작성했습니다. 그리고 이것을 바탕으로 제안서를 작성하여 기업에 멘토 제의를 하여 멘토-멘티 협약을 맺었습니다. 멘토 기업과 3차례에 걸쳐 회의하였고 구상만 하였던 저희의 아이디어는 멘토 기업의 조언이 더해져 현실성을 가지게 되었습니다. 그 과정에는 교수님의 자문과 공장 견학, 전문서적 혹은 인터넷 정보 수집이 있었습니다. 또한, 최종보고서 작성을 위하여 2D 와 3D 모델링을 통해 제품 설계를 하였고 해석 프로그램을 이용한 ANSYS 해석, 기계 가공 및 조립을 통해 시제품제작을 하였습니다. 완성된 제품으로 실험하였고 제품의 효과를 검증하고 실험 결과를 도출하였습니다.
#
# 4년제 대학생들과 경쟁을 해야 하며 머릿속에 있던 아이디어를 제품으로 현실화시키는 것은 매우 도전적인 일이었고 어려웠습니다. 하지만 팀원들과 함께 밤낮 평일 주말 할 것 없이 모여 연구개발에 임하였고 그 결과 절삭유 부패 및 미세 칩 침전 방지 장치를 개발하여, 한국OOOO학회로부터 200만 원의 상금과 우수상을 받는 결과를 얻을 수 있게 되었습니다.
#
# 오랜 시간 함께하는 과정에서 학교 시험 기간, 자격증공부와 겹쳐 팀원 모두 시간적 여유가 없어 갈등이 생기기도 했습니다. 하지만 더 큰 오해로 번지기 전에 팀원이 모여앉아 문제에 직접 부딪혀 갈등의 원인이 무엇인지, 또 어떻게 해결하면 좋을지 상의하였습니다. 아쉬운점 1
#
# 저는 이러한 경험으로 팀의 성과를 달성하기 위해서는 개인주의적인 행동이 아닌 서로 이해하고 배려하는 자세가 중요한 것을 깨달았습니다. 또한, 혼자서는 못하였을 큰 도전도 함께 힘을 모으면 긍정적인 성과를 이룰 수 있다는 것을 몸소 배웠습니다. 저는 팀원을 이해하고 배려하는 자세를 바탕으로 협력하여 SK실트론에서 또한 눈에 보이는 성과를 만들어내겠습니다. 아쉬운점 2 글자수 1,091자1,851Byte
#
#
#
#
#
#
# Q1 (지원포부) LH 경영목표 중 어떤 부분에 관심이 있으며 입사 후 어떻게 기여하고 싶은지, 본인의 주요 직무 역량 및 강점을 기반으로 기술해 주십시오.		     (0 / 500자 이내) A1 LH 공사에서 가장 관심 있는 분야는 ‘도시재생사업’입니다. 홈페이지 자료 및 도시재생 종합정보체계를 통해 공사에 대한 정보를 찾아볼 수 있었습니다. 이를 통해 공사의 사업은 일자리 창출 및 도시경쟁력 강화를 통해 ‘사회적 가치 실현’을 지향하고 있다는 점을 알게 되었습니다. 정확성 및 신뢰성 높은 재생사업 업무를 수행하기 위해 토목시공과 품질에 관한 역량이 필요하다고 생각합니다.
# 아쉬운점 1
# 이러한 역량을 쌓기 위해 공학인증 과목을 이수하며 전반적인 토목공학에 관한 지식을 쌓을 수 있었습니다. ‘재료역학’과 ‘구조역학’ 등 토목공학의 주요 전공지식을 습득하는 한편, 이를 바탕으로 토목 구조물의 경제적이고 안전한 설계를 위한 일련의 과정을 학습했습니다. 이후, 축적된 지식을 바탕으로 토목기사와 건설재료시험기사를 취득했습니다.아쉬운점 2
#
# 도시재생은 지역의 특성을 고려하여 추진하기 때문에, 직무 역량과 더불어 정확하고 세심한 태도로 저평가된 도시공간의 가치를 높이고, 완성도를 높이는 직원이 되겠습니다.                        글자수 503자875Byte
# Q2 (경험 및 경력 활동) 본인의 학교생활 또는 사회생활 중 전문성 향상 또는 역량 개발에 가장 도움이 되었던 경험, 경력, 활동을 먼저 기술하고, 귀하가 지원한 업무를 수행하는데 어떻게 활용(도움)이 될 수 있는지 기술해 주십시오.                          (0 / 500자 이내) A2 ‘단지설계’ 부문에서 효율적인 업무 수행을 위해서는 ‘안전관리능력’이 필수적이라 생각합니다.
# 좋은점 1
# 학부 시절 지반공학설계 팀 프로젝트에서 옹벽의 안정성 및 최적 단면 설계를 통한 모의실험 경험이 있습니다. 지반의 상태변화에 따른 옹벽의 경제적이고 안전한 설계 내용을 보고서로 작성하였습니다. 특히 직접 모형을 제작하면서 구조물의 안정조건을 만족하는 것이 쉽지 않다는 것을 배웠습니다. 이를 통해 실제 공사에서는 안전하고 합리적인 설계 및 시공법 제시를 위해 토목공학 전반의 지식을 상호 연계하며 학습하여 기본기를 탄탄하게 쌓아왔습니다.
#
# 이와 같은 경험은 희망하는 ‘도시재생사업처’에서 두 가지 측면에서 도움이 될 것이라 생각합니다. 첫 번째, 시설물을 이용하는 국민이 더 안전하게 이용할 수 있도록 기반 마련과 두 번째, 준공 후 사후 구조물의 안전기준을 정비, 적정 시기를 놓치지 않도록 유지관리체계 개선 등의 원활한 업무 수행을 통하여 현재 LH 공사의 ‘도시재생사업’에 보탬이 되겠습니다.아쉬운점 1
#  글자수 506자877Byte
# Q3 (직업기초능력 : 의사소통) 본인보다 나이나 경험이 아주 많은 사람에게 내 의견을 전달하고, 소통했던 경험을 아래 순서에 따라 기술해 주십시오. (가족 제외)   ① 당시 의견 전달 및 소통해야 했던 상황과 이유에 대해 기술   ② 사용한 방법과 그 방법을 선택한 이유에 대해 기술                  (0 / 600자 이내) A3 의사소통에서 가장 중요한 것은 ‘상대방에게 나를 어떻게 이해시킬까?’가 중요하다고 생각합니다.
#
# 과거 컴프레셔 건설장비 현장 경험을 통해 타 업체 직원과 효과적으로 소통한 경험이 있습니다. 당시 타 업체 직원은 저와 나이 차이가 크게 났기 때문에, 저와 의사소통하는 데에 어려움이 있을 것이라는 선입견이 있었습니다. 이런 상대방에게 어떻게 저의 의견을 정확히 전달할 수 있을지 고민했습니다. 그 결과 ‘나를 이해하려 하지 않는 상대방에게 어떤 방식으로 마음의 문을 열게 할 것인가?’에 중점을 두는 것으로 결론을 냈습니다.좋은점 1
#
# 그래서 첫 번째로 ‘경청’과 ‘칭찬’을 통해서 상대방 마음의 문을 열고, 두 번째로 제 의사를 표현할 때는 ‘명확하게 전달’했습니다. 이렇게 두 가지를 활용한 저만의 대화 방식은 저를 이해하려 하지 않았던 직원분과의 의사소통을 효과적으로 할 수 있도록 이끌었습니다. 그 결과 서로 원활하게 소통하며 전보다 작업을 신속하게 끝낼 수 있었습니다.
# 아쉬운점 1
# LH 공사 업무 중에도 연령대나 경험의 차이로 인해 의사소통 문제가 발생할 수 있습니다. 그러나 이러한 가치관을 바탕으로 나이나 경험과 관계없이 잘 융화될 수 있는 직원이 되겠습니다.                        글자수 597자1,025Byte
# Q4 (직업기초능력 : 대인관계) 주변 지인과 원만하지 못한 관계를 회복하기 위해서 노력했던 사례를 아래 순서에 따라 기술해 주십시오.(가족 제외)   ① 원만한 대인관계를 유지하기 위해 평소 견지하고 있는 원칙이나 좌우명을 기술   ② 주변 지인과의 평소 관계를 간단하게 기술하고, 그 사람과의 관계가 소홀해졌던 계기 또는 이유에 대해 기술   ③ 원만하지 못한 관계를 회복하기 위해 본인이 취한 노력 및 성과에 대해 기술 (0 / 600 자이내) A4 평소 ‘갈등은 언제나 있으므로 해결하는 방식이 중요하다’라는 좌우명이 있습니다. 대인관계에 있어서 발생하는 다양한 갈등상황은 매일 일어나기 때문에 굉장히 자연스럽고, 그러므로 이런 매 순간의 갈등상황을 어떻게 유연하게 대처하는가가 중요하다고 생각합니다.좋은점 1
#
# OOOO 어학연수 중 친밀한 관계를 유지해온 3명의 팀원과 함께 ‘싱가포르 호텔’이라는 주제로 발표를 준비하게 되었습니다. 하지만 프로젝트 역할분배 과정에서 부당함을 호소하는 팀원이 발생하였고, 동시에 저에게 ‘불공정하게 역할을 분배했다‘고 주장하며 마찰이 발생했습니다.아쉬운점 1
#
# 하지만 이러한 갈등은 프로젝트를 하는 상황에서는 당연히 일어날 수 있는 일이라 생각했습니다. 그래서 갈등 해결을 위해 두 가지 해결방법을 취했습니다. 첫 번째, 팀원들과 술을 한잔하며 분배 과정에서 지나치게 감정적이었던 분위기를 누그러뜨렸습니다. 두 번째로, 허심탄회하게 터놓고 얘기하며 역할 재분배 과정을 거쳐 이러한 갈등을 해결할 수 있었습니다.아쉬운점 2
#
# 업무를 진행하면서도 의견 마찰과 갈등상황이 발생할 것입니다. 그때마다 상대방의 의견을 존중하고, 대화를 통해 해결하는 대응방식으로 조직 구성원 간의 관계 개선에 늘 힘쓰는 구성원이 되겠습니다.                        글자수 606자1,055Byte
# Q5 (직업기초능력 : 공동체윤리) 지원자 개인의 편의와 공공의 이익 사이에서 고민했던 경험을 아래 순서에 따라 소개해 주십시오.   ① 고민되었던 상황을 기술   ② 당시 대처 방안과 그 이유를 기술                                  (0 / 500 자이내) A5 조직이나 공동체가 지켜야 하는 ‘원칙’은 사소한 것이라 하더라도 모두가 지키려 노력해야 한다고 생각합니다. 하지만 그것이 ’과거부터 내려오는 좋지 않은 관습‘이라고 판단된다면 이를 없애거나 개선하고자 하는 노력이 필요하다고 생각합니다.아쉬운점 1
#
# 과거 컴프레셔 건설장비를 맡아서 일할 당시 ‘건설 현장에서 장비와 관련된 작업만 하면 된다’는 암묵적 관행이 있었습니다. 기존의 직원분들도 이를 당연시 여겼으며, 그러다 보니 현장에서 타 업체 직원분들과 예민한 분위기가 연출되기도 했습니다.
#
# 이는 같은 현장에서 협업하는 상황에서는 불편한 상황을 야기시킬 수 있는 악습이라 판단하여, 제가 할 수 있는 범위 안에서 작업을 도우며 타 직원분들과의 유대감과 신뢰도를 동시에 쌓는데 주력했습니다. 그러다 보니 실수를 하더라도 전과는 다르게 저에게 적극적으로 도움을 주기 시작했습니다. 이러한 변화를 다른 직원분에게 설명하자 처음에는 불만을 표하던 직원도 점점 생각이 바뀌며 이러한 관습이 사라지게 되었습니다.
# 아쉬운점 2 글자수 505자880Byte
#
#
#
#
#
# Q1 지원직무를 선택한 이유를(직무와 관련한 경험,전공,수강과목,자격증 등을 포함하여) 설명하십시오. A1 "마케팅에 대한 입체적 이해"
#
# 마케팅은 명확한 업무 성과를 바탕으로 가장 확실한 성취감을 느낄 수 있는 직무라는 점에서 매력적으로 느껴졌습니다. 충분한 성취감을 느낄 수 있을 때, 지치지 않고 성장할 수 있다고 생각하기 때문입니다. 아쉬운점 1
#
# 마케팅이란 철저한 시장조사 및 고객분석을 바탕으로 전략을 수립/실천함으로써 사업 전반에 기여하는 것입니다. 따라서 마케터의 필수 역량은 '분석 및 전략적 사고 역량'입니다. 저는 OO 기업에서 마케팅 인턴으로 근무하며 해당 역량을 키웠습니다.
#
# 첫 번째로, 기존 고객을 대상으로 뉴스레터를 작성하고 발송하며 고객관리 업무를 수행했습니다. 저는 매월 두 차례 뉴스레터를 발송하며 시간, 날짜, 콘텐츠별로 클릭률을 기록해왔습니다. 그리고 해당 데이터를 분석해서 뉴스레터의 클릭률을 높일 수 있는 전략을 수립했습니다. 그 결과 지난 분기 대비 약 13% 향상한 클릭률을 달성할 수 있었습니다.
#
# 두 번째로, 회사 블로그와 SNS 계정, 홈페이지 내 홍보센터 등의 온라인 채널을 활용해 마케팅 활동을 했습니다. 업계 혹은 회사 관련 이슈와 우수 고객 사례, 서비스 할인 행사 등의 내용을 바탕으로 카드뉴스를 제작하고 채널에 등록했습니다.
#
# 구글 Analytics 프로그램을 통해 회사 웹사이트 방문자 추이를 기록하고, 고객의 검색 키워드 데이터를 분석했습니다. 이후 회사 웹사이트 접속을 증가시킬 수 있는 키워드를 선별해서 검색엔진 최적화를 진행했으며, 구글 Ads 프로그램을 통해 회사 웹사이트 광고를 등록했습니다. 위의 활동을 통해 웹사이트 방문자 수를 1분기 대비 60% 증가시켰습니다.아쉬운점 2 글자수 806자1,360Byte
# Q2 직장 또는 단체생활에서 구성원에게 가장 필요한 태도,역량은 무엇이라고 생각하는지 본인의 경험을 바탕으로 설명하십시오. A2 "팀워크의 필수전략, 균등한 가치 부여"
#
# 팀워크를 높이기 위해서는 각 팀원의 고민과 의견에 균등한 가치를 부여하고, 이를 반영하기 위한 의지가 필요하다고 생각합니다. 그래야만 서로의 문제점에 대해 공감하고 납득할 수 있기 때문입니다. 저는 팀원의 고민에 공감하고 그에 대한 해결방안을 제시함으로써 팀워크를 끌어낸 경험이 있습니다.아쉬운점 1
#
# 대학교 재학 당시 창업 공모전에 참가했었습니다. 저는 미대생의 졸업 작품을 판매할 수 있는 '미술품 중개거래 플랫폼'을 고안하였습니다. 하지만 프로젝트를 진행할수록 팀원 간의 의견이 충돌하는 경우가 자주 발생했습니다. 특히 수익구조에 대한 타당성 부분에서 주장이 엇갈렸습니다. 몇몇 팀원은 단순 중개 수수료를 기반으로 하는 수익구조가 합리적이지 않다는 의견을 제시했지만, 저를 포함한 다른 팀원들은 기한 내에 새로운 수익구조를 설계하는 것은 불가능하다고 판단했습니다.
#
# 이견이 좁혀지지 않아 논쟁이 길어졌고, 저는 문제를 해결하기 위해 창업학 교수님께 문의드리는 방안을 제시했습니다. 그 결과, 교수님과의 상담을 통해 경매방식 기반의 새로운 수익구조를 창출할 수 있었습니다. 이후로는 팀원 모두 단합하여 프로젝트를 효율적으로 준비할 수 있었고, 마침내 공모전에서 대상을 받았습니다.아쉬운점 2
#
# 마케팅은 R&D, 제조, PR, 디자인 등 다양한 유관부서와의 협업이 필수인 직무입니다. 저는 입사 후에도 유관부서 및 동료들과 업무 수행에서의 문제점을 공유하고, 효과적인 해결방안을 제시하겠습니다. 이를 통해 공통된 목표를 달성할 수 있도록 팀워크를 형성하기 위해 노력하겠습니다.                        글자수 791자1,364Byte
# Q3 오뚜기에 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 설명하십시오. A3 "트렌드에 주목"
#
# 마케팅 직무에 있어 가장 중요한 것은 트렌드에 주목하는 것이라 생각합니다. 트렌드에 주목한다는 것은 단순히 유행을 따라 하는 것이 아닌, 소비자의 니즈를 빠르게 인식하고 대응하는 것입니다. 다음의 사례를 통해 오뚜기가 트렌드에 맞춰 마케팅 활동을 하고 있다고 느꼈습니다.
# 오뚜기는 펀딩 사이트 와디즈를 통해 개성 있는 굿즈를 출시했습니다. 다양한 굿즈를 활용해 소비자들의 소유 욕구를 유발하는 최근 식품업계의 마케팅 트렌드를 효과적으로 활용한 것입니다. 또한, SNS에 제품별 꿀조합 조리법 영상을 업로드하며 고객들과 소통하는 모습이 인상 깊었습니다. 저 역시 이러한 오뚜기에서 근무하며, 트렌드에 민감하게 반응하는 마케팅 전문가로 성장하겠습니다.아쉬운점 1
#
# "Balance를 추구하는 글로벌 마케터"
#
# 오뚜기에서 제가 이루고 싶은 단기적 목표는 식품 산업의 마케팅 전문가로 성장하는 것입니다. 이 목표를 이루기 위해 '신규 고객 유치를 통한 매출 확대'와 '기존 고객 충성화를 통한 안정화'의 균형을 추구하겠습니다. 우선, 철저한 시장조사 및 고객 분석을 통해 구체적인 마케팅 전략을 수립함으로써 신규 고객을 유치하겠습니다. 동시에 고객 관리적 마케팅 활동을 통해 이탈을 방지하고 고객 충성화를 이루겠습니다.아쉬운점 2
#
# 저의 중장기적 목표는 글로벌 마케터가 되는 것입니다. 오뚜기는 현재 베트남, 뉴질랜드, 미국 등 다양한 국가에서 법인을 설립함으로써 미래 성장동력을 확보하고 있습니다. 입사 후, 글로벌 시각을 바탕으로 마케팅 업무를 수행하고, 국내 시장뿐 아니라 글로벌 시장에서도 오뚜기가 성과를 낼 수 있도록 하겠습니다.아쉬운점 3 글자수 809자1,384Byte
#
#
#
#
#
#
#
# Q1 본인 성격의 강/약점에 대해서 실제 사례를 포함하여 작성해주세요. A1 "열정맨"
#
# 저는 열정적 학습능력을 가지고 있습니다 은행 투자상품부서 인턴으로 근무하면서 처음 제가 맡은 업무는 보험 서류를 스캔하여 이미지화 하는 작업이 대부분이었습니다. 저는 남는 시간에 부점 자체연수로 제작된 여신사후관리 교육 자료를 읽으며 부서 내의 팀별 역할을 파악했습니다 그렇게 이해한 업무 흐름을 토대로 담당자께 요청하여 신용회복 특수채권 팀의 일까지 더 폭넓은 업무를 수행하였습니다. 또한 적극적인 태도를 좋게 봐주신 팀장님의 배려로 담보물 현장 실사를 참관할 수 있었습니다. 이러한 적극적인 업무 태도는 바쁜 시즌 재경팀에서 강점으로 발휘할 수 있다고 생각합니다.좋은점 1
#
# "과한 도전정신이 초래한 실패"
#
# 도전에 대한 욕심 때문에 맡은 업무를 완수하지 못했던 경험이 있습니다. 전역 후 복학 당시 대외활동, 동아리, 학업, 아르바이트 활동을 병행했던 경험이 있습니다. 개인적인 욕심으로 다소 무리한 스케줄 세우면서 수면 시간을 줄이고, 이동 시간을 통해 자투리 공부를 하는 등 가용 시간을 최대한 확보했습니다. 초기에는 노력을 통해 속한 조직에서 맡은 업무를 충실히 해낼 수 있었습니다. 하지만 여유가 없는 일정으로 인해 몸 상태가 악화되었고, 맡은 일을 동료에게 넘겨야 하는일까지 발생하면서 때로는 무리한 도전보다 어떤 일에 도전하기 전 스스로 할 수 있는 일인지 먼저 생각해보고 결심하는 것의 중요성을 느꼈습니다.좋은점 2 글자수 695자1,197Byte
# Q2 본인이 회사를 선택하는 기준을 바탕으로 우리 회사를 선택한 이유를 작성해주세요 A2 "언제나 NEXT를 준비하는 기업"
#
# 현실에 안주하지 않고 끊임없는 성장을 추구하는 가치관이 IT 분야에서 시작해 금융 뿐 아니라 다양한 사업군의 서비스 개발을 통해 사회 구성원들에게 더 편리한 가치를전달하는 다우기술의 발자취에 부합한다고 생각해 지원하게 되었습니다.
#
# 대학 시절을 보내면서 항상 새로운 목표를 세우고 달성하는 성취지향적 마인드를 갖췄습니다. 무에서 유를 만들어보고 싶은 개인적인 욕심과 사회에 더 나은 가치를 주는사람이 되자는 신념으로 여러 활동을 해왔습니다. 특히 지역 내 홍보가 미비한 체육시설과 소외되는 스포츠 종목을 홍보했던 창업 동아리 활동, 청년 금융이해도 향상과 노인 교통사고 감소를 목표로 진행했던 1년 간 사회변화 프로젝트 활동은 사회에 긍정적인 가치를 전하고 지속적으로 발전하는 기업에서 근무하는 것을 목표한 큰 계기가 되었습니다.아쉬운점 1
#
# 벤처 1세대부터 이제는 IT분야 대표 기업으로 성장한 다우기술의 비결은 끊임없는 도전과 동반 성장의 가치라고 확신합니다. 대표 계열사인 키움증권과 사람인처럼 금융소비자와 취업준비생 등 소비자에게 기존에 접하지 못한 서비스로 새로운 가치를 전하는 기업과의 동반 성장을 추구하는 다우기술의 일원으로서 다가오는 미래에 대한 변화를 두려워하지 않고 사회에 새로운 가치를 전하고자하는 저의 직업관을 실현해보고 싶습니다.아쉬운점 2 글자수 668자1,158Byte
# Q3 해당 직무에 지원하신 이유, 본인이 적합하다고 판단하는 근거, 관련 산출물 등을 작성해주세요. (프로젝트, 포트폴리오, github/블로그 URL 등이 있다면 간단한 설명과 함께 작성) A3 "목표액 1000만 원을 달성한 회계학도"
#
# 대학 졸업 전 일천만 원 저축이라는 목표를 세웠습니다. 용돈, 아르바이트, 인턴 등을 통해 자산을 축적하고 가계부 작성으로 불필요한 지출을 줄이는 자산 관리로 목표했던 1000만 원을 달성할 수 있었습니다. 매출을 통해 자금을 확보하고 적절한 예산 집행과 관리를 통해 성장을 달성하는 점에서 기업의 회계도 큰 틀에서 비슷하다고 생각합니다. 돈에 관한 관심으로 회계학을 전공했고 특히 재무회계에 대한 관심으로 재무제표 작성을 통해 중장기적인 기업의 계획을 수립하는 데 재무직무를 목표로 하게 되었습니다.아쉬운점 1
#
# 재무직무는 정확도와 신뢰도가 생명인 직무이기에, 매 순간 긴장을 요구하는 어려움이 있을 것이라 예상합니다. 이론과 함께 실무 경험을 쌓아오면서 이 부분에 강점을 가지고 있습니다. 군 복무 시절, 2년간 재정회계 병으로 근무하며 매월 500명의 병 급여 지급을 담당했습니다. 수치에 ‘0’ 자리를 하나 더 붙이는 등의 작은 실수가 엄청난 자금 오류를 발생시킬 수 있었기에 예산지급 파일을 수십 번 검토하고 확신을 얻는 업무 방식 덕에 한 차례의 지금 사고도 발생하지 않았습니다.
#
# 또한, 은행 인턴 업무를 담당하며 주인의식을 키웠습니다. 하루 200건의 보험 서류 접수 담당자로서 계약 서류의 분실 혹은 기한 미준수 시, 고객 보험금 지급이 연기될 수 있었기 때문에 업무 진행 전 체크리스트를 제작했습니다. 자주 실수가 나오는 부분을 선제 파악한 후 30분 일찍 출근해 검토하고 지점과의 유기적인 소통으로 서류 분실률 0%를 달성할 수 있었습니다.아쉬운점 2
#
# 이처럼 재무 직무의 기본인 수치에 대한 정확성과 책임감을 갖추기 위해 한 걸음씩 걸어왔습니다. 입사 후에도 이러한 역량을 발휘해, 다우기술의 신뢰받는 재무팀 사원으로 거듭나겠습니다.                        글자수 894자1,518Byte
# Q4 본인이 지원한 직무에서 입사 후 어떠한 업무를 하고 싶은지 작성해주세요. A4 "관리회계 : 기업 성장의 밑바탕"
#
# 팀 별 매출과 원가비용의 정확한 파악과 적절한 판매관리비 집행을 통해 적재적소에 예산을 배부하는 관리회계 업무를 맡고 싶습니다. 학부 시절 원가회계와 관리회계를학습하면서 조직의 성장에 있어서 매출 뿐 아니라 판관비를 포함한 비용의 지출을 적절하게 관리하는 것이 영업이익의 증대와 기업의 실질적인 성장에 중요하다는 사실을알 수 있었습니다.
#
# 또한 이론 뿐 아니라 작은 규모의 조직이었지만 대학생 사회봉사단 활동 경험을 통해 1년 간 약 5백만원 정도의 예산을 관리했던 경험이 있습니다. 당시 총무 역할을 맡으며 비용의 사용처가 적절한지 검토하고 전체적인 예산 계획을 세우면서 조직 예산의 밑바탕을 그리는 일이 조직의 성패를 좌우할 수 있을 정도로 중요한 일임을 느낄 수 있었습니다.아쉬운점 1
#
# 입사 후 동료 사원들에게 회계팀 소통왕으로 불리고 싶습니다. 관리회계 업무 담당자로서, 수치에 대한 정확성 뿐 아니라 구매, 제조, 영업, 마케팅 등 조직의 전반적인 프로세스와 이를 진행하는 담당자들의 입장에서 이해할 수 있는 마인드가 필요하다고 생각합니다. 특히 20여 개의 계열사를 두고있는 다우기술의 재무 담당자는 구성원들과의 소통이 더욱 중요할 것이라 생각됩니다. 특유의 친화력을 발휘해 조직 내 구성원들과 끊임없이 소통하며 적재적소에 자금을 조달할 수 있는 재무팀 사원이 되겠습니다.아쉬운점 2 글자수 685자1,181Byte
#
#
#
#
#
#
# Q1 직무관련 경험기술서 (3,000Bytes 이내) 상단에 작성한 직무관련 경험사항에 대해 본인이 수행한 활동 조직, 역할 및 구체적 활동 내용, 주요 결과 등에 대해 상세히 기술해 주시기 바랍니다. A1 "OOO - 디지털 사이니지 취약점 분석 및 보안 가이드라인 제시"
#
# 저는 2019년 9월부터 12월까지 한국OOOOOOO에서 운영하는 OOO의 2차 과정에서 디지털 전광판으로 불리는 디지털 사이니지의 취약점을 IDA pro, fiddler, 에뮬레이터, wireshark, FTK manager ,uart, logic analyzer 등으로 4개의 플랫폼에 대해 분석하고 STRIDE 위협 모델링을 하여 논문으로 작성해 한국OOOO학회에서 우수논문상을 수여받고 Digital Signage 관리솔루션 인증우회 취약점과 IR Relay를 이용한 보안 위협 시나리오에 대해 논문을 작성해 한국OOOO회에서 우수상을 수여 받았습니다. 또한 국내 대기업 제품을 분석하여 취약점을 제보하였고 감사장을 받은 경험이 있습니다.
#
# "OOOOOOOO 주최 OO 보안 허점을 찾아라 대회"
#
# 저는 2019년 11월 30일부터 12월 1일까지 열린 'OO 보안 허점을 찾아라'라는 대회에 참가하였습니다. 해당 대회는 OOOOOOOO의 홈페이지의 취약점을 찾고 제보한 내용을 토대로 점수화하여 순위를 매기는 대회였습니다. 프록시, 자바스크립트 우회 등으로 웹 해킹을 하였고 결과적으로 최우수상을 수상하였습니다.좋은점 1
#
# "안랩 대학생기자단"
#
# 기사의 질을 높이기 위해 매달 콘셉트회의를 하고 및 기획서를 만든 경험이 있습니다. 기사를 쓴다는 자체가 처음이었고 전문성을 높이기 위해 많은 준비가 필요로 했습니다. 콘셉트회의 및 기획을 하기 전에 중구난방식 기사 작성을 하면 신경을 쓸게 적어서 편할 순 있지만, 기사의 질을 보장하지 못한다는 점이 있었습니다.이런 점에 있어 서로 피드백을 하고 대화를 통해 전문성을 높여 10여 개의 기사를 작성했습니다.아쉬운점 1
#
# "OOOOOOOO OOOOOO지원센터 현장실습생"
#
# 저는 2017년 1월 한 달간 OOOOOOOO센터 현장실습생으로 일하며 중소기업 및 기업 대상으로 할 수 있는 정보보호 서비스- 제품, 서비스 현황조사(국내외), 일본 중소기업의 정보보호 대책 가이드라인 요약 보고서 작성 실습,  2016년 OO지역 중소기업 웹 취약점 분석 결과 문서철 및 내용 정리 분석, OO지역 중소기업 재직자 및 대학생 대상 정보보호 교육 운영 계획 작성 실습(교육 과정, 인원, 기간, 홍보방법 등)을 한 경험이 있습니다. 짧은 기간 동안 과제를 완수하기 위해서 남들보다 30분 일찍 출근하고 검색 및 조사를 생활화하여 문서작성에 근거를 두고 작성하였습니다.
#
# "교내 정보보호 동아리"
#
# 저는 2013년 3월부터 2014년 7월까지 교내 정보보호동아리 활동을 하였습니다. 동아리를 하면서 리버싱, 알고리즘, 워게임 풀이 스터디 및 세미나 진행, PC 관리 프로그램 제작 프로젝트 등을 경험하였습니다.좋은점 2 글자수 1,364자2,173Byte
# Q2 자기소개서(학교명 입력 불가) * 본인의 성장과정에서 만들어진 자신의 장단점이 무엇인지 기술하고, 그 장단점을 활용해 팀 또는 조직의 이익에 어떤 도움이 되었는지 사례를 들어 설명하시오. A2 "발전하는 나로 인해 발전하는 은행"
#
# 저는 IT에 관심이 많은 학생입니다. 하지만 고3 진로를 심각하게 고민하던 중에 정보보호에 대해서 알게 되었고 대학교 과도 관련 학과로 진학해 성적장학금도 여러 번 받았고 군대에서는 정보보호 반에 보직을 받아 근무하였습니다.아쉬운점 1 군 생활 도중 시간에 대한 소중함을 느끼고, 하다가 중간에 그만둔 것에 대해 아쉬움이 생겼습니다.
#
# 하지만 이때까지 저의 단점은 하고 싶어 하는 열정에 비해 끈기가 부족한 것이었습니다. 군대에 가서 좋은 간부님을 만나 어떤 일에서나 포기하지 않는 자세를 배우게 되었습니다. 그 결과 각 부대 에이스들 만 온다는 분대장교육대에서 부대 창설 이후 최초로 1등을 할 수 있었습니다. 군대가기전에는 항상 겉 핥기교육 식으로만 여러 방면에 대해 공부를 해왔다가 전역 이후에 제대로 한 부분씩 차근차근 해봐야겠다는 생각이 들어 끈기를 갖고 계속 가지고 도전해보고 있습니다. 아쉬운점 2
#
# 한 번쯤 외국에서 살아보고 싶다는 생각이 있었고, 전역 후 돈을 모아 워킹홀리데이를 다녀왔습니다. 또 그동안 하고 싶지만 무서워서 시작 못 한 주짓수를 시작하였고 시대회에 나가 은메달을 따는 결과를 내기도 했습니다. 또한 전공에서도 OOO,  OOO 같은 최선을 다해 프로젝트를 진행하며 좋은 결과를 만들기도 하였습니다. 이런 경험들이 모여 작심삼일도 3일마다 하면 끈기를 갖고 노력할 수 있다고 생각하고 항상 목표를 리마인드시키며 단점을 극복하고 제 장점인 열정으로 노력하여 IBK기업은행의 일원이 되었을 때 열정 있는 신입 행원의 자세로 차근차근 일을 배우고 먼저 다가가 고객님과 옆에 있는 동료, 선배님들께 인정받는 후배가 되고 싶습니다.아쉬운점 3 글자수 832자1,421Byte
# Q3 본인이 생각하는 실패의 기준은 무엇이고, 그동안 살아오면서 가장 크게 실패했던 경험을 기술하시오. A3 "실패의 기준, 행동"
#
# 저는 실패의 기준을 행동하지 않는 것으로 생각합니다. 저는 지금처럼 노력하며 살기까지 원인이 있었습니다. 친구들과 술자리에서 어느 한 친구가 질문했습니다. "너희는 왜 사는 거야?" 항상 장난스럽게만 느끼던 말이 왠지 심각하고 무겁게 다가왔습니다. 답을 하려 하자 떠오르는 답이 없었습니다. 사실 생각해 본 적이 없었다는 게 맞는 것이었습니다. 분명히 살아가는 데 이유가 필요하다고 생각했는데 이유 없이 살아가는 저에 대해 무기력해졌습니다. 그 이후로 제가 사는 이유가 생겼을 때 후회하지 않기 위해 모든 일에 최선을 다하고 있습니다. 아쉬운점 1전공도 좋고 학교생활도 나쁘지 않았지만, 그 이유를 찾기 위해 잠시간의 휴식을 갖게 되었고, 휴학하고 하고 싶었지만 무서워서 시도하지 못했던 주짓수를 시작하였고 대회에 나가서 준우승까지 할 수 있었습니다.
#
# 또 외국에서 살아보고 싶다는 버킷리스트를 이루기 위해 캐나다로 워킹홀리데이를 떠났습니다. 말도 안 통하는 타지생활이 외롭고 힘들었습니다. 영어가 많이 부족하여 경험문제라 생각해 핸드폰, 노트북 설정도 다 영어로 바꾸고 영어와 친숙해지기 위해 노력을 많이 하였습니다. 하지만  영어가 늘어감에도 외로움과 두려움의 감정은 없어지지 않았습니다. 생각해보니 자신감의 문제였고, 내가 먼저 다가가는 행동을 많이 했습니다. 같이 일하는 동료들과 데이오프때 같이 놀러 도가고 주짓수 도장에서 만난 친구들과 게임도 같이 하면서 친밀감을 형성할 수 있었습니다. 영어가 부족하더라도 의사소통을 어느 정도 할 수 있다면 네이티브 친구들보다 부족한 영어 실력은 그들에게 매력 포인트가 되었습니다. 문법이 틀리더라도 웃으면서 놀리고 맞는 문장을 알려주며 영어 실력을 상승시킬 수 있었습니다.
#
# 후엔 영어가 모국어가 아니지만 너 정말 잘한다는 소리를 들었고, 한국에서 온 친구들과 함께한 미국여행에서 안내를 할 수 있는 실력까지 올릴 수 있었습니다. 지금와서 생각해보니 캐나다에서의 처음 6개월은 자신감을 갖고 행동하지 않은 저 자신의 실패 였다고 생각합니다. 좀 더 나은 타지생활이 될 수 있었고 좋은 추억을 더 많이 남길 수 있었을텐데 라는 아쉬움이 들었습니다. 이후 만사에 자신 있게 행동하는 자세를 갖게 되었습니다. 아쉬운점 2 글자수 1,109자1,913Byte
# Q4 IBK기업은행에 지원한 이유를 설명하고, 본인이 선택한 지원분야에 자신이 가장 적합한 인재라고 생각한 이유를 기술하시오. A4 "고객이 꿈을 이루도록 도와주는 은행"
#
# 저는 친구의 질문이었던 삶을 사는 이유를 찾지 못했었습니다. 그래서 꿈이라는 자체가 얼마나 귀중한 것인 것을 알기에 그 꿈을 이루기 위해 믿고 이용하는 고객들의 꿈을 지켜주고 싶다는 생각이 들었습니다. 저는 기업은행이 고객들의 현재, 미래의 꿈을 이뤄주는 은행이라고 생각을 합니다. 희망을 키우는 기업은행이라는 슬로건 속에서 제가 입행하게 된다면 제가 쌓은 다양한 경험들로 안전한 인프라운영, 서비스 구축 등에 이바지하고 고객들의 꿈을 지키고 실현하는 데 꼭 도움이 되고 싶습니다. 아쉬운점 1
#
# 저는 고객들의 꿈을 지켜주는 데 필요한 다양한 직무 역량을 갖고 있습니다. 안을 공부하며 화이트 박스 기반의 취약 소스코드 분석을 하려면 필요로 하기에 C.C ++, python, 어셈블리어 등 여러 가지 언어를 익혀야 했습니다. 그 결과 상당수의 프로그래밍 과목에서 좋은 성적을 얻을 수 있었고, 보안의 경우도 공격방법을 알아야 그에 대해 보안을 할 수 있어 큰 도움이 되었습니다. 교내 보안 동아리에도 들어가 동아리 스터디도 해보고 세미나 발표도 해보며 기술적인 부분에 관해 좀 더 자세히 알 수 있게 되었습니다.
#
# 관련 기업 대학생기자단이 되어 저학년 때부터 정보보안 필드에서 일어나는 일들을 많이 접해볼 수 있었습니다. 그리고 군대의 경우 자대에서 정보보호병을 보직 받아 NAC, UTM, 백신 서버 등 장비를 운영하여 군단 예하의 노드 및 PC 들을 관리 하였습니다. 이후에는 IT 프로젝트를 진행하면서 현직에 계신 멘토님과 함께 블루투스를 사용하는 IoT 장비, 디지털 사이니지의 취약점을 분석해 볼 수 있었습니다.  프로젝트의 경우에는 프로젝트의 성과를 인정받아 버그바운티와 감사장을 수여 받을 수 있었습니다. 또한, 관련 취약점 트리거 방법을 논문으로 작성해 OOOOOO학회 동계학술대회에서 우수 논문상, OOOOOO회에서 학부생 우수논문상을 받았습니다. 또한, OOOOOOOO에서 주최하는 'OO 보안 허점을 찾아라' 대회에 나가 최우수상을 취득하였습니다. 이 역량들을 갖고 안전한 서비스 운영을 하며 다양한 사람의 꿈을 이루는 것을 돕다 보면 저도 삶을 사는 이유를 찾을 수 있을 것이라 믿기에 기업은행에 지원하게 되었습니다.아쉬운점 2 글자수 1,110자1,870Byte
# Q5 본인이 사회적 책임을 가지고 타인, 공동체 또는 사회의 공익에 기여했던 경험을 기술하고, 이를 통해 느낀 점을 작성하시오. A5 "작은 도움이 큰 도움으로"
#
# 저는 워킹홀리데이를 다녀았지만 좋았던 점도 있었고 좋지 않았던 점들이 있었습니다. 살면서 느낀 점들을 공유하고 다음에 올 워킹홀리데이 희망자들은 나와 같은 실수를 범하지 않게, 좀 더 좋은 삶을 살 수 있었으면 좋겠다고 생각하였습니다. 좋은 방법이 없나 고민하던 중 OOOOO에서 진행하는 대외활동을 알게 되었고 해외통신원에 선발되어 행사, 현지 맛집 탐방 등 현지 소식을 인터넷을 통해 공유할 수 있었습니다. 또한, 워킹홀리데이를 다녀온 후에는 OOOOO에서 진행하는 OOOOO에 선발되어 워킹홀리데이 희망자들에게 설명회를 열고 상담을 해줄 수 있었습니다. 시간이 지난 후, 상담을 받은 분들로 부터 성공적인 워킹홀리데이가 되었다는 감사인사를 받고 저의 작은 도움이 누군가에게는 큰 도움이 될 수 있다는 것을 알게 되었습니다.
#
# ...
#
#
#
#
#
#
#
# Q1 (지원포부) LH 경영목표 중 어떤 부분에 관심이 있으며 입사 후 어떻게 기여하고 싶은지, 본인의 주요 직무 역량 및 강점을 기반으로 기술해 주십시오. A1 저는 LH 한국토지주택공사의 경영목표 중 '국민 주거권을 보장하는 주거복지 서비스'에 관심이 있습니다. 그중에서도 노후주택 매입 후 신축 또는 리모델링 후 공급하는 업무에 관심이 있습니다. 해당 업무는 저의 전공지식 및 역량을 발휘할 수 있는 업무라고 생각하며, 국민의 필요도에 직결되는 업무라고 생각하기 때문입니다. 좋은점 1
#
# 실제로 저는 OO공사에서 건축 기간제로 근무했던 경험이 있습니다. 근무 당시 건축현장의 보조감독 업무를 맡았으며, 전체적인 공정을 관리하는 공무 업무를 맡았습니다. 위 경험을 통해 건축 감독으로서 일시적이기보다, '내가 살 집'이라는 생각으로 지속 가능한 공공주택을 건설하는 것이 중요하다는 것을 알 수 있었습니다. 위 경험이 LH의 해당 업무를 수행할 때 도움이 될 것으로 생각합니다. 본 업무를 통해 LH가 제공하는 서비스에 대한 국민의 필요를 충족시키며, 지속 가능한 주거복지 기반을 마련하는 일에 이바지하고 싶습니다.아쉬운점 1 글자수 476자814Byte
# Q2 (경험 및 경력활동) 본인의 학교생활 또는 사회생활 중 전문성 향상 또는 역량 개발에 가장 도움이 되었던 경험, 경력, 활동을 먼저 기술하고, 귀하가 지원한 업무를 수행하는데 어떻게 활용(도움)이 될 수 있는지 기술해 주십시오. A2 저는 건축공학을 전공하며 건설공사의 각 과정을 공부했습니다. 대학 시절 배운 건축계획 및 설계, 시공, 공정관리 등 관련 지식을 실제로 업무에 활용해보고자 하여, OO공사에서 건축직 기간제로 근무했습니다. 근무하는 동안 건축공사가 실제로 어떻게 이루어지는지 직접 볼 수 있었고, 현장 시공 점검을 통해 도면과 실 공사를 비교할 수 있었습니다. 또한, 행정능력은 어떤 업무를 하게 되더라도 기본적으로 갖춰야 할 역량이라고 생각되었습니다. 그래서 저는 대학교 졸업 후 OO대학교 국제교류처에서 1년 2개월간 근무했습니다. 본 업무를 통해 기본적인 컴퓨터 활용능력 및 일반행정, 민원 응대 등의 역량을 쌓을 수 있었습니다. 좋은점 1
#
# LH의 건축 업무는 전문적인 지식이 필요하지만, 관리 및 감독 업무를 수행하기 위한 행정능력 또한 필요하다고 생각합니다. 위 경험을 토대로, 두 역량을 모두 요구하는 LH의 건축 업무에서 저의 역량을 발휘하고자 합니다.아쉬운점 1 글자수 473자804Byte
# Q3 (직업기초능력 : 의사소통) 본인 보다 나이나 경험이 아주 많은 사람에게 내 의견을 전달하고, 소통했던 경험을 아래 순서에 따라 기술해 주십시오.(가족 제외) ① 당시 의견 전달 및 소통해야 했던 상황과 이유에 대해 기술 ② 사용한 방법과 그 방법을 선택한 이유에 대해 기술 A3 이전 직장 근무 당시의 일입니다. 당시 사용하던 회사에 포털 시스템은 구축되어 있었지만, 실무에 필요한 몇 가지 항목이 누락되어 있어, 해당 사항을 전산화하는 업무를 맡게 되었습니다. 해당 업무를 수행하기 위해서 당시 실무를 담당하던 저, 저희 부서 팀장님, 그리고 전산화를 도와주실 타 부서 팀장님과 소통해야 했습니다. 두 팀장님은 각 분야에서 경험이 많으신 분들이었기 때문에 원하는 업무방식이 달랐고, 업무를 진행함에 각자의 업무 이해도에 차이가 있음을 발견했습니다. 저희 부서 팀장님께서는 실무를 담당하시는 분이 아니었기 때문에 실제로 어떤 항목이 필요한지 모르고 계셨고, 타부서 팀장님께서는 저희 부서의 기본사항에 대해 잘 모르셨기 때문에 소통의 어려움이 있었습니다. 좋은점 1
#
# 그래서 저는 먼저 실무자로서 전산화가 필요한 항목이 무엇인지 정리해 저희 부서 팀장님에게 설명해 드린 후 개선사항을 함께 논의하였습니다. 그리고 정리된 자료를 통해 타부서 팀장님과는 현실적으로 실행 가능한 부분을 논의한 후 개선을 요청했습니다. 위 과정을 통해 해당 과업을 성공적으로 진행할 수 있었으며, 상대방과 소통함에서는 각자의 요구에 맞게 소통하는 것이 중요함을 알게 되었습니다.아쉬운점 1 글자수 598자1,038Byte
# Q4 (직업기초능력 : 대인관계) 주변 지인과 원만하지 못한 관계를 회복하기 위해서 노력했던 사례를 아래 순서에 따라 기술해 주십시오.(가족 제외) ① 원만한 대인관계를 유지하기 위해 평소 견지하고 있는 원칙이나 좌우명을 기술 -> 적을 두지 말자 ② 주변 지인과의 평소 관계를 간단하게 기술하고, 그 사람과의 관계가 소홀해졌던 계기 또는 이유에 대해 기술 ③ 원만하지 못한 관계를 회복하기 위해 본인이 취한 노력 및 성과에 대해 기술 A4 평소 저는 모든 사람과 원만한 관계를 유지하는 편이며, 다른 사람이 다가오기 편한 사람이 되자는 생각을 가지고 있습니다. 회사 생활을 하던 때에 신입사원과 있었던 일입니다. 당시 저는 그 신입사원에게 업무를 알려주는 입장이었습니다. 제 나름대로는 잘 도와준다고 생각했으나, 그 사원은 저를 계속 어려워하는 것으로 보였습니다. 그렇게 친해지기 어렵다고 생각할 무렵, 저는 신입사원에게 혹시 저에게 불편하거나 어려운 점이 있는지 물어봤습니다. 신입사원은 업무가 처음이다 보니 모르는 것을 저에게 자주 질문하게 되어 저를 방해하는 것 같아 미안한 마음이 들었다며, 제가 불편한 게 아니라고 설명해주었습니다. 그렇게 그 사원과의 오해를 풀 수 있었고, 미안해할 필요 없다며 편하게 도움을 요청하라고 당부했습니다. 또한, 신입사원이 업무뿐 아니라 부서의 분위기에도 잘 적응할 수 있도록 저도 적극적으로 도와주게 되었습니다. 이후 그 사원과 원만하게 지낼 수 있었으며, 퇴사 이후에도 연락을 주고받을 정도로 편한 사이가 되었습니다. 이 일을 통해 대인관계에 문제가 생겼을 때, 상대방이 다가오기만을 기다리는 것이 아니라 내가 먼저 노력하는 것이 중요하다는 것을 알게 되었습니다.좋은점 1 글자수 597자1,035Byte
# Q5 (직업기초능력 : 공동체윤리) 지원자 개인의 편의와 공공의 이익 사이에서 고민했던 경험을 아래 순서에 따라 소개해 주십시오. ① 고민되었던 상황을 기술 ② 당시 대처 방안과 그 이유를 기술 A5 OO공사에서 현장 보조감독으로 근무하던 당시의 일입니다. 하루는 기초철근 배근 점검을 하게 되었습니다. 덥고 습했던 날씨 탓에, 같이 점검을 나갔던 동료가 대충 보고 복귀하자는 식으로 말했습니다. 저도 피곤했기 때문에 순간적으로 고민이 됐지만, 지금 점검을 제대로 하지 않고 콘크리트 타설을 하게되면 나중에 구조적으로 문제가 생길 수 있으므로, 피곤하더라도 원칙대로 하는 것이 좋겠다고 말했습니다. 동료는 어쩔 수 없다는 식으로 함께 점검하였고, 도면에 표기된 것보다 철근이 적게 배근 된 부분을 발견하고 시공사 측에 시정조치를 요청하게 되었습니다. 며칠 후, 부서회의에서 해당 현장의 현황에 대해 상사에게 보고해야 했고, 조치된 사항을 보고드렸습니다. 그때 발견한 사항을 시정조치 했기 때문에 무사히 공사를 착수할 수 있었으며, 다음에 있을 더 큰 피해를 방지할 수 있었습니다. 앞으로 LH에서도 이러한 상황이 생긴다면, 편한 방법을 찾기보다 원칙대로 행동하는 직원이 되겠습니다.아쉬운점 1 글자수 493자851Byte
#
#
#
#
#
# Q1 본인의 성장과정을 간략히 기술하되, 가장 힘들었던 시기와 사유, 그 시기를 극복하기 위해 어떠한 노력을 기울였는지 기술해 주십시오. A1 "포기하지 않고 노력하는 사람"
#
# ‘노력’에 대해 강조하고 또 강조하셨던 아버지의 자녀 교육 덕분에 어려서부터 ‘노력’에 대해 많은 생각을 하며 성장하게 되었습니다. 그리하여 도전 앞에서 넘어져도 포기하지 않는 마음가짐을 늘 새로이 해왔습니다. 이러한 마음가짐은 유학생활에서도 이어졌습니다. 처음 유학생활 저의 경쟁자들은 원어민들이었고 제가 할 수 있는 최고의 방법은 누구보다 더 열심히 노력하는 것이었습니다. 이러한 노력으로 인해 OOO 주립대학교에서 2년을 공부하는 중, 더 큰 목표와 성장을 위해 OO주립대로의 편입을 결심 끝에 합격하게 되었습니다. 좋은점 1
#
# 하지만 기쁨도 잠시 새로운 학교에 대한 적응과 전공에 대한 고민으로 힘든 시간을 보내게 되었습니다. 더군다나 설상가상으로 군대 문제와 재정적인 문제까지 생겨 위기의 때가 많았습니다. ‘이대로 포기하고 한국으로 돌아가야 하는 건가?’ 하는 생각도 해보았습니다. 하지만 저는 중도에 포기할 수 없었습니다. 아침에 눈을 뜨면 ‘주어진 오늘에 최선을 다하자’는 마음으로 포기하지 않고 노력한 결과, 조기 졸업이라는 성과를 거두게 되었습니다.
#
# 유학 생활 중 어렵고 힘든 일들이 있었지만 저는 포기하지 않고 노력하여 학업을 끝까지 다 마치고 국내로 돌아올 수 있었습니다. 노력하는 자세는 저를 강하게 만들었고 앞으로 나아 갈 수 있는 원동력이 되었습니다. 좋은점 2포기하지 않고 최선을 다하여 노력하는 자세로 SIMPAC 발전에 성실히 기여하고 싶습니다. 많은 힘든 일이 있을지라도 포기하지 않고 노력하며 나아가는 SIMPAC의 해외영업관리인이 되겠습니다.아쉬운점 1 글자수 789자1,352Byte
# Q2 본인이 선택한 직무를 담당하고 싶은 이유, 적합성 등에 대해 자유롭게 설명해 보십시오.(학업, 인턴 등 경험한 내용을 중심으로) A2 "세밀한 분석력과 커뮤니케이션 능력"
#
# 저는 영문학과와 국제경영을 전공하여, 글쓰기, 소통 능력과 해외 경제 흐름에 대해 생각하는 연습을 해왔습니다. 그리고 글로벌 역량을 쌓기 위해 미국에서 학사 시절을 보내면서 다양한 문화와 사고방식을 이해하고 다양한 사람들과 협업하며 목적한 바를 이루기 위해 이해하고 배려하는 태도와 주어진 일에 열정을 다하는 태도를 길렀습니다. 또한, 국제 경영을 전공하며 국제 시장의 흐름과 사업을 배우기 위해 "국제 경제" 동아리 활동을 하였습니다. 저는 해외영업을 하는데 있어서 제가 가진 2가지 역량을 보여드리겠습니다.아쉬운점 1
#
# 첫째, 저는 경제학 강의를 수강하면서 창업하고 비즈니스를 분석하고 보고서를 작성했습니다. 저희는 김밥을 창업 아이템으로 정하고 창업을 위해 김밥 산업을 분석하고 저희가 선택한 지역의 상권을 분석했습니다. 적극적인 의사소통과 분석을 통해 완성한 보고서는 A를 받았고 저도 이 프로젝트를 진행하면서 리스크 관리와 세밀한 분석력을 키울 수 있었습니다.
#
# 둘째, 커뮤니케이션 능력입니다. 축구동아리 주장 당시 동부 축구한인대회를 개최를 위해 타학교 주장들과 구장스탭들과 끊임없는 대화를 통해 의견을 수렴했고 성공적인 동부 축구 한인대회 3회연속 개최를 성공했습니다.아쉬운점 2
#
# 이러한 세밀한 분석력과 커뮤니케이션 능력으로 SIMPAC의 차별화된 방법으로 해외 사업에 안정적인 진출을 추진하고 유관 부서 및 실행조직과의 협업을 통해 시너지를 추구하여 SIMPAC의 세계지도를 완성하겠습니다. 저는 이러한 팀원들과 협업을 위해 소통능력을 기르기 위해 노력할 것입니다.아쉬운점 3 글자수 791자1,362Byte
# Q3 SIMPAC을 선택한 이유와 입사 후 회사에서 이루고 싶은 꿈을 기술하십시오.(추상적인 내용을 지양하고 구체적인 방법 및 계획을 제시할 것) A3 "더 큰 꿈을 위해 함께 ‘도전’할 수 있는 회사"
#
# 직장을 선택하는 데 있어 제게 중요한 것은 저와 기업의 성장 가능성입니다. 이를 위해 회사가 가치 창출을 혁신하고 있는지, 제 경험과 역량을 발휘해 성장할 수 있는지 고려합니다. 한국의 금속성형 기술 선두주자인 SIMPAC은 40여 년의 경험으로 세계 최고의 프레스 제조업체 중 하나로 평가 받습니다. 자동차와 가전 등에 쓰이는 금속을 압축, 성형하는 장비인 프레스기계 분야에서 국내 1위로 평가 받습니다. 또한, SIMPAC은 전 세계의 여러 현지 제휴업체들이 참여하는 광범위한 서비스 네트워크를 보유하고 있습니다. 저는 이러한 SIMPAC에서 제가 가진 역량과 경험으로 SIMPAC이 전세계에 진출하여 SIMPAC의 세계 지도를 완성하고 싶습니다.아쉬운점 1
#
# 입사 후 3년간 SIMPAC의 경영이념과 방침을 체득하는 데 집중하겠습니다. 특히 주력 사업인 프레스 기계 분야에서는 안정적인 시장지위를 기반으로 우수한 영업 수익성이 지속할 수 있도록 노력하겠습니다. 또한, 향후 5년간, 업무에 탁월성을 더하기 위해 개인적 시간을 이용하여 스피치학원에 등록하여 커뮤니케이션 기술을 전문화하도록 하겠습니다. 그 후, 고객의 요구를 더욱 구체적으로 파악할 안목을 키우도록 하겠습니다. 이를 통해 한국 최고의 세일즈 전문가가 되어 세계 최고의 기업인 SIMPAC에 걸맞은 인재로 성장할 것입니다. 또한, 저의 글로벌 역량으로서 SIMPAC이 해외로 진출하여 세계지도를 완성하는데 있어 이바지하고 싶습니다.아쉬운점 2 글자수 755자1,260Byte
# Q4 최근 사회이슈 중 중요하다고 생각되는 사항을 한가지 선택하고 이에 관한 자신의 견해를 기술해 주시기 바랍니다. A4 올해 상반기에는 코로나19가 전 세계적으로 확산하면서 전반적으로 무역이 위축됐지만, 한국-인도 교역의 경우 인도 대상 수출이 더 타격받은 것입니다. 이 기간 인도 대상 수출은 53억6천만달러로 작년보다 33.2% 급감했습니다. 반면 수입은 25억9천만달러로 작년보다 5.3% 줄어드는 데 그쳤습니다. 수출은 철강판(-46.6%), 자동차부품(-15.4%), 반도체(-39.0%), 합성수지(-39.6%) 등 주요 품목이 모두 많이 감소했습니다. 글로벌 컨테이너 선사들이 코로나19에 따른 경기 침체에 대응해 감선· 감편 전략을 벌여 운임을 끌어올리고 있습니다. 선박 공급을 줄임으로써 결과적으로 선사들의 재무 실적은 개선됐지만, 위기감을 느낀 글로벌 선사들은 선박 공급을 줄이는 방식으로 대응하고 있습니다. 좋은점 1‘임시 결항 (블랭크 세일링)’을 통해 선박 투입을 줄인 만큼 소수의 선박에 화물을 몰아넣어 적재율도 높이는 방법으로 현재의 위기를 극복하고 있습니다. 유가의 상승은 연료비를 증가시키기 때문에 선사들의 비용을 증가시켜 해운업체들에 악영향을 미칠 수 있습니다. 반면 연초 저유가로 호황을 누려왔던 탱커의 경우 유가 상승에 따라 원유 운반 수요가 줄 가능성이 농후합니다. 향후 지속적인 유가상승은 해운업체의 운영비를 증가시킬 수 있기 때문에, 저유황유나 LNG 등 친환경 에너지 추진 선박으로의 전환을 더 빠르게 촉진시킬 수 있습니다. 이에 따라 선사들은 안정적 연료 공급방안을 마련 하여 현재의 위기를 극복하여 무역의 수출, 수입 정상 회복까지 이루어 내야합니다.아쉬운점 1 글자수 766자1,290Byte
#
#
#
#
#
#
# Q1 본인이 선택한 직무에 대해 아래 내용을 포함하여 기술하시오. ①지원한 직무의 역할이 무엇이라 생각하는지 자유롭게 기술 ②본인이 해당 직무에 적합하다는 근거를 본인의 경험을 바탕으로 기술 ③입사 후 경력개발 계획에 대해 기술 A1 "소통과 행동으로 행복을 전하는 일"
#
# SC 직무는 본부와 가맹점포의 매출, 이익증대를 위해 점포경영 지도, 조언을 하며 이 과정에서 가맹점주 및 다양한 이해관계자들과 소통을 통해 업무를 진행합니다. 화려한 언변이 아닌, 진정성 있는 소통으로 상대방의 상황을 이해하고 합의점을 찾는 것이 중요합니다. 또한, 소통에서만 그치는 것이 아니라 매출을 극대화할 수 있는 점포 운영방안을 구체적인 행동으로 옮길 수 있어야 합니다. 이처럼 소통과 행동을 통해 점주에게는 '수익증대'의 행복을, 고객에게는 일상 가까이에서 느낄 수 있는 '만족'의 가치를 전하는 것이 SC 직무라고 생각합니다. 아쉬운점 1
#
# "변화를 이끄는 능동적 태도"
#
# SC 직무를 수행하는데 필요한 '능동적인 태도'를 가졌습니다. 카페에서 파트타이머로 근무하며 점포 매출과 고객 만족도를 높인 경험이 있습니다. 당시 카페는 초등학교 근처에 위치하여 학부모와 아이들이 주 고객층이었고, 주로 아이들의 입맛에 맞춰 주문이 이루어졌습니다. 이러한 고객 특성을 고려하여 캐릭터가 그려진 음료 및 케익을 주문하여 이를 아이들의 동선과 눈높이에 맞게 진열대 하단에 샘플 진열하였습니다. 이후 아이들의 많은 관심은 구매로 이어졌고 점포의 매출과 고객의 만족도까지 높일 수 있었습니다. 이처럼 적극적으로 변화의 요소를 찾는 능동적 태도는 점포와 관련된 다양한 현황을 분석하여 방향성을 제시해주는 SC 직무에서 큰 장점이 될 것입니다. 아쉬운점 2
#
# 입사 후, 전국 매출 1위 SC가 되는 것이 목표입니다. 담당 점포의 현재 상황과 특성을 적극적으로 파악하고 차별화된 판매 전략 수립을 통해 매출을 극대화하겠습니다. 또한, 정량적 평가뿐 아니라 가맹점주에게 신뢰받을 수 있는 SC로 성장하겠습니다.아쉬운점 3 글자수 865자1,469Byte
# Q2 공동의 목표를 달성하기 위하여 가장 중요하다고 생각하는 역량 1가지를 선정하고,그 이유와 해당 역량을 발휘하여 목표를 달성한 경험에 대해 구체적으로 기술하시오. A2 "피드백을 수용하는 자세"
#
# 공동의 목표를 달성하기 위해서는 피드백을 긍정적으로 수용하는 자세가 중요하다고 생각합니다. 학부 시절 동기들과 참가한 공모전에서 이러한 자세를 통해 공동의 목표를 달성한 경험이 있습니다. 아쉬운점 1당시 공모전을 준비하는 과정에서 발표 내용의 배경지식 분량에 대한 의견이 나뉘며 불화가 발생했습니다. 서로 각자 의견만 고집하다 보니 상대방의 객관적인 조언과 피드백을 제대로 받아들이지 못했습니다.
#
# 이러한 갈등을 해결하기 위해 의견이 다르면 '왜' 그렇게 생각했는지에 대해 경청하고, 상대방 의견을 긍정적으로 받아들이려고 노력했습니다. 자신의 의견에 대한 부족한 점을 적극적으로 수용한 결과, '설명문 배부'라는 모두가 동의하는 방법으로 공동의 목표를 이룰 수 있었습니다.
#
# 같은 목표가 있는 조직이라도 수행과정에서 다른 의견과의 충돌은 불가피합니다. 하지만, 그 과정에서 상대방을 존중하는 자세로 다른 사람이 가지고 있는 좋은 의견을 받아들인다면 더 나은 결과를 얻을 수 있습니다. 아쉬운점 2
# 이러한 자세는 팀 단위로 업무를 진행하며 점포의 안정적 운영과 매출 극대화의 목표를 가지는 SC 직무에서 중요한 역량이라고 생각합니다.                        글자수 598자1,025Byte
# Q3 남들과 다른 새로운 관점으로 변화/혁신을 추구한 경험과 그를 통해 배운점이 무엇인지 기술하시오. A3 "판매자가 아닌, 고객의 입장에서"
#
# 의류 판매장에서 감사제 기간 동안 '새로운 홍보 멘트'를 통해 변화를 이끈 경험이 있습니다.  당시 맡은 업무는 10만 원 이상 구매한 고객에게 증정품을 제공하는 것이었습니다. 처음에는 형식적인 인사와 무미건조한 홍보 멘트로 인해 증정량도 미비했습니다. 하지만 얼마 후 7~8만 원대의 구매 영수증을 보여주며 증정품을 바라는 40대 주부 고객층이 많다는 점과 이들은 주로 가족들 옷을 사러 온 고객이라는 것을 알 수 있었습니다.
#
# 이후 직접 고객의 입장에서 구매 욕구를 자극하는 새로운 홍보 멘트를 생각했습니다. “ 우리 아드님, 따님분이 교복에도 편하게 입을 수 있는 후리스, 아버님들 겨울철 필수 아이템 발열내의 상품이 할인된 가격으로 판매 중입니다.” 등 가족을 떠올릴 수 있는 멘트와 부족한 가격을 충족시켜주는 상품 홍보를 시작하자 증정품을 예상보다 빠르게 소진할 수 있었습니다. 아쉬운점 1
#
# 이 경험을 통해 사소한 생각과 관점의 변화가 곧 변화, 혁신의 시작이라는 것을 깨닫고 어떠한 어려운 문제라도 내 생각과 행동이 바뀐다면 해결할 수 있다는 자신감을 얻을 수 있었습니다.                        글자수 583자983Byte
# Q4 평소 CU 편의점 이용 시 느꼈던 장단점을 기술하고, CU 편의점 경쟁력을 제고할 수 있는 아이디어를 제시하시오. A4 "Trend를 선도하는 신상품 및 서비스 도입"
#
# 소비자 Needs를 고려한 신상품 출시, 서비스 도입 등  다양한 도전으로 편의점 업계를 선도해 나가는 것이 가장 큰 장점이라고 생각합니다. 대표적인 예로 화이트데이 무료 배달 서비스를 통해 이벤트 데이를 더욱 특별하게 만들어주며 최근 언택트 선물을 선호하는 고객 Needs를 정확히 충족시켜주었습니다. 상품군 또한, 사탕뿐 아니라 마카롱, 젤리 등 차별화된 상품으로 선택의 폭을 넓혀주었습니다. 이처럼 빠르게 변하는 소비자의 Needs를 정확히 파악하고 그에 맞는 신상품과 서비스를 통해 만족을 전해주는 것이 CU를 이용하며 느낀 가장 큰 장점입니다.아쉬운점 1
#
# "점포별 실시간 재고 현황 공유"
#
# 점포마다 판매하고 있는 상품이 다르다는 것이 다소 아쉽습니다. 점포의 규모에 따라  즉석 조리 식품이나 인기 간편식 상품을 판매하지 않거나, 재고가 없어 대체재를 구매하는 경우가 많았습니다. 물론 점포 면적, 입지 특성 등 다양한 요인에 따라 다를 수 있지만,  소비자 입장에서 같은 CU 점포에서 특정 상품을 구매하지 못하거나 서비스를 이용하지 못하면 만족도가 감소할 수  있다고 생각합니다. 아쉬운점 2
#
# 이러한 점을 보완하고 경쟁력을 높이기 위해 '점포별 실시간 상품 및 재고 확인 서비스'가 필요하다고 생각합니다. 점포마다 취급하는 상품 및 재고 정보를 실시간 앱을 통해 공유할 수 있다면 고객들의 편의성 증대는 물론, 대체재 구매에서 오는 아쉬움을 만족으로 바꿀 수 있을 것입니다. 이처럼 고객을 위하는 작은 차이 하나가 CVS 산업에서 경쟁력을 높일 수 있는 가장 좋은 방안이라고 생각합니다.아쉬운점 3 글자수 817자1,368Byte
#
#
#
#
#
#
# Q1 우리 공사에 지원한 동기를 지원자가 가진 직장 선택의 기준과 연계하여 기술해 주십시오. (800자 이내) A1 제가 한국주택공사를 지원한 이유는 전산직 채용이 있어서 지원하게 되었고, 직장을 선택하는 기준은 제 적성에 맞고, 제가 할 수 있는 일을 하는 안정된 직장을 원해서입니다. 전공이 OOOOOO이고, 시스템 개발직으로 6년 3개월간 근무한 경력도 있어서 전산직에 지원하였습니다. 그리고 신입 직원의 연봉 수준도 고려해서 지원하게 되었습니다. 한국주택공사의 서민 주거 복지향상으로 개선하는 기관으로 주택금융 등의 장기적ㆍ안정적 공급을 촉진하여 국민의 복지증진과 국민경제의 발전에 이바지함을 목적으로 하는 한국주택공사의 취지도 마음에 들었습니다. 아쉬운점 1 글자수 302자530Byte
# Q2 지원자의 장점을 공사 인재상인 창조인, 전문인, 화합인과 각각 연관 지어 상세히 설명하고,  이를 공사업무 수행 시 어떻게 활용할 것인지를 기술해 주십시오. (800자 이내) A2 공사의 인재상인 창조인, 전문인 그리고 화합인을 지향하는 한국주택금융공사의 주택금융의 장기적 · 안정적 공급을 통해 국민 복지증진과 국민경제 발전에 기여를 미션으로 국민의 행복과 함께 성장하는 최고의 주택금융기관, 서민 주거복지 향상으로 삶의 질을 개선하는 기관의 비전을 가지고 국민의 삶의 질을 높이고, 안정적인 주택마련을 위해 힘쓰는 한국주택금융공사의 직원으로서의 역할을 다할 것입니다. '집없는 설움'이라는 말이 있듯이 오랫동안 무주택자로 지낸 서민들에게 단비와 같은 한국주택공사의 단비와 같은 창조적인 인재, 그리고 주택금융업무에 관한 전문인, 고객의 마음을 읽을 줄 알아 따뜻한 마음으로 보듬을 수 있는 수평적인 사고를 가진 화합인이 되어 공사의 직원으로서의 소임을 다하겠습니다.아쉬운점 1 글자수 385자676Byte
# Q3 공사는 T.O.P 조직문화를 가지고 있으며, T.O.P란 “Together(함께)”, “Open(열린)”, “Professional(전문적인)”을 의미합니다. 위 단어(Together, Open, Professional) 중 하나를 선택하고, 선택한 단어가 조직문화에서 어떤 의미를 가지는지를 지원자의 경험과 함께 기술해 주십시오. (900자 이내) A3 조직문화 내에서 '열린(Open)' 마인드의 사고는 나와 다른 타인의 의사를 존중하고 배려함으로써 이타적이고 모두의 개념이 녹아있는 단어라고 생각합니다. 나만의 사고나 아이디어가 아니라 모두의 의견을 수렴하고, 상대를 배려함으로써 나의 이익만을 추구하지 않고 상대와의 의견차이를 좁혀 적절한 합의점에 도달하는 일은 열린 마음과 남에 대한 존중과 배려가 아니라면 이루어 지지 않을 마인드라고 생각합니다. 아쉬운점 1시스템을 개발하면서 나와 다른 의견을 가진 상대의 의견을 존중하면서 상대를 나의 결론으로 설득하는 능력도 갖추어야 할 소신이라고 생각합니다. 내 의견을 들어주는 상대가 있어야 나의 의견도 받아들여지듯이 상대의 의견도 이해하고 수용하는 자세 또한 열린 마인드를 가지고 업무에 임하는데 필요한 자세라고 생각합니다. 아쉬운점 2 글자수 399자696Byte
# Q4 공사 상품(보금자리론, 주택보증, 주택연금 등) 중 지원자가 가장 관심 갖고 있는 상품을 1가지 선정하고, 그 이유와 공사에 입사하여, 해당 상품 분야에 대한 전문가로 성장하기 위해 어떠한 계획을 가지고 있는지를 기술해 주십시오. (900자 이내) A4 제가 가장 관심을 갖고 있는 상품인 보금자리론은 신규주택구입용도, 전세자금반환 및 기존 주택담보대출상환용도로 신청이 가능하며, 대출 받은 날부터 만기까지 안정적인 고정금리가 적용되어, 향후 금리 변동의 위험을 피하고자 하는 고객에게 적합한 상품입니다. 이유는 내집을 마련하려면 보금자리론을 모르면 안 될 정도로 낮은 고정 금리의 주택담보대출이기 때문입니다.좋은점 1 보금자리론 상품의 전문가가 되기 위해 보금자리론의 신청대상, 대출금리, 대상주택, 조정대상지역 등 지역별 유의사항, 대출기간, 상환방식, 소득증빙방법 등의 보금자리론을 신청하려는 국민에게 보금자리론의 장점과 단점에 대해서 상세하게 설명하고 어떤 대출금리를 선택하고, 대출기간은 얼마로 하고, 상환방식은 어떻게 결정하고, 대출을 받기 위한 필요한 서류 등을 친절히 안내할 것입니다.
# 아쉬운점 1 글자수 415자726Byte
# Q5 공사에는 다양한 연령대의 고객이 있습니다. 지원자가 생각하는 20~30대, 40~50대, 60대 이상 고객별 주택금융 관련 관심과 니즈(needs)는 무엇인지 설명하고, 그러한 관심과 니즈를 고려한 공사의 역할은 무엇인지를 기술해 주십시오. (900자 이내) A5 20~30대는 사회생활의 초반대이고 사회생활을 왕성하게 하는 연령대로 사회생활의 첫출발을 하는 20대는 내집마련의 막연한 미래의 꿈보다 혼자서 생활하게 된다면 원룸의 월세방이나 보증금을 주고 월세를 내는 주택에서 생활을 할 것으로 본인 역시 20대에 원룸에 보즘금에 월 얼마의 세를 내고 생활을 했습니다. 30대는 신혼으로 새집 마련이나 전세로 새출발을 할 가능성이 높아 주택금융의 전세자금 대출이나, 보금자리론으로 내집마련을 준비하는 연령대라고 생각합니다. 40 ~ 50대는 집을 더 늘리거나 자녀의 주택을 마련하는 연령대로 역시 보금자리론을 이용할 수 있는 연령대라고 생각합니다. 60대는 역시 자녀의 주택을 마련하거나 주택을 가지고 노후에 월 생활 노후자금으로 주택연금에 가입해 쓸 수 있는 나이라고 생각합니다. 좋은점 1그래서 각 연령대별 주택의 필요성을 구분하여 주택금융공사의 역할을 설계하는 게 좋다고 생각합니다. 이미 시행하고 있는 내용이기도 합니다만, 모든 연령대를 만족시킬 수 있는 주택자금대출 상품을 마련해 내집을 마련하고자 하는 서민과 실수요자에게 더 많은 혜택이 돌아갈 수 있게 주택금융공사의 역할을 더 일반성과 공공성을 가지고 주택마련에 관한 낮은 이율의 대출을 더 확대하는 게 앞으로의 주택공사가 더 많은 국민의 내집마련의 소원을 이루게 해 주는 든든한 주택공사가 되지 않을까 생각합니다.
# 아쉬운점 1 글자수 678자1,171Byte
# Q6 공사는 사회적 책임을 다하기 위해, 은퇴금융아카데미, 재밌지예, 어르신 한글교실, 집 고치기 등 다양한 공익 지향적 활동을 진행하고 있습니다. 지원자의 과거 공익 지향적 경험은 무엇이며, 공사에 입사하여 공사의 특성 및 지원자의 경험을 반영하여, 새로운 공익 지향적 활동을 계획한다면, 어떠한 것이 있을지를 기술해 주십시오. (900자 이내) A6 저의 공익 지향적 경험은 2003년도의 OO OO OOOOOO 선수촌 영어 통역 자원봉사일이였습니다. 당시 대구에 국제 스포츠 대회를 유치하고, 선수촌을 마련하고자 대구시에서 노력을 기울였는데, 대회가 끝나고 구내외 선수들의 선수촌을 위해 만든 아파트는 일반 대구 시민에게 돌아가 현재는 선수촌이였던 동변동의 아파트가 일반 시민이 거주하는 민영 아파트가 된 걸로 알고 있습니다. 실제로 아파트에 당첨되고자 하는 목적때문에 자원봉사를 오신 분들도 계셨습니다. 아쉬운점 1한국주택공사에서 사회에 책임을 다하기 위해 위와 같은 다양한 공익 지향적 활동을 하는지는 처음 알았습니다. 집에 대한 소중함도 알고 국민을 위한 한국주택공사라는 공사가 있다는 것도 알게되는 좋은 일이 생길 것 같습니다.
# 아쉬운점 2 글자수 381자662Byte
#
#
#
#
# Q1 한국전력공사의 4가지 인재상(기업가형 인재, 통섭형 인재, 도전적 인재, 가치창조적 인재) 중 본인과 가장 부합된다고 생각하는 인재상을 두 가지 선택하여 그렇게 생각하는 이유를 본인의 교육, 경험, 경력사항 등 구체적인 사례를 들어 기술하여 주십시오. A1 기업가형 인재와 도전적 인재에 가장 부합한다고 생각합니다.좋은점 1 대학교 시절부터 여러 조직에서 활동하며 원활한 조직 운영을 위해 항상 저의 위치에서 최선을 다했고 동시에 도전정신을 키우기 위해 노력했습니다. 1학년 때부터 활동해온 동아리에서는 동아리 회장을 맡아 각종 행사 참여 및 회원 관리를 하며 동아리 발전을 위해 노력하였고 동시에 학과 학생회 활동을 하며 임원으로서 학생들을 위한 여러 가지 행사 기획 및 진행을 도와 1년간 학생들을 위해 봉사하였습니다. 또한 학과 실험실에서 연구보조원으로 활동하여 교수님과 대학원생 선배들을 보조하며 개인 공부도 게을리하지 않았습니다. 좋은점 2이러한 활동들을 하며 조직의 이익을 위해 노력하는 동시에 저 자신의 도전 의식을 키울 수 있었습니다. 따라서 저는 한국전력공사의 인재상 중 기업형 인재와 도전적 인재에 부합한다고 생각합니다.좋은점 3 글자수 427자745Byte
# Q2 최근 한국전력공사 또는 한국전력공사의 사업과 관련된 주요 이슈에 대해 한 가지를 언급하고, 그것에 대한 본인의 견해(문제의 원인, 개선방안 등 포함)를 기술하여 주십시오 A2 빅데이터를 활용한 전력 설비 유지보수는 고장률, 비용을 절감할 수 있습니다. 이를 확대하기 위해서는 각종 상태, 고장 유무를 점검할 수 있는 센서 개발이 중요하다고 생각합니다. ICT, 통신 기술은 다른 나라에 비해 우수하지만, 각종 센서 기술은 아직 미비합니다. 빅데이터 활용 기술에 활용할 각종 센서, 모듈, 소프트웨어 개발이 필수라고 생각합니다. 이제는 데이터 센터뿐만 아니라 각종 센서를 접목할 시험대 확대, 현장 작업자 협업이 필요합니다. 이를 통해 설비 고장률 절감, 유지보수자 안전성 확보 등을 도모할 수 있습니다.아쉬운점 1 글자수 295자502Byte
# Q3 한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업무를 하고 싶은지를 본인의 교육, 경험, 경력사항 등과 연계하여 구체적으로 기술하여 주십시오. A3 학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감리, 발전 공학 등의 과목에서 부족함을 느껴 학교 교육 외의 교육을 받으며 전기기사 자격증을 취득하였습니다. 공부를 하면서 실무 경험이 매우 중요하다고 생각했지만, 학생 신분에서 실제 업무에 사용되는 장비를 다뤄보기란 쉬운 일이 아니었습니다. 그래서 실험 수업이나 학부생 인턴 프로그램에 적극적으로 참여해 많은 장비를 다뤄보려 노력했습니다.아쉬운점 1
#
# 특히 학부생 인턴 프로그램에서 고전압을 이용하는 등 위험 장비와 주요 장비들을 실제로 사용해 볼 수 있었습니다. 이를 통해 실무에서 장비의 정확한 제어와 유지보수가 얼마나 중요한지를 알게 되었습니다. 하지만 분명 실무에서 사용되는 것과 차이가 있을 것입니다. 저는 이번 인턴 활동을 통해 실제 현장에서 실제 송배전 , 변전 업무가 어떻게 이루어지는지 간접적으로라도 경험해 볼 것입니다. 직간접적인 실무 경험을 통해 실무에 대한 데이터를 잘 쌓아 놓는다면 후에 한국전력의 일원이 되었을 때 이때의 경험으로 실제 업무에 잘 적용할 수 있을 것이라 생각합니다.아쉬운점 2 글자수 548자952Byte

# %% [markdown]
# # 해야 할 일
# ## 1. 뒷부분 오류 해결(IndexError  Traceback (most recent call last))
# ### 11번 째 페이지(오뚜기에서 오류)
# https://www.jobkorea.co.kr/starter/PassAssay/View/235803?Page=1&OrderBy=0&schTxt=%EC%84%A0%ED%83%9D%ED%95%9C&FavorCo_Stat=0&Pass_An_Stat=0
#
# ## 2. 순차적으로 담기(질문, 답, 질문, 답, 질문, 답, ... 해결하기)
# ## 3. 다른 페이지 반복
# ## 4. DB

# %%
df = pd.DataFrame(contents,columns=['company', 'group', 'score', 'question', 'answer'])
df
# Out:
#   company                  group score  \
# 0  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 1  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 2  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 3  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 4  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 5  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
# 6  한국전력공사  2020년 상반기 신입 전기·전자·제어     3
#
#                                             question  \
# 0  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 1  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 2  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 3  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 4  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 5  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
# 6  한국전력공사에 지원하게 된 동기, 희망 직무를 선택한 이유 그리고 입사 후 어떤 업...
#
#                                               answer
# 0  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 1  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 2  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 3  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 4  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 5  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...
# 6  학과 커리큘럼에 따른 전기 관련 과목들을 이수했습니다. 그러나 송배전 변전설비나 감...

# %%
# Out:
# Empty DataFrame
# Columns: [company, group, score, question, answer]
# Index: []
