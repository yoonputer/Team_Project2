# %%
from selenium import webdriver

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 963C-DFD5
#
#  C:\Develops\forkspoon 디렉터리
# 파일을 찾을 수 없습니다.

# %%
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('https://www.jobkorea.co.kr/')

# %%
import time

# %%
time.sleep(2)
browser.find_element_by_css_selector('span.mainBtn.mainBtnPer').click()
browser.find_elements_by_css_selector('input#lb_id.iptTx')[0].send_keys('')
browser.find_elements_by_css_selector('input#lb_pw.iptTx.devCapsLock')[0].send_keys('')
browser.find_element_by_css_selector('div.loginIptWrap.clear>button.btnLogin').click()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
time.sleep(2)
browser.find_element_by_css_selector('li#gnbStart>a.linkItem').click()
browser.find_element_by_css_selector('li>a[href="/starter/passassay/"]').click()

# %%
browser.find_element_by_css_selector('div.toolTipCont.fullLy>div>button').click()
browser.find_elements_by_css_selector('input#txtSearch')[0].send_keys('선택한')

browser.find_element_by_css_selector('button#btnSraech').click()

# %%
from bs4 import BeautifulSoup

# %%
cnt = 0
import pandas as pd
from bs4 import BeautifulSoup

# %%
browser.find_element_by_css_selector('li:nth-child(1) > div.txBx > p > a > span').click()
contents = soup.select('div.stContainer')
print(type(contents))
contents[0]
# Out:
# <class 'bs4.element.ResultSet'>
# <div class="stContainer">
# <!-- starViewTit 추가 -->
# <h2 class="starViewTit">합격자소서</h2>
# <div class="selfTopBx">
# <div class="viewTitWrap">
# <h2 class="hd">
# <strong>
# <!--신입공채 페이지 호출방식변경-->
# <a href="https://www.jobkorea.co.kr/Recruit/Co_Read/C/ottogi " target="_blank" title="기업 홈 이동">(주)오뚜기</a>
# <!-- 스크랩 버튼추가. 기본클래스 off, 스크랩 되었을경우 클래스 off 삭제 on 추가 -->
# <button class="btnStarSc off btnFavorStat" type="button"><span class="stSpImg"></span><span class="skip">관심기업</span></button>
# <input id="hdnCId" name="CId" type="hidden" value="ottogi"/><input id="hdnMemSysNo" name="MemSysNo" type="hidden" value="264656"/> </strong><em>2020년 하반기 신입 바이오·제약·식품</em>합격자소서
#             </h2>
# <div class="btns">
# <!--<a href="#" class="linkGo stSpImg">기업 홈 가기</a>-->
# <a class="linkWrite stSpImg" href="//www.jobkorea.co.kr/SelfIntroduction/PassAssayView?PflNo=236312" target="_blank">자소서 작성</a>
# </div>
# </div>
# <div class="selfCtWrap">
# <h3 class="hd">합격자 정보</h3>
# <ul class="specLists">
# <li>수도권4년</li>
# <li>식품생명공학과</li>
# <li>학점 3.51/4.5</li>
# <li>토익 870</li>
# <li>자격증 2개</li>
# <li>인턴 2회</li>
# <li>동아리 1회</li>
# <li class="txViewNum">9,202<span class="stSpImg">읽음</span></li>
# </ul>
# </div>
# </div>
# <div class="adviceTotal">
# <div class="hd">
# <h3 class="tit">전문가 자소서 총평</h3>
# <span class="grade">
# <span class="stars lv02">
# <span class="down stSpImg"></span>
# <span class="up"></span>
# </span>
#                     2
#                 </span>
# </div>
# <p class="tx">지원자는 전체적으로 기승전결 방식으로 내용을 쓰고 있어 읽다 보면 답답함이 느껴진다는 점이 아쉽습니다. 지원자가 제시한 각종 이야기는 자기소개서의 핵심 내용이 될 수 없습니다. 그 이유는 지원자와 제시한 이야기 사례와 비슷한 타 지원자의 이야기가 많기 때문입니다. 하지만 질문에서 경험과 사례를 제시하라고 했으니 당연히 이야기는 써야 합니다. 결론이 앞에 나오는 것이 중요한 이유가 여기에 있습니다. 많은 지원자들이 비슷하게 쓰는 이야기를 인사 담당자들이 처음부터 읽다가 지치게 만드는 것보다 결론을 먼저 제시함으로써 어떤 이야기인지 미리 알려줄 수 있고, 핵심 위주로 읽게 유도함으로써  인사담당자도 편하게 하고 지원자도 자신이 말하고자 한 핵심을 알리는 역할을 한다는 것입니다. 그리고 전반적으로 내용이 불필요하게 복잡합니다.</p>
# </div>
# <div class="selfQnaWrap">
# <h3 class="skip">합격자소서 질문 및 내용</h3>
# <!--
#             페이지 로드시 질답 활성화 클래스
#             dt 클래스         : on
#             dd 클래스         : show
#             dd 다음 dt 클래스 : next
#          -->
# <dl class="qnaLists">
# <dt class="on">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q1.</span><span class="tx">지원직무를 선택한 이유를(직무와 관련한 경험, 전공, 수강과목, 자격증 등을 포함하여) 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="show">
# <strong class="skip">답변</strong>
# <div class="tx">
# "직접 만든다는 것"
# <br/>
# <br/><b class="bad">실습을 위해 콤부차를 조사하였습니다. 한정된 자료에서 최대한 조사했지만, 자세한 공정은 알 수 없었습니다. 좋은 결과를 도출하기 위해선 철저한 계획이 중요하다 생각돼 제조사, 제조공장에 문의하여 부원료 선택조건, 발효시간 등의 부분적인 답변을 들음으로 초안을 계획할 수 있었습니다. 이후 차 제조회사의 개발 업무에서 두 원료를 조합해 제품을 개발하는 업무에 참여했는데, 두 원료를 섞으면서 각각의 특색이 사라지는 문제가 있었습니다. 두 원료가 활성을 가지는 당도와 산도가 극과 극이었기 때문이었는데, 이전 실습을 위해 공정 조사를 문의할 때 조합이 좋을 것 같은데 왜 사용을 하지 않는지에 대한 답변을 실제로 경험하게 된 상황이었습니다. 두 원료의 황금비율을 찾는 것과 동시에 맛, 컨셉, 안정성 또한 유지하려 노력했습니다. 배합비를 수정하고 관능 검사하는 과정을 반복하면서 혀가 쓴맛을 즐기게 될 때쯤, 제품의 완성도가 갖춰져 두가지 원료를 조화롭게 느낄 수 있었습니다. 그리고 전화로 들었던 한계를 해결하는 듯한 성취감 또한 느꼈습니다. <span class="sup">아쉬운점 1</span></b>
# <br/>
# <br/><b class="bad">소비자 입장에서 왜 맛있는 두가지를 섞어 팔지 않는지에 대해 의구심을 가졌습니다. 하지만 식품을 전공하면서 의구심에 대한 답을 배우고, 개발을 하면서 해결방안을 찾았습니다. 주변을 둘러보면 많은 소비자들이 자신들이 자신이 원하는 제품을 기다리는 모습을 볼 수 있습니다. 모든 소비자가 식품을 전공하고 개발할 수 없기에 누군가가 소비자를 위해 제품을 만들어야 합니다. 그리고 저는 제가 얻은 지식과 경험으로 소비자를 위한 제품을 만들기 위해 노력하겠습니다.<span class="sup">아쉬운점 2</span></b> <p class="txSpllChk"><span>글자수 <strong>800</strong>자</span><span><strong>1,381</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 자기소개서는 질문에 답을 제대로 하는 것이 중요합니다. 구구절절한 스토리를 쓰는 것이 중요한 것이 아니라는 것입니다. 질문은 지원직무를 선택한 이유를 묻고 있습니다. 그렇다면 지원직무가 무엇인지 먼저 제시하고 왜 해당 직무를 선택했는지에 대한 결론을 제시해야 합니다. 지원자가 쓴 내용은 질문과 자연스럽게 이어지지도 않고, 결론적으로 왜 이 직무를 희망하는지도 쉽게 이해하기도 어렵습니다. 스토리는 스토리를 요구할 때 쓰면 됩니다/</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 지원직무 선택동기를 묻고 있는데, 앞으로의 계획과 포부로 마무리하고 있습니다. 질문과 제대로 의사소통이 되고 있지 않습니다.</p>
# </div>
# </dd>
# <dt class="on">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q2.</span><span class="tx">직장 또는 단체생활에서 구성원에게 가장 필요한 태도, 역량은 무엇이라고 생각하는지 본인의 경험을 바탕으로 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="show">
# <strong class="skip">답변</strong>
# <div class="tx">
# "각자의 경험이 다르다는 것"
# <br/>
# <br/><b class="bad">인턴기간에 동반성장을 목표로 새로운 메뉴를 개발하는 프로젝트에 참여했습니다. 기업간의 협업으로, 각자가 잘 하는 방식으로 자신의 역할에 최선을 다했어야 했기에 초기 아이디어 회의에서부터 많은 의견이 나왔습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">30개의 아이디어는 각각 매력과 가능성을 가지고 있었지만 가장 좋은 것을 선별해야 했습니다. 먼저 1차적인 선별을 위해 시장조사와 제조공정을 파악하여 대중성이 있고, 자체 개발이 가능한 제품을 선별했습니다. 이 과정에서 저는 팀으로 협력하면서 팀 구성원에게 필요한 태도를 배울 수 있었는데, 바로, 각자의 역할을 수행하고, 서로의 접근방식을 공유하고 수용하며 해답을 찾는 것입니다. <span class="sup">아쉬운점 2</span></b><b class="bad">저는 프로젝트에서 소비자들의 소비형태와 그에 따른 시장의 동향을 조사하였고, 이를 요약하여 팀원들에게 분배했습니다. 그리고 팀원들은 받은 자료를 토대로 각자가 담당하던 제품과 연관된 소재를 구체화하였고, 마지막으로 팀장이 단가, 공정 등 세부사항을 판단하여 좋은 주제를 간추렸습니다.
# <br/>
# <br/>기업간 협업에서 각자가 잘하는 방식으로 역할에 최선을 다하듯 팀 구성원도 자신의 역할에 충실하여 효율을 높일 수 있었습니다. 또한, 아이디어 회의에서부터 매일 1회 이상 프로젝트 회의를 진행하면서 비슷한 상황에서 창의적, 효과적으로 해결할 수 있었던 각자의 방법을 서로 제시하고 실천하여 효율적으로 업무를 진행하였습니다. 결과적으로, 각자의 경험이 다르다는 것은 다양한 시선과 방법이 다양하다는 것으로, 관점과 방법을 제시하고 수용하면서 함께 발전할 수 있다는 점에서 팀에게 가장 필요한 태도이자 역량이라고 생각하였습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>803</strong>자</span><span><strong>1,398</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 자기소개서는 기승전결식의 이야기가 아니라 질문에 대한 답을 먼저 제시하고 그에 대한 근거를 제시하는 방식이 더 읽기 쉬운 내용입니다. 즉, 직장 또는 단체생활에서 구성원에게 가장 필요한 태도가 무엇인지를 먼저 제시하고 왜 그렇게 생각하는 지를 쓴 다음 이와 관련한 경험을 제시하는 순서로 쓰는 것이 더 읽기 편한 내용이라는 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 이 부분에서 지원자는 협업에서 필요한 점을 언급하고 있는데 그 방식이 불필요하게 복잡합니다. 핵심은 생각을 공유하는 것임을 먼저 구체적으로 설명하고 수용에 대한 내용은 뒤에 설명하는 것이 더 집중도를 높이는 방향일 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 3</strong> 무엇을 말하고자 하는지는 잘 알겠지만, 전체적으로 내용이 복잡하게 설명되어 있습니다. 그리고 질문은 단체생활에서 구성원에게 필요한 태도와 역량을 묻고 있는데, 지원자는 협업의 관점에서만 이야기를 하고 있습니다. 즉, 질문에서 협업에서의 태도와 역할을 묻지 않았는데, 지원자는 그렇게 이해했다는 것입니다. 질문과 내용이 정확하게 맞지 않습니다.</p>
# </div>
# </dd>
# <dt class="next">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q3.</span><span class="tx">오뚜기에 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="">
# <strong class="skip">답변</strong>
# <div class="tx">
# "가능성을 캐내고 가치를 심자"
# <br/>
# <br/><b class="bad">식품은 광범위한 방면에서 다양한 방향성을 가지고 나아가고 있기 때문에 대학에 오랜 기간에 걸쳐 쌓인 지식으로는 현재 식품 시장을 온전히 이해할 수 없다고 생각했습니다. 우물 안 개구리에서 벗어나 트렌드를 이해하고 한발 먼저 행동하기 위해 식품 신문을 읽고 시장과 제품 조사를 하면서 빠른 변화에 적응하려고 노력했습니다. 그러면서 깨달은 것은 식품 산업이 무궁무진한 가능성을 가지고 있는 덕분에 다양한 방향성을 가지고 나아갈 수 있다는 것이었습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">오뚜기는 식품 산업 전반을 이끄는 기업입니다. 가능성을 봤을 때 언제든 뛰어들어 열풍을 이끌 수 있다고 오뚜기의 제품이 증명합니다.
# <br/>
# <br/>저는 식품 산업의 가능성을 확인하면서 가능한 방향성을 찾을 수 있었습니다. 그리고 그 방향성으로부터 원료와 제품에서 가치를 발굴하고 또다른 가치를 심어주는 것을 저의 목표로 하였습니다. <span class="sup">아쉬운점 2</span></b><b class="bad">신라면 두부김치, 열려라 참깨라면은 두가지 제품의 시너지 효과를, 전자레인지를 이용한 컵라면 조리방법은 새로운 즐거움을, 진짬뽕밥은 기존 제품에 새로운 가치를 이끌어냈습니다. OEM, ODM, 아웃소싱, 협업 등의 구조는 계속해서 발전하면서 좋은 제품을 위한 방법을 제시하고 가치를 창출할 수 있는 가능성이 증가시킵니다. 오징어 먹물을 넣은 검은색 비빔면, 시금치 페스토를 이용한 파스타 등 다양한 가치를 지녔지만 아직 발굴되지 않은 제품이 많다고 생각합니다. 새로움과 변화를 주도하는 오뚜기에서 저는 기존 제품의 가능성을 캐내고, 새로운 원료와 가능성에 가치를 심어 함께 발전하도록 하겠습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>787</strong>자</span><span><strong>1,359</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 이런 내용이 인사 담당자를 지치게 만드는 내용입니다. 그냥 식품 트렌드에 관심이 많아 관련 자료를 읽고 학습했다는 내용을 제시하고 그 속에서 지원자가 발견한 현 트렌드가 무엇인지만 말하면 됩니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 회사 지원동기에 해당되는 부분인데, 이 회사만의 동기는 아닙니다. 다른 유명회사 이름을 이 내용에 갖다 붙여도 틀린 내용이 아니라는 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 3</strong> 기존에 나온 제품보다 앞으로 본인이 개발할 제품이 무엇인지에 집중하는 것이 좋겠습니다. 왜 검은색 비빔면을 생각했고, 그것이 왜 제품성이 있는지, 이를 위해 본인의 어떤 지식, 능력을 활용할 수 있는지 등 앞으로 본인이 할 일에 대한 내용이 강조되는 방향이 좋겠습니다.</p>
# </div>
# </dd>
# </dl>
# </div>
# <div class="viewBtns">
# <a class="linkList" href="/starter/PassAssay?Page=1&amp;schTxt=%EC%84%A0%ED%83%9D%ED%95%9C&amp;OrderBy=0&amp;FavorCo_Stat=0&amp;isSaved=1&amp;Pass_An_Stat=0"><span class="stSpImg"></span>목록보기</a>
# <a class="pAssayWrite stSpBefore stSpAfter" data-cidx="196" data-cname="(주)오뚜기" href="javascript:void(0);">합격자소서 등록하면 <em>상품권 증정</em></a>
# </div>
# <div class="selfViewListsWrap" style="display:block">
# <div class="viewListsAtc">
# <h3 class="hd"><strong>‘(주)오뚜기’</strong>의 인기 합격자소서</h3>
# <ul class="lists">
# <li><a href="/starter/PassAssay/View/200655">2019년 하반기  <b>'생산관리·공정관리·품질관리'</b> </a><span class="readNum">25,423<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/166716">2016년 하반기  <b>'기획·전략·경영'</b> </a><span class="readNum">17,910<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/146816">2016년 하반기  <b>'인사·노무·교육'</b> </a><span class="readNum">15,738<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199264">2019년 상반기  <b>'구매·자재'</b> </a><span class="readNum">15,124<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/193150">2017년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">14,428<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199984">2019년 하반기  <b>'화학·에너지·환경'</b> </a><span class="readNum">13,889<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197168">2018년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">13,124<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/195512">2017년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">12,569<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/200093">2019년 상반기  <b>'영업관리·지원·영업기획'</b> </a><span class="readNum">12,090<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/145318">2014년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">10,989<span class="stSpImg">읽음</span></span></li>
# </ul>
# <a class="moreLink" href="/starter/PassAssay?schTxt=%28%EC%A3%BC%29%EC%98%A4%EB%9A%9C%EA%B8%B0&amp;isFilterChecked=0">전체보기<span class="stSpImg"></span></a>
# </div>
# <div class="viewListsAtc">
# <h3 class="hd"><strong>‘바이오·제약·식품’</strong>의 인기 합격자소서</h3>
# <ul class="lists">
# <li><a href="/starter/PassAssay/View/197420"><b>'(주)셀트리온'</b> 2018년 하반기 </a><span class="readNum">47,744<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197441"><b>'한국콜마홀딩스(주)'</b> 2018년 하반기 </a><span class="readNum">29,999<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199626"><b>'(주)세스코'</b> 2019년 하반기 </a><span class="readNum">24,578<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/200230"><b>'삼성바이오로직스(주)'</b> 2019년 하반기 </a><span class="readNum">23,522<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/201017"><b>'삼성바이오로직스(주)'</b> 2019년 하반기 </a><span class="readNum">22,282<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197445"><b>'일동홀딩스'</b> 2018년 하반기 </a><span class="readNum">15,202<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197769"><b>'차그룹'</b> 2018년 하반기 </a><span class="readNum">14,705<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197425"><b>'삼성바이오에피스(주)'</b> 2018년 하반기 </a><span class="readNum">13,725<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197970"><b>'(주)신세계푸드'</b> 2018년 하반기 </a><span class="readNum">12,002<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/198001"><b>'SPC'</b> 2018년 하반기 </a><span class="readNum">11,630<span class="stSpImg">읽음</span></span></li>
# </ul>
# </div>
# </div>
# <!-- //신입공채 컨텐츠 연결 -->
# <div class="otherListWrap">
# <h3 class="hd"><strong>‘(주)오뚜기’</strong> 다른 취업정보</h3>
# <div class="listTabArea">
# <!-- 탭 없을 경우 .listTab 비노출 -->
# <ul class="listTab">
# <!-- 활성화 클래스 li.on -->
# <li class="on"><a href="javascript:void(0);">합격스펙</a></li>
# <li><a href="javascript:void(0);">인적성·면접후기</a></li>
# </ul>
# <!-- //합격스펙 -->
# <div class="devStartlist listArea specList" style="display:block">
# <div class="averageSpec allContent">
# <!-- // 리스트 -->
# <div class="specListWrap">
# <p class="txInfo"><a href="/starter/spec/view?C_Idx=196">(주)오뚜기 <strong>합격스펙 분석</strong></a></p>
# <div class="totalList">
# <ul>
# <li>
# <div class="item">
# <strong class="tit">학점</strong>
# <span class="score"> <em>3.6</em>/4.5</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">토익</strong>
# <span class="score"> <em>810</em>점</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">토익스피킹</strong>
# <span class="score"> <em>Lv6</em></span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">OPIC</strong>
# <span class="score"> <em>IM3</em></span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">외국어(기타)</strong>
# <span class="score"> <em>1.1</em>개</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">자격증</strong>
# <span class="score"> <em>2.2</em>개</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">해외경험</strong>
# <span class="score"> <em>1.2</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">인턴</strong>
# <span class="score"> <em>1.2</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">수상내역</strong>
# <span class="score"> <em>1.4</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">교내/사회/봉사</strong>
# <span class="score"> <em>1.6</em>회</span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- 리스트 // -->
# <div class="myTotalResult">
# <!-- 그래프 영역-->
# <div class="totalRadar devGraphSupport">
# <div class="chart radar_avg">
# <canvas height="268" id="radar_btm" width="336"></canvas>
# </div>
# </div>
# <!-- 브라우저 지원 안될경우 -->
# <div class="notSupportBx devGraphNotSupport" style="display:none; ">
# <div class="notInner">
# <p class="tx"><span class="rowBx">IE9 미만 브라우저는 그래프가 지원되지 않습니다.</span> 그래프 활성화를 위해 브라우저를<br/> <strong>최신 버전으로 업데이트해주시거나, <br/>
# 다른 브라우저를 이용해주세요.</strong></p>
# <div class="notSptBxLink"><a href="https://support.microsoft.com/ko-kr#!ko-kr">업데이트</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 합격스펙// -->
# <!-- //인적성면접후기 -->
# <div class="devStartlist listArea reviewList" style="display:none">
# <ul>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">인적성후기</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">온라인 인적성이었기 때문에 집에서 봤습니다. 입사시험 치고는 굉장히 허술하다고 느꼈습니다. 응시자 얼굴 뿐만 아니라 손목과 바닥, 측면, 후면 등 모두 체크하지 않았습니다. 부정행위를 방지하기 위한 장치가 ...</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">인적성후기 9개 더보기<span class="stSpImg"></span></a></div>
# </li>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">면접질문</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">본인이 관리하는 점포에서 가격을 인하해달라고 요구한다면 어떻게 대처 할건가요?</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">면접질문 48개 더보기<span class="stSpImg"></span></a></div>
# </li>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">면접후기</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">오뚜기 본사에서 진행 10시.</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">면접후기 5개 더보기<span class="stSpImg"></span></a></div>
# </li>
# </ul>
# </div>
# <!-- 인적성면접후기// -->
# </div>
# <input id="devStartOtherListTab" type="hidden"/>
# </div>
# <!-- 신입공채 컨텐츠 연결// -->
# <script src="/Scripts/underscore.min.js" type="text/javascript"></script>
# <script src="/Scripts/Common/JK5cript.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/lib/raphael-2.2.0.min.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/chartnew.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/helper.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/chart.pi.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/chart.line.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/star_spec.min.js" type="text/javascript"></script>
# <script>
#     var logined = true;
#
#    $(function() {
#
#        var isBrowserGraphSupport = 1; // 브라우저 그래프 지원 (IE9 이하)
#
#        if (document.getElementById("radar_btm")) {
#            // IE 에물레이션 모드 인 경우 useragent 를 맞추지 않으면 체크가 안될 수 있어서 getContext 지원 확인
#            try {
#                document.getElementById("radar_btm").getContext("2d");
#                isBrowserGraphSupport = 1;
#            }
#
#            catch (e) {
#                isBrowserGraphSupport = 0;
#            }
#        }
#
#        // 브라우저 지원이 안되는 경우 미지원 그래프 표시
#        if (!isBrowserGraphSupport) {
#            $(".devGraphSupport").hide();
#            $(".devGraphNotSupport").show();
#        }
#
#
#         var radarOpt1 = {
#             animationSteps : 50,
#             graphTitle : "",
#             legend : false,
#             inGraphDataShow : false,
#             annotateDisplay : false,
#             graphTitleFontSize: 0,
#             angleLineColor: "rgba(220,227,233,1)",
#             angleLineWidth: 1,
#             pointLabelFontSize: 14
#         }
#
#
#         // 하단 다른취업정보 그래프
#         var radarBtmData = {
#             labels : [ "학점", "토익", "토익스피킹", "OPIC", "외국어(기타)", "자격증", "해외경험", "인턴", "수상내역", "교내/사회/봉사"],
#             datasets : [
#                 {
#                     fillColor : "rgba(51,153,255,0.1)",
#                     strokeColor : "rgba(115,186,255,1)",
#                     bordersWidth : 0.1,
#                     pointColor : "rgba(51,153,255,1)",
#                     data : [ 40, 40, 40, 39, 28, 37, 31, 30, 35, 27  ],
#                     datasetStrokeWidth: 1,
#                     pointDotRadius: 2
#                 },
#                     {
#                         fillColor : "transparent",
#                         strokeColor : "transparent",
#                         bordersWidth : 0,
#                         pointColor : "transparent",
#                         pointstrokeColor : "transparent",
#                         data : [ 0, 50, 50, 50, 50, 50, 50, 50, 50, 50  ],
#                         title : "",
#                         pointDotRadius: 0,
#                         pointDotStrokeWidth: 0
#                     }
#
#             ]
#         }
#
#        if (isBrowserGraphSupport && document.getElementById("radar_btm")) {
#            var radar_btm = new Chart(document.getElementById("radar_btm").getContext("2d")).Radar(radarBtmData,radarOpt1);
#        }
#
#         // sp보기 레이어
#         $('.starLyElWrap').starCommonLy();
#
#     });
# </script>
# <div class="cpWrap">
# <h2 class="hd"><strong>‘(주)오뚜기’</strong> 직원들이 졸업한 대학교는 어디일까요?</h2>
# <a class="moreLink" href="/careerpath/result?enterprise=1014601" onclick="ClickCountUp('88078')" target="_blank">커리어패스 자세히보기<span class="stSpImg"></span></a>
# <ul class="lists">
# <li>
# <span class="num">6</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0188" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="인하대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0188_70x70.gif"/>
# </span>
# <span class="txt">인하대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">7</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0232" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="한국외국어대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0232_70x70.gif"/>
# </span>
# <span class="txt">한국외국어대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">8</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0002" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="가천대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0002_70x70.gif"/>
# </span>
# <span class="txt">가천대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">9</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0012" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="경기대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0012_70x70.gif"/>
# </span>
# <span class="txt">경기대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">10</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0084" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="동아대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0084_70x70.gif"/>
# </span>
# <span class="txt">동아대학교</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <script>
#     function ClickCountUp(type) {
#         var logPath = "//m.jobkorea.co.kr/Link/default_JSON.asp?No=" + type;
#         $.ajax({
#             url: logPath,
#             method: "post",
#             dataType: "jsonp",
#             success: function () { }
#         });
#     }
# </script></div>

# %%
content = contents[0]
content
# Out:
# <div class="stContainer">
# <!-- starViewTit 추가 -->
# <h2 class="starViewTit">합격자소서</h2>
# <div class="selfTopBx">
# <div class="viewTitWrap">
# <h2 class="hd">
# <strong>
# <!--신입공채 페이지 호출방식변경-->
# <a href="https://www.jobkorea.co.kr/Recruit/Co_Read/C/ottogi " target="_blank" title="기업 홈 이동">(주)오뚜기</a>
# <!-- 스크랩 버튼추가. 기본클래스 off, 스크랩 되었을경우 클래스 off 삭제 on 추가 -->
# <button class="btnStarSc off btnFavorStat" type="button"><span class="stSpImg"></span><span class="skip">관심기업</span></button>
# <input id="hdnCId" name="CId" type="hidden" value="ottogi"/><input id="hdnMemSysNo" name="MemSysNo" type="hidden" value="264656"/> </strong><em>2020년 하반기 신입 바이오·제약·식품</em>합격자소서
#             </h2>
# <div class="btns">
# <!--<a href="#" class="linkGo stSpImg">기업 홈 가기</a>-->
# <a class="linkWrite stSpImg" href="//www.jobkorea.co.kr/SelfIntroduction/PassAssayView?PflNo=236312" target="_blank">자소서 작성</a>
# </div>
# </div>
# <div class="selfCtWrap">
# <h3 class="hd">합격자 정보</h3>
# <ul class="specLists">
# <li>수도권4년</li>
# <li>식품생명공학과</li>
# <li>학점 3.51/4.5</li>
# <li>토익 870</li>
# <li>자격증 2개</li>
# <li>인턴 2회</li>
# <li>동아리 1회</li>
# <li class="txViewNum">9,202<span class="stSpImg">읽음</span></li>
# </ul>
# </div>
# </div>
# <div class="adviceTotal">
# <div class="hd">
# <h3 class="tit">전문가 자소서 총평</h3>
# <span class="grade">
# <span class="stars lv02">
# <span class="down stSpImg"></span>
# <span class="up"></span>
# </span>
#                     2
#                 </span>
# </div>
# <p class="tx">지원자는 전체적으로 기승전결 방식으로 내용을 쓰고 있어 읽다 보면 답답함이 느껴진다는 점이 아쉽습니다. 지원자가 제시한 각종 이야기는 자기소개서의 핵심 내용이 될 수 없습니다. 그 이유는 지원자와 제시한 이야기 사례와 비슷한 타 지원자의 이야기가 많기 때문입니다. 하지만 질문에서 경험과 사례를 제시하라고 했으니 당연히 이야기는 써야 합니다. 결론이 앞에 나오는 것이 중요한 이유가 여기에 있습니다. 많은 지원자들이 비슷하게 쓰는 이야기를 인사 담당자들이 처음부터 읽다가 지치게 만드는 것보다 결론을 먼저 제시함으로써 어떤 이야기인지 미리 알려줄 수 있고, 핵심 위주로 읽게 유도함으로써  인사담당자도 편하게 하고 지원자도 자신이 말하고자 한 핵심을 알리는 역할을 한다는 것입니다. 그리고 전반적으로 내용이 불필요하게 복잡합니다.</p>
# </div>
# <div class="selfQnaWrap">
# <h3 class="skip">합격자소서 질문 및 내용</h3>
# <!--
#             페이지 로드시 질답 활성화 클래스
#             dt 클래스         : on
#             dd 클래스         : show
#             dd 다음 dt 클래스 : next
#          -->
# <dl class="qnaLists">
# <dt class="on">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q1.</span><span class="tx">지원직무를 선택한 이유를(직무와 관련한 경험, 전공, 수강과목, 자격증 등을 포함하여) 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="show">
# <strong class="skip">답변</strong>
# <div class="tx">
# "직접 만든다는 것"
# <br/>
# <br/><b class="bad">실습을 위해 콤부차를 조사하였습니다. 한정된 자료에서 최대한 조사했지만, 자세한 공정은 알 수 없었습니다. 좋은 결과를 도출하기 위해선 철저한 계획이 중요하다 생각돼 제조사, 제조공장에 문의하여 부원료 선택조건, 발효시간 등의 부분적인 답변을 들음으로 초안을 계획할 수 있었습니다. 이후 차 제조회사의 개발 업무에서 두 원료를 조합해 제품을 개발하는 업무에 참여했는데, 두 원료를 섞으면서 각각의 특색이 사라지는 문제가 있었습니다. 두 원료가 활성을 가지는 당도와 산도가 극과 극이었기 때문이었는데, 이전 실습을 위해 공정 조사를 문의할 때 조합이 좋을 것 같은데 왜 사용을 하지 않는지에 대한 답변을 실제로 경험하게 된 상황이었습니다. 두 원료의 황금비율을 찾는 것과 동시에 맛, 컨셉, 안정성 또한 유지하려 노력했습니다. 배합비를 수정하고 관능 검사하는 과정을 반복하면서 혀가 쓴맛을 즐기게 될 때쯤, 제품의 완성도가 갖춰져 두가지 원료를 조화롭게 느낄 수 있었습니다. 그리고 전화로 들었던 한계를 해결하는 듯한 성취감 또한 느꼈습니다. <span class="sup">아쉬운점 1</span></b>
# <br/>
# <br/><b class="bad">소비자 입장에서 왜 맛있는 두가지를 섞어 팔지 않는지에 대해 의구심을 가졌습니다. 하지만 식품을 전공하면서 의구심에 대한 답을 배우고, 개발을 하면서 해결방안을 찾았습니다. 주변을 둘러보면 많은 소비자들이 자신들이 자신이 원하는 제품을 기다리는 모습을 볼 수 있습니다. 모든 소비자가 식품을 전공하고 개발할 수 없기에 누군가가 소비자를 위해 제품을 만들어야 합니다. 그리고 저는 제가 얻은 지식과 경험으로 소비자를 위한 제품을 만들기 위해 노력하겠습니다.<span class="sup">아쉬운점 2</span></b> <p class="txSpllChk"><span>글자수 <strong>800</strong>자</span><span><strong>1,381</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 자기소개서는 질문에 답을 제대로 하는 것이 중요합니다. 구구절절한 스토리를 쓰는 것이 중요한 것이 아니라는 것입니다. 질문은 지원직무를 선택한 이유를 묻고 있습니다. 그렇다면 지원직무가 무엇인지 먼저 제시하고 왜 해당 직무를 선택했는지에 대한 결론을 제시해야 합니다. 지원자가 쓴 내용은 질문과 자연스럽게 이어지지도 않고, 결론적으로 왜 이 직무를 희망하는지도 쉽게 이해하기도 어렵습니다. 스토리는 스토리를 요구할 때 쓰면 됩니다/</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 지원직무 선택동기를 묻고 있는데, 앞으로의 계획과 포부로 마무리하고 있습니다. 질문과 제대로 의사소통이 되고 있지 않습니다.</p>
# </div>
# </dd>
# <dt class="on">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q2.</span><span class="tx">직장 또는 단체생활에서 구성원에게 가장 필요한 태도, 역량은 무엇이라고 생각하는지 본인의 경험을 바탕으로 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="show">
# <strong class="skip">답변</strong>
# <div class="tx">
# "각자의 경험이 다르다는 것"
# <br/>
# <br/><b class="bad">인턴기간에 동반성장을 목표로 새로운 메뉴를 개발하는 프로젝트에 참여했습니다. 기업간의 협업으로, 각자가 잘 하는 방식으로 자신의 역할에 최선을 다했어야 했기에 초기 아이디어 회의에서부터 많은 의견이 나왔습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">30개의 아이디어는 각각 매력과 가능성을 가지고 있었지만 가장 좋은 것을 선별해야 했습니다. 먼저 1차적인 선별을 위해 시장조사와 제조공정을 파악하여 대중성이 있고, 자체 개발이 가능한 제품을 선별했습니다. 이 과정에서 저는 팀으로 협력하면서 팀 구성원에게 필요한 태도를 배울 수 있었는데, 바로, 각자의 역할을 수행하고, 서로의 접근방식을 공유하고 수용하며 해답을 찾는 것입니다. <span class="sup">아쉬운점 2</span></b><b class="bad">저는 프로젝트에서 소비자들의 소비형태와 그에 따른 시장의 동향을 조사하였고, 이를 요약하여 팀원들에게 분배했습니다. 그리고 팀원들은 받은 자료를 토대로 각자가 담당하던 제품과 연관된 소재를 구체화하였고, 마지막으로 팀장이 단가, 공정 등 세부사항을 판단하여 좋은 주제를 간추렸습니다.
# <br/>
# <br/>기업간 협업에서 각자가 잘하는 방식으로 역할에 최선을 다하듯 팀 구성원도 자신의 역할에 충실하여 효율을 높일 수 있었습니다. 또한, 아이디어 회의에서부터 매일 1회 이상 프로젝트 회의를 진행하면서 비슷한 상황에서 창의적, 효과적으로 해결할 수 있었던 각자의 방법을 서로 제시하고 실천하여 효율적으로 업무를 진행하였습니다. 결과적으로, 각자의 경험이 다르다는 것은 다양한 시선과 방법이 다양하다는 것으로, 관점과 방법을 제시하고 수용하면서 함께 발전할 수 있다는 점에서 팀에게 가장 필요한 태도이자 역량이라고 생각하였습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>803</strong>자</span><span><strong>1,398</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 자기소개서는 기승전결식의 이야기가 아니라 질문에 대한 답을 먼저 제시하고 그에 대한 근거를 제시하는 방식이 더 읽기 쉬운 내용입니다. 즉, 직장 또는 단체생활에서 구성원에게 가장 필요한 태도가 무엇인지를 먼저 제시하고 왜 그렇게 생각하는 지를 쓴 다음 이와 관련한 경험을 제시하는 순서로 쓰는 것이 더 읽기 편한 내용이라는 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 이 부분에서 지원자는 협업에서 필요한 점을 언급하고 있는데 그 방식이 불필요하게 복잡합니다. 핵심은 생각을 공유하는 것임을 먼저 구체적으로 설명하고 수용에 대한 내용은 뒤에 설명하는 것이 더 집중도를 높이는 방향일 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 3</strong> 무엇을 말하고자 하는지는 잘 알겠지만, 전체적으로 내용이 복잡하게 설명되어 있습니다. 그리고 질문은 단체생활에서 구성원에게 필요한 태도와 역량을 묻고 있는데, 지원자는 협업의 관점에서만 이야기를 하고 있습니다. 즉, 질문에서 협업에서의 태도와 역할을 묻지 않았는데, 지원자는 그렇게 이해했다는 것입니다. 질문과 내용이 정확하게 맞지 않습니다.</p>
# </div>
# </dd>
# <dt class="next">
# <button type="button"><strong class="skip">질문</strong><span class="num">Q3.</span><span class="tx">오뚜기에 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 설명하십시오.</span><span class="arr stSpImg">보기</span></button>
# </dt>
# <dd class="">
# <strong class="skip">답변</strong>
# <div class="tx">
# "가능성을 캐내고 가치를 심자"
# <br/>
# <br/><b class="bad">식품은 광범위한 방면에서 다양한 방향성을 가지고 나아가고 있기 때문에 대학에 오랜 기간에 걸쳐 쌓인 지식으로는 현재 식품 시장을 온전히 이해할 수 없다고 생각했습니다. 우물 안 개구리에서 벗어나 트렌드를 이해하고 한발 먼저 행동하기 위해 식품 신문을 읽고 시장과 제품 조사를 하면서 빠른 변화에 적응하려고 노력했습니다. 그러면서 깨달은 것은 식품 산업이 무궁무진한 가능성을 가지고 있는 덕분에 다양한 방향성을 가지고 나아갈 수 있다는 것이었습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">오뚜기는 식품 산업 전반을 이끄는 기업입니다. 가능성을 봤을 때 언제든 뛰어들어 열풍을 이끌 수 있다고 오뚜기의 제품이 증명합니다.
# <br/>
# <br/>저는 식품 산업의 가능성을 확인하면서 가능한 방향성을 찾을 수 있었습니다. 그리고 그 방향성으로부터 원료와 제품에서 가치를 발굴하고 또다른 가치를 심어주는 것을 저의 목표로 하였습니다. <span class="sup">아쉬운점 2</span></b><b class="bad">신라면 두부김치, 열려라 참깨라면은 두가지 제품의 시너지 효과를, 전자레인지를 이용한 컵라면 조리방법은 새로운 즐거움을, 진짬뽕밥은 기존 제품에 새로운 가치를 이끌어냈습니다. OEM, ODM, 아웃소싱, 협업 등의 구조는 계속해서 발전하면서 좋은 제품을 위한 방법을 제시하고 가치를 창출할 수 있는 가능성이 증가시킵니다. 오징어 먹물을 넣은 검은색 비빔면, 시금치 페스토를 이용한 파스타 등 다양한 가치를 지녔지만 아직 발굴되지 않은 제품이 많다고 생각합니다. 새로움과 변화를 주도하는 오뚜기에서 저는 기존 제품의 가능성을 캐내고, 새로운 원료와 가능성에 가치를 심어 함께 발전하도록 하겠습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>787</strong>자</span><span><strong>1,359</strong>Byte</span></p>
# </div>
# <div class="advice">
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 1</strong> 이런 내용이 인사 담당자를 지치게 만드는 내용입니다. 그냥 식품 트렌드에 관심이 많아 관련 자료를 읽고 학습했다는 내용을 제시하고 그 속에서 지원자가 발견한 현 트렌드가 무엇인지만 말하면 됩니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 2</strong> 회사 지원동기에 해당되는 부분인데, 이 회사만의 동기는 아닙니다. 다른 유명회사 이름을 이 내용에 갖다 붙여도 틀린 내용이 아니라는 것입니다.</p>
# <p><strong class="bad stSpBefore stSpAfter">아쉬운점 3</strong> 기존에 나온 제품보다 앞으로 본인이 개발할 제품이 무엇인지에 집중하는 것이 좋겠습니다. 왜 검은색 비빔면을 생각했고, 그것이 왜 제품성이 있는지, 이를 위해 본인의 어떤 지식, 능력을 활용할 수 있는지 등 앞으로 본인이 할 일에 대한 내용이 강조되는 방향이 좋겠습니다.</p>
# </div>
# </dd>
# </dl>
# </div>
# <div class="viewBtns">
# <a class="linkList" href="/starter/PassAssay?Page=1&amp;schTxt=%EC%84%A0%ED%83%9D%ED%95%9C&amp;OrderBy=0&amp;FavorCo_Stat=0&amp;isSaved=1&amp;Pass_An_Stat=0"><span class="stSpImg"></span>목록보기</a>
# <a class="pAssayWrite stSpBefore stSpAfter" data-cidx="196" data-cname="(주)오뚜기" href="javascript:void(0);">합격자소서 등록하면 <em>상품권 증정</em></a>
# </div>
# <div class="selfViewListsWrap" style="display:block">
# <div class="viewListsAtc">
# <h3 class="hd"><strong>‘(주)오뚜기’</strong>의 인기 합격자소서</h3>
# <ul class="lists">
# <li><a href="/starter/PassAssay/View/200655">2019년 하반기  <b>'생산관리·공정관리·품질관리'</b> </a><span class="readNum">25,423<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/166716">2016년 하반기  <b>'기획·전략·경영'</b> </a><span class="readNum">17,910<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/146816">2016년 하반기  <b>'인사·노무·교육'</b> </a><span class="readNum">15,738<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199264">2019년 상반기  <b>'구매·자재'</b> </a><span class="readNum">15,124<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/193150">2017년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">14,428<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199984">2019년 하반기  <b>'화학·에너지·환경'</b> </a><span class="readNum">13,889<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197168">2018년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">13,124<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/195512">2017년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">12,569<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/200093">2019년 상반기  <b>'영업관리·지원·영업기획'</b> </a><span class="readNum">12,090<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/145318">2014년 하반기  <b>'제품·서비스영업'</b> </a><span class="readNum">10,989<span class="stSpImg">읽음</span></span></li>
# </ul>
# <a class="moreLink" href="/starter/PassAssay?schTxt=%28%EC%A3%BC%29%EC%98%A4%EB%9A%9C%EA%B8%B0&amp;isFilterChecked=0">전체보기<span class="stSpImg"></span></a>
# </div>
# <div class="viewListsAtc">
# <h3 class="hd"><strong>‘바이오·제약·식품’</strong>의 인기 합격자소서</h3>
# <ul class="lists">
# <li><a href="/starter/PassAssay/View/197420"><b>'(주)셀트리온'</b> 2018년 하반기 </a><span class="readNum">47,744<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197441"><b>'한국콜마홀딩스(주)'</b> 2018년 하반기 </a><span class="readNum">29,999<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/199626"><b>'(주)세스코'</b> 2019년 하반기 </a><span class="readNum">24,578<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/200230"><b>'삼성바이오로직스(주)'</b> 2019년 하반기 </a><span class="readNum">23,522<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/201017"><b>'삼성바이오로직스(주)'</b> 2019년 하반기 </a><span class="readNum">22,282<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197445"><b>'일동홀딩스'</b> 2018년 하반기 </a><span class="readNum">15,202<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197769"><b>'차그룹'</b> 2018년 하반기 </a><span class="readNum">14,705<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197425"><b>'삼성바이오에피스(주)'</b> 2018년 하반기 </a><span class="readNum">13,725<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/197970"><b>'(주)신세계푸드'</b> 2018년 하반기 </a><span class="readNum">12,002<span class="stSpImg">읽음</span></span></li>
# <li><a href="/starter/PassAssay/View/198001"><b>'SPC'</b> 2018년 하반기 </a><span class="readNum">11,630<span class="stSpImg">읽음</span></span></li>
# </ul>
# </div>
# </div>
# <!-- //신입공채 컨텐츠 연결 -->
# <div class="otherListWrap">
# <h3 class="hd"><strong>‘(주)오뚜기’</strong> 다른 취업정보</h3>
# <div class="listTabArea">
# <!-- 탭 없을 경우 .listTab 비노출 -->
# <ul class="listTab">
# <!-- 활성화 클래스 li.on -->
# <li class="on"><a href="javascript:void(0);">합격스펙</a></li>
# <li><a href="javascript:void(0);">인적성·면접후기</a></li>
# </ul>
# <!-- //합격스펙 -->
# <div class="devStartlist listArea specList" style="display:block">
# <div class="averageSpec allContent">
# <!-- // 리스트 -->
# <div class="specListWrap">
# <p class="txInfo"><a href="/starter/spec/view?C_Idx=196">(주)오뚜기 <strong>합격스펙 분석</strong></a></p>
# <div class="totalList">
# <ul>
# <li>
# <div class="item">
# <strong class="tit">학점</strong>
# <span class="score"> <em>3.6</em>/4.5</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">토익</strong>
# <span class="score"> <em>810</em>점</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">토익스피킹</strong>
# <span class="score"> <em>Lv6</em></span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">OPIC</strong>
# <span class="score"> <em>IM3</em></span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">외국어(기타)</strong>
# <span class="score"> <em>1.1</em>개</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">자격증</strong>
# <span class="score"> <em>2.2</em>개</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">해외경험</strong>
# <span class="score"> <em>1.2</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">인턴</strong>
# <span class="score"> <em>1.2</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">수상내역</strong>
# <span class="score"> <em>1.4</em>회</span>
# </div>
# </li>
# <li>
# <div class="item">
# <strong class="tit">교내/사회/봉사</strong>
# <span class="score"> <em>1.6</em>회</span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <!-- 리스트 // -->
# <div class="myTotalResult">
# <!-- 그래프 영역-->
# <div class="totalRadar devGraphSupport">
# <div class="chart radar_avg">
# <canvas height="268" id="radar_btm" width="336"></canvas>
# </div>
# </div>
# <!-- 브라우저 지원 안될경우 -->
# <div class="notSupportBx devGraphNotSupport" style="display:none; ">
# <div class="notInner">
# <p class="tx"><span class="rowBx">IE9 미만 브라우저는 그래프가 지원되지 않습니다.</span> 그래프 활성화를 위해 브라우저를<br/> <strong>최신 버전으로 업데이트해주시거나, <br/>
# 다른 브라우저를 이용해주세요.</strong></p>
# <div class="notSptBxLink"><a href="https://support.microsoft.com/ko-kr#!ko-kr">업데이트</a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 합격스펙// -->
# <!-- //인적성면접후기 -->
# <div class="devStartlist listArea reviewList" style="display:none">
# <ul>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">인적성후기</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">온라인 인적성이었기 때문에 집에서 봤습니다. 입사시험 치고는 굉장히 허술하다고 느꼈습니다. 응시자 얼굴 뿐만 아니라 손목과 바닥, 측면, 후면 등 모두 체크하지 않았습니다. 부정행위를 방지하기 위한 장치가 ...</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=2">인적성후기 9개 더보기<span class="stSpImg"></span></a></div>
# </li>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">면접질문</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">본인이 관리하는 점포에서 가격을 인하해달라고 요구한다면 어떻게 대처 할건가요?</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=5">면접질문 48개 더보기<span class="stSpImg"></span></a></div>
# </li>
# <li>
# <div class="ctgr"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">면접후기</a></div>
# <div class="tx"><a href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">오뚜기 본사에서 진행 10시.</a></div>
# <div class="moreBtns"><a class="linkList" href="/starter/review/view?C_Idx=196&amp;Ctgr_Code=3">면접후기 5개 더보기<span class="stSpImg"></span></a></div>
# </li>
# </ul>
# </div>
# <!-- 인적성면접후기// -->
# </div>
# <input id="devStartOtherListTab" type="hidden"/>
# </div>
# <!-- 신입공채 컨텐츠 연결// -->
# <script src="/Scripts/underscore.min.js" type="text/javascript"></script>
# <script src="/Scripts/Common/JK5cript.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/lib/raphael-2.2.0.min.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/chartnew.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/helper.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/chart.pi.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/chart.line.js" type="text/javascript"></script>
# <script src="https://i.jobkorea.kr/content/js/starter/spec/pc/star_spec.min.js" type="text/javascript"></script>
# <script>
#     var logined = true;
#
#    $(function() {
#
#        var isBrowserGraphSupport = 1; // 브라우저 그래프 지원 (IE9 이하)
#
#        if (document.getElementById("radar_btm")) {
#            // IE 에물레이션 모드 인 경우 useragent 를 맞추지 않으면 체크가 안될 수 있어서 getContext 지원 확인
#            try {
#                document.getElementById("radar_btm").getContext("2d");
#                isBrowserGraphSupport = 1;
#            }
#
#            catch (e) {
#                isBrowserGraphSupport = 0;
#            }
#        }
#
#        // 브라우저 지원이 안되는 경우 미지원 그래프 표시
#        if (!isBrowserGraphSupport) {
#            $(".devGraphSupport").hide();
#            $(".devGraphNotSupport").show();
#        }
#
#
#         var radarOpt1 = {
#             animationSteps : 50,
#             graphTitle : "",
#             legend : false,
#             inGraphDataShow : false,
#             annotateDisplay : false,
#             graphTitleFontSize: 0,
#             angleLineColor: "rgba(220,227,233,1)",
#             angleLineWidth: 1,
#             pointLabelFontSize: 14
#         }
#
#
#         // 하단 다른취업정보 그래프
#         var radarBtmData = {
#             labels : [ "학점", "토익", "토익스피킹", "OPIC", "외국어(기타)", "자격증", "해외경험", "인턴", "수상내역", "교내/사회/봉사"],
#             datasets : [
#                 {
#                     fillColor : "rgba(51,153,255,0.1)",
#                     strokeColor : "rgba(115,186,255,1)",
#                     bordersWidth : 0.1,
#                     pointColor : "rgba(51,153,255,1)",
#                     data : [ 40, 40, 40, 39, 28, 37, 31, 30, 35, 27  ],
#                     datasetStrokeWidth: 1,
#                     pointDotRadius: 2
#                 },
#                     {
#                         fillColor : "transparent",
#                         strokeColor : "transparent",
#                         bordersWidth : 0,
#                         pointColor : "transparent",
#                         pointstrokeColor : "transparent",
#                         data : [ 0, 50, 50, 50, 50, 50, 50, 50, 50, 50  ],
#                         title : "",
#                         pointDotRadius: 0,
#                         pointDotStrokeWidth: 0
#                     }
#
#             ]
#         }
#
#        if (isBrowserGraphSupport && document.getElementById("radar_btm")) {
#            var radar_btm = new Chart(document.getElementById("radar_btm").getContext("2d")).Radar(radarBtmData,radarOpt1);
#        }
#
#         // sp보기 레이어
#         $('.starLyElWrap').starCommonLy();
#
#     });
# </script>
# <div class="cpWrap">
# <h2 class="hd"><strong>‘(주)오뚜기’</strong> 직원들이 졸업한 대학교는 어디일까요?</h2>
# <a class="moreLink" href="/careerpath/result?enterprise=1014601" onclick="ClickCountUp('88078')" target="_blank">커리어패스 자세히보기<span class="stSpImg"></span></a>
# <ul class="lists">
# <li>
# <span class="num">6</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0188" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="인하대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0188_70x70.gif"/>
# </span>
# <span class="txt">인하대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">7</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0232" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="한국외국어대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0232_70x70.gif"/>
# </span>
# <span class="txt">한국외국어대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">8</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0002" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="가천대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0002_70x70.gif"/>
# </span>
# <span class="txt">가천대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">9</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0012" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="경기대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0012_70x70.gif"/>
# </span>
# <span class="txt">경기대학교</span>
# </span>
# </a>
# </li>
# <li>
# <span class="num">10</span><!-- 1,2,3위만 top 클래스 추가 -->
# <a class="link" href="/CareerPath/result?school=U0084" onclick="ClickCountUp('88079')" target="_blank">
# <span class="listCnt">
# <span class="logo">
# <img alt="동아대학교" src="//file2.jobkorea.co.kr/Net/SchoolMng/LogoView?FN=Univ\U0084_70x70.gif"/>
# </span>
# <span class="txt">동아대학교</span>
# </span>
# </a>
# </li>
# </ul>
# </div>
# <script>
#     function ClickCountUp(type) {
#         var logPath = "//m.jobkorea.co.kr/Link/default_JSON.asp?No=" + type;
#         $.ajax({
#             url: logPath,
#             method: "post",
#             dataType: "jsonp",
#             success: function () { }
#         });
#     }
# </script></div>

# %%
question = content.select('button > span.tx')
question
# Out:
# [<span class="tx">지원직무를 선택한 이유를(직무와 관련한 경험, 전공, 수강과목, 자격증 등을 포함하여) 설명하십시오.</span>,
#  <span class="tx">직장 또는 단체생활에서 구성원에게 가장 필요한 태도, 역량은 무엇이라고 생각하는지 본인의 경험을 바탕으로 설명하십시오.</span>,
#  <span class="tx">오뚜기에 지원한 이유와 입사 후 회사에서 이루고 싶은 꿈을 설명하십시오.</span>]

# %%
answer = content.select('dd > div.tx')
answer
# Out:
# [<div class="tx">
#  "직접 만든다는 것"
#  <br/>
#  <br/><b class="bad">실습을 위해 콤부차를 조사하였습니다. 한정된 자료에서 최대한 조사했지만, 자세한 공정은 알 수 없었습니다. 좋은 결과를 도출하기 위해선 철저한 계획이 중요하다 생각돼 제조사, 제조공장에 문의하여 부원료 선택조건, 발효시간 등의 부분적인 답변을 들음으로 초안을 계획할 수 있었습니다. 이후 차 제조회사의 개발 업무에서 두 원료를 조합해 제품을 개발하는 업무에 참여했는데, 두 원료를 섞으면서 각각의 특색이 사라지는 문제가 있었습니다. 두 원료가 활성을 가지는 당도와 산도가 극과 극이었기 때문이었는데, 이전 실습을 위해 공정 조사를 문의할 때 조합이 좋을 것 같은데 왜 사용을 하지 않는지에 대한 답변을 실제로 경험하게 된 상황이었습니다. 두 원료의 황금비율을 찾는 것과 동시에 맛, 컨셉, 안정성 또한 유지하려 노력했습니다. 배합비를 수정하고 관능 검사하는 과정을 반복하면서 혀가 쓴맛을 즐기게 될 때쯤, 제품의 완성도가 갖춰져 두가지 원료를 조화롭게 느낄 수 있었습니다. 그리고 전화로 들었던 한계를 해결하는 듯한 성취감 또한 느꼈습니다. <span class="sup">아쉬운점 1</span></b>
#  <br/>
#  <br/><b class="bad">소비자 입장에서 왜 맛있는 두가지를 섞어 팔지 않는지에 대해 의구심을 가졌습니다. 하지만 식품을 전공하면서 의구심에 대한 답을 배우고, 개발을 하면서 해결방안을 찾았습니다. 주변을 둘러보면 많은 소비자들이 자신들이 자신이 원하는 제품을 기다리는 모습을 볼 수 있습니다. 모든 소비자가 식품을 전공하고 개발할 수 없기에 누군가가 소비자를 위해 제품을 만들어야 합니다. 그리고 저는 제가 얻은 지식과 경험으로 소비자를 위한 제품을 만들기 위해 노력하겠습니다.<span class="sup">아쉬운점 2</span></b> <p class="txSpllChk"><span>글자수 <strong>800</strong>자</span><span><strong>1,381</strong>Byte</span></p>
#  </div>,
#  <div class="tx">
#  "각자의 경험이 다르다는 것"
#  <br/>
#  <br/><b class="bad">인턴기간에 동반성장을 목표로 새로운 메뉴를 개발하는 프로젝트에 참여했습니다. 기업간의 협업으로, 각자가 잘 하는 방식으로 자신의 역할에 최선을 다했어야 했기에 초기 아이디어 회의에서부터 많은 의견이 나왔습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">30개의 아이디어는 각각 매력과 가능성을 가지고 있었지만 가장 좋은 것을 선별해야 했습니다. 먼저 1차적인 선별을 위해 시장조사와 제조공정을 파악하여 대중성이 있고, 자체 개발이 가능한 제품을 선별했습니다. 이 과정에서 저는 팀으로 협력하면서 팀 구성원에게 필요한 태도를 배울 수 있었는데, 바로, 각자의 역할을 수행하고, 서로의 접근방식을 공유하고 수용하며 해답을 찾는 것입니다. <span class="sup">아쉬운점 2</span></b><b class="bad">저는 프로젝트에서 소비자들의 소비형태와 그에 따른 시장의 동향을 조사하였고, 이를 요약하여 팀원들에게 분배했습니다. 그리고 팀원들은 받은 자료를 토대로 각자가 담당하던 제품과 연관된 소재를 구체화하였고, 마지막으로 팀장이 단가, 공정 등 세부사항을 판단하여 좋은 주제를 간추렸습니다.
#  <br/>
#  <br/>기업간 협업에서 각자가 잘하는 방식으로 역할에 최선을 다하듯 팀 구성원도 자신의 역할에 충실하여 효율을 높일 수 있었습니다. 또한, 아이디어 회의에서부터 매일 1회 이상 프로젝트 회의를 진행하면서 비슷한 상황에서 창의적, 효과적으로 해결할 수 있었던 각자의 방법을 서로 제시하고 실천하여 효율적으로 업무를 진행하였습니다. 결과적으로, 각자의 경험이 다르다는 것은 다양한 시선과 방법이 다양하다는 것으로, 관점과 방법을 제시하고 수용하면서 함께 발전할 수 있다는 점에서 팀에게 가장 필요한 태도이자 역량이라고 생각하였습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>803</strong>자</span><span><strong>1,398</strong>Byte</span></p>
#  </div>,
#  <div class="tx">
#  "가능성을 캐내고 가치를 심자"
#  <br/>
#  <br/><b class="bad">식품은 광범위한 방면에서 다양한 방향성을 가지고 나아가고 있기 때문에 대학에 오랜 기간에 걸쳐 쌓인 지식으로는 현재 식품 시장을 온전히 이해할 수 없다고 생각했습니다. 우물 안 개구리에서 벗어나 트렌드를 이해하고 한발 먼저 행동하기 위해 식품 신문을 읽고 시장과 제품 조사를 하면서 빠른 변화에 적응하려고 노력했습니다. 그러면서 깨달은 것은 식품 산업이 무궁무진한 가능성을 가지고 있는 덕분에 다양한 방향성을 가지고 나아갈 수 있다는 것이었습니다. <span class="sup">아쉬운점 1</span></b><b class="bad">오뚜기는 식품 산업 전반을 이끄는 기업입니다. 가능성을 봤을 때 언제든 뛰어들어 열풍을 이끌 수 있다고 오뚜기의 제품이 증명합니다.
#  <br/>
#  <br/>저는 식품 산업의 가능성을 확인하면서 가능한 방향성을 찾을 수 있었습니다. 그리고 그 방향성으로부터 원료와 제품에서 가치를 발굴하고 또다른 가치를 심어주는 것을 저의 목표로 하였습니다. <span class="sup">아쉬운점 2</span></b><b class="bad">신라면 두부김치, 열려라 참깨라면은 두가지 제품의 시너지 효과를, 전자레인지를 이용한 컵라면 조리방법은 새로운 즐거움을, 진짬뽕밥은 기존 제품에 새로운 가치를 이끌어냈습니다. OEM, ODM, 아웃소싱, 협업 등의 구조는 계속해서 발전하면서 좋은 제품을 위한 방법을 제시하고 가치를 창출할 수 있는 가능성이 증가시킵니다. 오징어 먹물을 넣은 검은색 비빔면, 시금치 페스토를 이용한 파스타 등 다양한 가치를 지녔지만 아직 발굴되지 않은 제품이 많다고 생각합니다. 새로움과 변화를 주도하는 오뚜기에서 저는 기존 제품의 가능성을 캐내고, 새로운 원료와 가능성에 가치를 심어 함께 발전하도록 하겠습니다.<span class="sup">아쉬운점 3</span></b> <p class="txSpllChk"><span>글자수 <strong>787</strong>자</span><span><strong>1,359</strong>Byte</span></p>
#  </div>]

# %%
question.text.strip(), answer.text.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-04496bb64c4c> in <module>
# ----> 1 question.text.strip(), answer.text.strip()
#
# C:\anaconda\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
contents = [] 
for content in contents:
    questions = soup.select('button > span.tx')[0]
    answers = soup.select('dd > div.tx')[0]
    print(questions.text.strip(), answers.text.strip())
    contents.append([questions.text.strip(), answers.text.strip()])
contents
# Out:
# []

# %% [markdown]
# ## 일단 위에까지....ㅠ

# %%
contents = []
for i in range(1,21):
    browser.find_element_by_css_selector('li:nth-child('+str(i)+') > div.txBx > p > a > span').click()
    html = browser.page_source
    soup = BeautifulSoup(html, 'html.parser')
    time.sleep(1)
    
    introduction_page = soup.select('div.stContainer')
    introduction_page[0]
    company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
    score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
    group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()

# %%
contents = []
for i in range(1,21):
    browser.find_element_by_css_selector('li:nth-child('+str(i)+') > div.txBx > p > a > span').click()
    soup=BeautifulSoup(browser.page_source,'html.parser')
    time.sleep(1)
    introduction_page = soup.select('div.stContainer')
    introduction_page[0]
    company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
    score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
    group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
    Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
    A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
    Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
    A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
    Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
    A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
    Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
    A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
    result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4]
    contents.append(result)
    contents
    df = pd.DataFrame(contents,columns=['company', 'score', 'group', 'Q1', 'A1', 'Q2', 'A2', 'Q3', 'A3', 'Q4', 'A4'])
    
    browser.back()

       
    
    
# for scraping in introduction_page:
#     company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
#     score = introduction_page[0].select('div.adviceTotal > div > span').text.strip()
#     group = introduction_page[0].select('div.adviceTotal > p').text.strip()
#     Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx').text.strip()
#     A1 = introduction_page[0].select('dd:nth-child(2) > div.tx').text.strip()
#     Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx').text.strip()
#     A2 = introduction_page[0].select('dd:nth-child(4) > div.tx').text.strip()
#     Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx').text.strip()
#     A3 = introduction_page[0].select('dd:nth-child(6) > div.tx').text.strip()
#     Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx').text.strip()
#     A4 = introduction_page[0].select('dd:nth-child(8) > div.tx').text.strip()    
#     contents.append(result)
# contents

# df = pd.DataFrame(contents,columns=['company', 'score', 'group', 'Q1', 'A1', 'Q2', 'A2', 'Q3', 'A3', 'Q4', 'A4'])
# df

# %%
contents = []
for i in range(1,2):
    browser.find_element_by_css_selector('li:nth-child('+str(i)+') > div.txBx > p > a > span').click()
    browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
    browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()
    time.sleep(1)
    
    introduction_page = browser.find_element_by_css_selector('li:nth-child('+str(i)+') > div.txBx > p > a > span').click()
    introduction_page[0]
    company = introduction_page[0].select('div.viewTitWrap').text.strip()
    score = introduction_page[0].select('div.adviceTotal > div > span').text.strip()
    group = introduction_page[0].select('div.adviceTotal > p').text.strip()
    Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx').text.strip()
    A1 = introduction_page[0].select('dd:nth-child(2) > div.tx').text.strip()
    Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx').text.strip()
    A2 = introduction_page[0].select('dd:nth-child(4) > div.tx').text.strip()
    Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx').text.strip()
    A3 = introduction_page[0].select('dd:nth-child(6) > div.tx').text.strip()
    Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx').text.strip()
    A4 = introduction_page[0].select('dd:nth-child(8) > div.tx').text.strip()    
    result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4]
    contents.append(result)
    contents
    df = pd.DataFrame(contents,columns=['company', 'score', 'group', 'Q1', 'A1', 'Q2', 'A2', 'Q3', 'A3', 'Q4', 'A4'])
    

    browser.back()

# %%
df

# %%
contents = []

company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()

# html = browser.page_source
# soup = BeautifulSoup(html, 'html.parser')
# introduction_page = soup.select('div.stContainer')
# browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
# browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()

# for page in range(1,20):
#     target = page1+str(page)+page2
#     print(target)
#     browser.target
#     html = browser.page_source
#     soup = BeautifulSoup(html, 'html.parser')
#     introduction_page = soup.select('div.stContainer')
#     browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
#     browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()
        
    
#     for scraping in introduction_page:
#         company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
#         score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
#         group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
#         Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
#         A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
#         Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
#         A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
#         Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
#         A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
#         Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
#         A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
#         result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4 ]
#         contents.append(result)
#         browser.back()

# %%
browser.find_element_by_css_selector('span.titTx').click()
introduction_page = soup.select('div.stContainer')
browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()
introduction_page[0]

# %%
contents = []

for scraping in introduction_page:
    company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
    score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
    group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
    Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
    A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
    Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
    A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
    Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
    A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
    Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
    A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
    result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4]
    contents.append(result)

contents

# %%
browser.find_element_by_css_selector('span.titTx').click()
introduction_page = soup.select('div.stContainer')
browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()
company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
contents = []

for scraping in introduction_page:
    company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
    score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
    group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
    Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
    A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
    Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
    A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
    Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
    A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
    Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
    A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
    result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4 ]
    contents.append(result)
    
browser.back()
contents

# %%
browser.find_element_by_css_selector('span.titTx').click()
introduction_page = soup.select('div.stContainer')
browser.find_element_by_css_selector('dt:nth-child(5) > button > span.tx').click()
browser.find_element_by_css_selector('dt:nth-child(7) > button > span.tx').click()
company = introduction_page[0].select('div.viewTitWrap')[0].text.strip()
score = introduction_page[0].select('div.adviceTotal > div > span')[0].text.strip()
group = introduction_page[0].select('div.adviceTotal > p')[0].text.strip()
Q1 = introduction_page[0].select('dt:nth-child(1) > button > span.tx')[0].text.strip()
A1 = introduction_page[0].select('dd:nth-child(2) > div.tx')[0].text.strip()
Q2 = introduction_page[0].select('dt:nth-child(3) > button > span.tx')[0].text.strip()
A2 = introduction_page[0].select('dd:nth-child(4) > div.tx')[0].text.strip()
Q3 = introduction_page[0].select('dt:nth-child(5) > button > span.tx')[0].text.strip()
A3 = introduction_page[0].select('dd:nth-child(6) > div.tx')[0].text.strip()
Q4 = introduction_page[0].select('dt:nth-child(7) > button > span.tx')[0].text.strip()
A4 = introduction_page[0].select('dd:nth-child(8) > div.tx')[0].text.strip()
result = [company, score, group, Q1, A1, Q2, A2, Q3, A3, Q4, A4 ]
contents.append(result)

# %%
import pandas as pd
df = pd.DataFrame(contents,columns=['company', 'group', 'group', 'Q1', 'A1', 'Q2', 'A2', 'Q3', 'A3', 'Q4', 'A4'])

# %%
df
