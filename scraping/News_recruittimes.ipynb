# %% [markdown]
# http://www.recruittimes.co.kr/news/articleList.html?view_type=sm
#
# section.article-list-content.type-sm.text-left 기사들 부분 전체
#
# div.list-block 각 기사
#
# ul.pagination.text-center 페이지
#
# div.float-center.max-width-1080 기사 내용
#
# div.article-head-title 제목
#
# div#article-view-content-div 내용

# %%
from selenium import webdriver
browser = webdriver.Chrome('./chromedriver.exe')

# %%
browser.get('http://www.recruittimes.co.kr/news/articleList.html?view_type=sm')
html = browser.page_source
html
# Out:
# '<html class="whatinput-types-initial" lang="ko" dir="ltr" data-whatinput="initial" data-whatintent="mouse"><head><script src="http://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=1080">\n<meta name="apple-mobile-web-app-title" content="리크루트타임스">\n<meta name="google-site-verification" content="YCQn7uGpNvRGA_1A2dmXGovbszh7TdUYOxmnQRKb9J0">\n<!-- 메타태그정보 //-->\n<meta name="description" content="4차산업 취업채용정보와 직업/교육정보 등 국내외 전산업 일자리 채용뉴스">\n<meta property="og:title" content="리크루트타임스">\n<meta property="og:site_name" content="리크루트타임스">\n<meta property="og:image" content="http://www.recruittimes.co.kr/image/logo/snslogo_20191224113720.jpg">\n<meta property="og:url" content="http://www.recruittimes.co.kr">\n<meta property="og:description" content="4차산업 취업채용정보와 직업/교육정보 등 국내외 전산업 일자리 채용뉴스">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

contents = soup.select('section.article-list-content.type-sm.text-left')
content= contents[0]

# %%
title = content.select('div.list-titles>a>strong')[0]
title.text.strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-09d6c58dfa80> in <module>
# ----> 1 title = content.select('div.list-titles>a>strong')[0]
#       2 title.text.strip()
#
# IndexError: list index out of range

# %%
describe = content.select('div.list-block>p.list-summary>a')[0]
describe.text.strip()

# %%
from bs4 import BeautifulSoup
uri = 'http://www.recruittimes.co.kr/news/articleList.html?view_type=sm'
article = []

for page in range(1,11):
    target = uri + str(page)
    print(target)
    browser.get(target)
    html= browser.page_source
    soup = BeautifulSoup(html,'html.parser')
    contents = soup.select('section.article-list-content.type-sm.text-left')
    
    for content in contents:
        
        title = content.select('div.list-titles>a>strong')[0]
        describe = content.select('div.list-block>p.list-summary>a')[0]
        article.append([title.text.strip(), describe.text.strip()])
        
    print(article)
