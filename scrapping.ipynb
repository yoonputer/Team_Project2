# %%
from selenium import webdriver

# %%
browser = webdriver.Chrome('c:/chromedriver.exe')

# %%
browser.get('https://www.jobkorea.co.kr/SelfIntroduction/PassAssayIndex')

# %%
html = browser.page_source
html
# Out:
# '<html lang="ko"><head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge, chrome=1">\n    <title>취업 자소서 작성 - 취업성공툴 | 잡코리아</title>\n\n    \n    <link rel="SHORTCUT ICON" href="//www.jobkorea.co.kr/favicon.ico?v1904091400">\n    <link rel="canonical" href="//www.jobkorea.co.kr/SelfIntroduction/PassAssayIndex">\n\n\n    <meta name="title" content="취업 자소서 작성 - 취업성공툴 | 잡코리아">\n    <meta name="writer" content="잡코리아">\n    <meta name="description" content="자소서 항목별 작성과 동시에 기업별 합격자소서까지 한 번에 볼 수 있는 자소서 작성 툴입니다.">\n    <meta name="keywords" content="채용 정보, 업종, 직종, 직무, 구인, 구직, 경력, 채용, 공고, 잡코리아">\n\n    <meta name="verify-v1" content="wfOOCE9Vtx+Z5etOXJnS9LU03yGpBxkK74T/yU63Xqs=">\n\n    <meta property="og:site_name" content="잡코리아 신입공채">\n    <meta property="og:title" content="잡코리아 신입공채">\n    <meta property="og:description" content="자소서 항목별 작성과 동시에 기업별 합격자소서까지 한 번에 볼 수 있는 자소서 작성 툴입니다.">\n    <meta property="og:image" content="//file1.jobkorea.co.kr/mailing/201
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
contents = soup.select('div.introListTxtArea')
print(type(contents))
contents[0]
# Out:
# <class 'bs4.element.ResultSet'>
# <div class="introListTxtArea">
# <span class="listDiv">한국수력원자력(주)</span>
# <a biz_no="1208618943" class="listTle passBtnGry_1" href="#" pfl_no="237136">2021 상반기 신입 해외영업·무역영업</a>
# </div>

# %%
browser.find_element_by_xpath("//*[@id='container']/article[1]/section/ul/li[1]/div[2]/a").click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="c8b591693a74eaecc36fedd4c0e74786", element="b9dd7230-67b7-45b7-9fe2-8f5212205e44")>>

# %%
# li > dl > dt
